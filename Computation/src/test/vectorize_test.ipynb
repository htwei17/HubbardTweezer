# %% [markdown]
# ## Profiler: why the function is single-threaded?

# %%
from Hubbard.equalizer import *
import numpy as np
import matplotlib.pyplot as plt

N = 20
R0 = np.array([3, 3, 7.2])
G = HubbardParamEqualizer(N,
                          R0=R0,
                          lattice=np.array([4], dtype=int),
                          band=1,
                          dim=2,
                          avg=1 / 2,
                          sparse=True,
                          equalize=False,
                          symmetry=True,
                          verbosity=0)
# %prun __, __, __, info = G.equalzie('uvt', random=True, callback=True)
# Out:
# Initial trap depths: [0.94285541 0.98085785]
# Initial waists:
# [[1.08291754 1.        ]
#  [0.98205364 1.        ]]
# Initial trap centers:
# [[-1.58238511  0.        ]
#  [-0.4082596   0.        ]]
# i=50	c=[0.09990731 0.9167044  0.07502301]	c_i=1.0916347190668363	c_i//2-c_i=-0.49423491499167793
# i=100	c=[0.00121951 0.02686512 0.0065927 ]	c_i=0.03467733374624908	c_i//2-c_i=0.3542075872553148
# i=150	c=[0.00163742 0.0015902  0.00064233]	c_i=0.0038699418280335653	c_i//2-c_i=0.04911866546302507
# i=200	c=[9.74662268e-06 3.73898051e-05 1.17859688e-04]	c_i=0.00016499611579848136	c_i//2-c_i=0.03451234249638431
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.389232003670117e-06
#             Iterations: 29
#             Function evaluations: 249
#             Gradient evaluations: 29
#          6482823 function calls (6396441 primitive calls) in 14.913 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    112940    7.377    0.000   11.540    0.000 arpack.py:533(iterate)
#    339820    2.188    0.000    2.188    0.000 {built-in method numpy.core._multiarray_umath.c_einsum}
# 406919/377559    1.237    0.000    4.274    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#    112940    1.099    0.000    3.893    0.000 core.py:390(H_op)
#     12000    0.492    0.000    0.531    0.000 function_base.py:3543(sinc)
#       500    0.217    0.000    2.573    0.005 core.py:576(wannier_func)
#    366781    0.175    0.000    0.175    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#    112940    0.147    0.000    4.184    0.000 _interface.py:201(matvec)
#      6000    0.121    0.000    0.670    0.000 core.py:303(delta)
#       500    0.107    0.000    0.108    0.000 arpack.py:573(extract)
#   1699100    0.106    0.000    0.106    0.000 einsumfunc.py:989(_einsum_dispatcher)
# 58000/3000    0.102    0.000    0.264    0.000 paths.py:190(_optimal_iterate)
#     58000    0.102    0.000    0.157    0.000 paths.py:100(calc_k12_flops)
#    339820    0.089    0.000    2.690    0.000 <__array_function__ internals>:177(einsum)
#      3000    0.068    0.000    0.595    0.000 contract.py:93(contract_path)
#      2000    0.066    0.000    2.350    0.001 core.py:277(psi)
#    339820    0.059    0.000    2.247    0.000 einsumfunc.py:997(einsum)
#       500    0.049    0.000    0.064    0.000 _quadrature.py:564(romb)
#     22882    0.047    0.000    0.047    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      2000    0.046    0.000    0.046    0.000 core.py:219(Vfun)
#      7000    0.039    0.000    1.007    0.000 numeric.py:943(tensordot)
#      3000    0.036    0.000    0.045    0.000 paths.py:63(ssa_to_linear)
#     91000    0.034    0.000    0.034    0.000 helpers.py:53(compute_size_by_dict)
#    112940    0.033    0.000    3.953    0.000 _interface.py:529(_matvec)
#       500    0.031    0.000   11.698    0.023 arpack.py:1350(eigsh)
#      8000    0.031    0.000    0.044    0.000 blas.py:12(can_blas)
#      2000    0.030    0.000    0.030    0.000 core.py:325(kinetic_offdiag)
#      3000    0.029    0.000    1.103    0.000 contract.py:530(_core_contract)
#      1000    0.027    0.000    0.064    0.000 core.py:332(Tmat_1d)
#    112940    0.027    0.000    3.919    0.000 core.py:446(applyH)
#       250    0.025    0.000    0.186    0.001 core.py:313(locality_mat)
#     69000    0.021    0.000    0.058    0.000 helpers.py:137(flop_count)
#     97524    0.019    0.000    0.025    0.000 {built-in method builtins.max}
#     33000    0.018    0.000    0.045    0.000 parser.py:154(<genexpr>)
#       250    0.017    0.000    2.687    0.011 core.py:524(singleband_interaction)
#      3000    0.016    0.000    1.717    0.001 contract.py:378(contract)
#       500    0.016    0.000    0.061    0.000 core.py:152(Vfun)
#      1879    0.015    0.000    0.015    0.000 {built-in method builtins.abs}
#     14000    0.014    0.000    0.014    0.000 {built-in method numpy.arange}
#      3500    0.013    0.000    0.013    0.000 core.py:249(get_init)
#      8000    0.013    0.000    0.026    0.000 helpers.py:82(find_contraction)
# 132331/131335    0.013    0.000    0.015    0.000 {built-in method builtins.isinstance}
#    256135    0.012    0.000    0.012    0.000 {built-in method builtins.len}
#      6548    0.012    0.000    0.012    0.000 {built-in method numpy.zeros}
#    135107    0.011    0.000    0.011    0.000 {built-in method numpy.asanyarray}
#     83000    0.011    0.000    0.011    0.000 {method 'count' of 'str' objects}
#      2000    0.010    0.000    0.010    0.000 core.py:290(<listcomp>)
#    130566    0.010    0.000    0.010    0.000 {built-in method numpy.asarray}
#     78000    0.009    0.000    0.009    0.000 {method 'find' of 'str' objects}
#      3000    0.009    0.000    0.318    0.000 paths.py:152(optimal)
#     24000    0.009    0.000    0.009    0.000 {built-in method builtins.sorted}
#     58000    0.009    0.000    0.009    0.000 {method 'union' of 'frozenset' objects}
#     28000    0.008    0.000    0.019    0.000 {method 'join' of 'str' objects}
#      1508    0.008    0.000    0.011    0.000 stride_tricks.py:339(_broadcast_to)
#     25000    0.008    0.000    0.014    0.000 parser.py:155(<listcomp>)
#      3000    0.008    0.000    0.031    0.000 parser.py:246(parse_einsum_input)
#     93315    0.008    0.000    0.008    0.000 {method 'append' of 'list' objects}
#       250    0.007    0.000    0.015    0.000 _decomp.py:267(eigh)
#       500    0.007    0.000   11.902    0.024 core.py:430(H_solver)
#      1000    0.007    0.000    0.009    0.000 _util.py:116(_aligned_zeros)
#     51000    0.006    0.000    0.006    0.000 parser.py:155(<genexpr>)
#       500    0.006    0.000    0.090    0.000 core.py:256(Vmat)
#  1000/500    0.006    0.000    0.009    0.000 numeric.py:1140(roll)
#     64000    0.006    0.000    0.006    0.000 {method 'pop' of 'list' objects}
#     19000    0.006    0.000    0.006    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#      8000    0.005    0.000    0.051    0.000 parser.py:141(find_output_shape)
#       249    0.005    0.000   14.817    0.060 equalizer.py:289(cbd_cost_func)
#       250    0.005    0.000    0.208    0.001 core.py:432(singleband_optimize)
#       500    0.005    0.000    0.013    0.000 function_base.py:23(linspace)
#       500    0.005    0.000   11.932    0.024 core.py:299(solve_sector)
#     12000    0.004    0.000    0.549    0.000 <__array_function__ internals>:177(sinc)
#       500    0.004    0.000    0.005    0.000 core.py:307(<listcomp>)
#     24000    0.004    0.000    0.004    0.000 paths.py:74(<genexpr>)
#      3322    0.004    0.000    0.013    0.000 fromnumeric.py:69(_wrapreduction)
#     16000    0.004    0.000    0.004    0.000 {method 'union' of 'set' objects}
#      7000    0.004    0.000    1.023    0.000 contract.py:369(_tensordot)
#       750    0.004    0.000    0.005    0.000 core.py:211(symm_unfold)
#      8295    0.004    0.000    0.004    0.000 {built-in method numpy.array}
#     23022    0.004    0.000    0.004    0.000 {method 'split' of 'str' objects}
#     24000    0.004    0.000    0.006    0.000 helpers.py:126(<genexpr>)
#     12029    0.004    0.000    0.039    0.000 <__array_function__ internals>:177(where)
#     31000    0.004    0.000    0.004    0.000 contract.py:564(<genexpr>)
#       500    0.004    0.000    0.074    0.000 core.py:359(Tmat)
#      7000    0.004    0.000    1.017    0.000 <__array_function__ internals>:177(tensordot)
#      3000    0.004    0.000    0.015    0.000 parser.py:122(find_output_str)
#       250    0.004    0.000   11.938    0.048 core.py:242(eigen_basis)
#      1500    0.004    0.000    0.005    0.000 twodim_base.py:161(eye)
#       500    0.004    0.000    0.006    0.000 shape_base.py:1171(tile)
#     10000    0.004    0.000    0.005    0.000 sharing.py:23(currently_sharing)
#       250    0.003    0.000    0.068    0.000 core.py:584(intgrl3d)
#      2000    0.003    0.000    0.009    0.000 core.py:289(<listcomp>)
#     11000    0.003    0.000    0.006    0.000 parser.py:138(<genexpr>)
#      7000    0.003    0.000    0.922    0.000 <__array_function__ internals>:177(dot)
#      7000    0.003    0.000    1.029    0.000 sharing.py:128(cached_tensordot)
#      3000    0.003    0.000    0.007    0.000 contract.py:244(<listcomp>)
#       250    0.003    0.000   14.836    0.059 core.py:168(singleband_Hubbard)
#      8000    0.003    0.000    0.004    0.000 contract.py:289(<listcomp>)
#      6251    0.003    0.000    0.007    0.000 fromnumeric.py:51(_wrapfunc)
#      8000    0.003    0.000    0.004    0.000 contract.py:552(<listcomp>)
#      5278    0.003    0.000    0.003    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       500    0.003    0.000    0.016    0.000 arpack.py:379(__init__)
#      3000    0.002    0.000    0.321    0.000 paths.py:1072(auto)
#      7000    0.002    0.000    0.002    0.000 blas.py:85(<listcomp>)
#     37000    0.002    0.000    0.002    0.000 {method 'pop' of 'dict' objects}
#       250    0.002    0.000    0.017    0.000 core.py:99(update_lattice)
#      2500    0.002    0.000    0.012    0.000 fromnumeric.py:2970(prod)
#      6002    0.002    0.000    0.005    0.000 {built-in method builtins.sum}
#      8000    0.002    0.000    0.003    0.000 contract.py:290(<listcomp>)
#      2274    0.002    0.000    0.012    0.000 function_base.py:5344(append)
#      3000    0.002    0.000    0.006    0.000 parser.py:277(<listcomp>)
#     10000    0.002    0.000    0.002    0.000 dispatch.py:60(get_func)
#      5000    0.002    0.000    0.011    0.000 <__array_function__ internals>:177(transpose)
#       250    0.002    0.000    0.004    0.000 _util.py:241(_asarray_validated)
#      3000    0.002    0.000    0.003    0.000 contract.py:510(infer_backend)
#      7000    0.002    0.000    0.002    0.000 numeric.py:1114(<listcomp>)
#       250    0.002    0.000    0.002    0.000 core.py:67(update_R0)
#      3000    0.002    0.000    0.005    0.000 contract.py:514(parse_backend)
#     14000    0.002    0.000    0.002    0.000 contract.py:253(<genexpr>)
#      9000    0.002    0.000    0.002    0.000 {method 'replace' of 'str' objects}
#     11000    0.002    0.000    0.003    0.000 parser.py:158(possibly_convert_to_numpy)
#       748    0.002    0.000    0.005    0.000 _methods.py:162(_mean)
#      3000    0.002    0.000    0.002    0.000 contract.py:214(<listcomp>)
#       250    0.002    0.000    0.004    0.000 core.py:229(xy_links)
#      2879    0.002    0.000    0.007    0.000 <__array_function__ internals>:177(concatenate)
#       500    0.002    0.000    0.004    0.000 arpack.py:309(__init__)
#       997    0.002    0.000    0.004    0.000 function_base.py:537(asarray_chkfinite)
#     13248    0.002    0.000    0.002    0.000 {built-in method builtins.hasattr}
#      1000    0.002    0.000    0.010    0.000 contract.py:333(_einsum)
#       250    0.002    0.000    0.007    0.000 arraypad.py:529(pad)
#         1    0.002    0.002   14.832   14.832 _slsqp_py.py:214(_minimize_slsqp)
#      5000    0.002    0.000    0.006    0.000 fromnumeric.py:601(transpose)
#       249    0.002    0.000    0.010    0.000 equalizer.py:391(t_cost_func)
#       747    0.002    0.000    0.005    0.000 _misc.py:17(norm)
#       500    0.002    0.000    0.021    0.000 function_base.py:4812(meshgrid)
#      2000    0.002    0.000    0.007    0.000 contract.py:361(_transpose)
#       748    0.002    0.000    0.002    0.000 _methods.py:66(_count_reduce_items)
#      3322    0.001    0.000    0.001    0.000 fromnumeric.py:70(<dictcomp>)
#       502    0.001    0.000    0.015    0.000 stride_tricks.py:479(broadcast_arrays)
#      2500    0.001    0.000    0.015    0.000 <__array_function__ internals>:177(prod)
#      2274    0.001    0.000    0.016    0.000 <__array_function__ internals>:177(append)
#       249    0.001    0.000    0.007    0.000 equalizer.py:413(u_cost_func)
#      2002    0.001    0.000    0.003    0.000 {built-in method builtins.all}
#      7000    0.001    0.000    0.001    0.000 numeric.py:1119(<listcomp>)
#      7251    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#       249    0.001    0.000    0.006    0.000 equalizer.py:380(v_cost_func)
#       250    0.001    0.000    0.003    0.000 lapack.py:968(_compute_lwork)
#       502    0.001    0.000    0.001    0.000 stride_tricks.py:415(_broadcast_shape)
#      3500    0.001    0.000    0.014    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      7000    0.001    0.000    0.001    0.000 numeric.py:1120(<listcomp>)
#     10009    0.001    0.000    0.001    0.000 {built-in method _thread.get_ident}
#      1805    0.001    0.000    0.002    0.000 fromnumeric.py:1755(ravel)
#     12029    0.001    0.000    0.001    0.000 multiarray.py:341(where)
#      7000    0.001    0.000    0.001    0.000 numeric.py:1122(<listcomp>)
#       249    0.001    0.000   14.821    0.060 _minimize.py:907(fun_out)
#     12000    0.001    0.000    0.001    0.000 function_base.py:3539(_sinc_dispatcher)
#      5275    0.001    0.000    0.002    0.000 {built-in method builtins.issubclass}
#       500    0.001    0.000    0.002    0.000 function_base.py:4943(<listcomp>)
#      2000    0.001    0.000    0.009    0.000 sharing.py:110(cached_transpose)
#       500    0.001    0.000    0.003    0.000 arraypad.py:454(_as_pairs)
#      1001    0.001    0.000    0.003    0.000 numerictypes.py:356(issubdtype)
#      3000    0.001    0.000    0.001    0.000 contract.py:218(<listcomp>)
#       249    0.001    0.000   14.823    0.060 _differentiable_functions.py:132(fun_wrapped)
#       250    0.001    0.000    0.001    0.000 arraypad.py:86(_pad_simple)
#     10000    0.001    0.000    0.001    0.000 parser.py:21(is_valid_einsum_char)
#       500    0.001    0.000    0.004    0.000 fromnumeric.py:1394(resize)
#      9829    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#      1758    0.001    0.000    0.002    0.000 {built-in method builtins.any}
#      2002    0.001    0.000    0.002    0.000 numerictypes.py:282(issubclass_)
#       500    0.001    0.000    0.001    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#        29    0.001    0.000   10.260    0.354 _numdiff.py:566(_dense_difference)
#      2807    0.001    0.000    0.001    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       500    0.001    0.000    0.001    0.000 numeric.py:1341(normalize_axis_tuple)
#      2502    0.001    0.000    0.003    0.000 <__array_function__ internals>:177(ndim)
#      1281    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#      1805    0.001    0.000    0.004    0.000 <__array_function__ internals>:177(ravel)
#      7000    0.001    0.000    0.001    0.000 numeric.py:939(_tensordot_dispatcher)
#      7000    0.001    0.000    0.001    0.000 numeric.py:1128(<listcomp>)
#      4500    0.001    0.000    0.001    0.000 _quadrature.py:282(tupleset)
#      7000    0.001    0.000    0.001    0.000 multiarray.py:736(dot)
#      1000    0.001    0.000    0.003    0.000 _sputils.py:199(isintlike)
#      7000    0.001    0.000    0.001    0.000 numeric.py:1127(<listcomp>)
#       500    0.001    0.000    0.028    0.000 _interface.py:510(__init__)
#      4248    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#      1000    0.001    0.000    0.011    0.000 sharing.py:148(cached_einsum)
#      1000    0.001    0.000    0.001    0.000 {method 'conj' of 'numpy.generic' objects}
#       500    0.001    0.000    0.001    0.000 lapack.py:1003(_check_work_float)
#       500    0.001    0.000    0.001    0.000 _threadsafety.py:37(__exit__)
#       748    0.001    0.000    0.006    0.000 fromnumeric.py:3356(mean)
#      1000    0.001    0.000    0.001    0.000 {method 'fill' of 'numpy.ndarray' objects}
#      3000    0.001    0.000    0.001    0.000 paths.py:1122(get_path_fn)
#       777    0.001    0.000    0.003    0.000 twodim_base.py:234(diag)
#       997    0.001    0.000    0.001    0.000 blas.py:383(getter)
#      3000    0.001    0.000    0.001    0.000 contract.py:74(_choose_memory_arg)
#      8508    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#       500    0.001    0.000    0.005    0.000 _interface.py:157(__init__)
#       748    0.001    0.000    0.001    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#       500    0.001    0.000    0.022    0.000 _interface.py:173(_init_dtype)
#      3000    0.001    0.000    0.001    0.000 dispatch.py:94(has_tensordot)
#       502    0.001    0.000    0.011    0.000 stride_tricks.py:545(<listcomp>)
#       500    0.001    0.000    0.001    0.000 {method 'repeat' of 'numpy.ndarray' objects}
#       500    0.001    0.000    0.004    0.000 _sputils.py:221(isshape)
#      6016    0.001    0.000    0.001    0.000 stride_tricks.py:344(<genexpr>)
#       250    0.001    0.000    0.001    0.000 arraypad.py:129(_set_pad_area)
#      3500    0.001    0.000    0.013    0.000 _methods.py:46(_sum)
#        29    0.001    0.000   10.262    0.354 _numdiff.py:275(approx_derivative)
#        29    0.001    0.000    0.001    0.000 _numdiff.py:11(_adjust_scheme_to_bounds)
#       749    0.001    0.000    0.001    0.000 numeric.py:1859(isscalar)
#      5000    0.001    0.000    0.001    0.000 fromnumeric.py:597(_transpose_dispatcher)
#      1101    0.001    0.000    0.003    0.000 {method 'all' of 'numpy.ndarray' objects}
#       780    0.001    0.000    0.001    0.000 <__array_function__ internals>:177(empty_like)
#       250    0.001    0.000    0.001    0.000 core.py:271(sector)
#       500    0.001    0.000    0.001    0.000 {method 'any' of 'numpy.generic' objects}
#      2002    0.001    0.000    0.001    0.000 {built-in method time.time}
#       748    0.001    0.000    0.001    0.000 fromnumeric.py:1552(diagonal)
#  1000/500    0.000    0.000    0.010    0.000 <__array_function__ internals>:177(roll)
#       249    0.000    0.000   14.818    0.060 equalizer.py:86(cost_func)
#      2502    0.000    0.000    0.000    0.000 fromnumeric.py:3164(ndim)
#       498    0.000    0.000    0.002    0.000 typing.py:719(__instancecheck__)
#       777    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(diag)
#       500    0.000    0.000    0.022    0.000 <__array_function__ internals>:177(meshgrid)
#       500    0.000    0.000    0.001    0.000 _interface.py:142(__new__)
#      3000    0.000    0.000    0.000    0.000 dispatch.py:76(has_einsum)
#       500    0.000    0.000    0.002    0.000 fromnumeric.py:1012(argsort)
#      1106    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       500    0.000    0.000    0.003    0.000 core.py:100(update_p)
#       251    0.000    0.000    0.002    0.000 numeric.py:76(zeros_like)
#       748    0.000    0.000    0.007    0.000 <__array_function__ internals>:177(mean)
#       500    0.000    0.000    0.007    0.000 <__array_function__ internals>:177(tile)
#       529    0.000    0.000    0.003    0.000 fromnumeric.py:2305(any)
#       502    0.000    0.000    0.016    0.000 <__array_function__ internals>:177(broadcast_arrays)
#      3000    0.000    0.000    0.000    0.000 contract.py:475(<dictcomp>)
#      3000    0.000    0.000    0.000    0.000 contract.py:489(<listcomp>)
#       500    0.000    0.000    0.001    0.000 _threadsafety.py:30(__enter__)
#      1500    0.000    0.000    0.000    0.000 shape_base.py:1253(<genexpr>)
#       250    0.000    0.000    0.000    0.000 core.py:256(<listcomp>)
#      1000    0.000    0.000    0.002    0.000 index_tricks.py:913(diag_indices)
#       498    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#      1508    0.000    0.000    0.000    0.000 function_base.py:346(iterable)
#       500    0.000    0.000    0.001    0.000 arpack.py:897(_aslinearoperator_with_dtype)
#      3000    0.000    0.000    0.000    0.000 fromnumeric.py:2965(_prod_dispatcher)
#      1000    0.000    0.000    0.002    0.000 parser.py:35(has_valid_einsum_chars_only)
#       498    0.000    0.000    0.001    0.000 typing.py:848(__subclasscheck__)
#       314    0.000    0.000    0.001    0.000 shape_base.py:23(atleast_1d)
#       250    0.000    0.000    0.002    0.000 core.py:200(nn_tunneling)
#      2879    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#       500    0.000    0.000    0.001    0.000 function_base.py:4956(<listcomp>)
#       502    0.000    0.000    0.001    0.000 stride_tricks.py:537(<listcomp>)
#       249    0.000    0.000    0.001    0.000 fromnumeric.py:2160(sum)
#       500    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(product)
#      1508    0.000    0.000    0.000    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#       748    0.000    0.000    0.002    0.000 <__array_function__ internals>:177(diagonal)
#      2250    0.000    0.000    0.000    0.000 {method 'conj' of 'numpy.ndarray' objects}
#       174    0.000    0.000   10.259    0.059 _numdiff.py:455(fun_wrapped)
#       500    0.000    0.000    0.002    0.000 <__array_function__ internals>:177(argsort)
#      1008    0.000    0.000    0.000    0.000 stride_tricks.py:541(<genexpr>)
#       250    0.000    0.000    0.008    0.000 <__array_function__ internals>:177(pad)
#       750    0.000    0.000    0.001    0.000 lapack.py:999(<genexpr>)
#      1101    0.000    0.000    0.002    0.000 _methods.py:60(_all)
#       529    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(any)
#      2274    0.000    0.000    0.000    0.000 function_base.py:5340(_append_dispatcher)
#       500    0.000    0.000    0.014    0.000 <__array_function__ internals>:177(linspace)
#      1000    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#      1000    0.000    0.000    0.000    0.000 shape_base.py:1243(<genexpr>)
#       104    0.000    0.000    0.001    0.000 _optimize.py:282(_check_clip_x)
#       500    0.000    0.000    0.004    0.000 fromnumeric.py:3776(product)
#       500    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(resize)
#       500    0.000    0.000    0.000    0.000 numeric.py:1391(<listcomp>)
#         7    0.000    0.000    0.000    0.000 arrayprint.py:934(fillFormat)
#      1805    0.000    0.000    0.000    0.000 fromnumeric.py:1751(_ravel_dispatcher)
#         6    0.000    0.000    0.000    0.000 socket.py:543(send)
#      2502    0.000    0.000    0.000    0.000 fromnumeric.py:3160(_ndim_dispatcher)
#       498    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(real)
#       500    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#      2000    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#       250    0.000    0.000    0.000    0.000 type_check.py:303(iscomplexobj)
#       500    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(result_type)
#      1248    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#       314    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(atleast_1d)
#       500    0.000    0.000    0.001    0.000 fromnumeric.py:198(reshape)
#       500    0.000    0.000    0.000    0.000 arpack.py:300(choose_ncv)
#       249    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#       251    0.000    0.000    0.002    0.000 <__array_function__ internals>:177(zeros_like)
#       500    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(reshape)
#      1508    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#       104    0.000    0.000    0.000    0.000 numeric.py:2388(array_equal)
#       250    0.000    0.000    0.000    0.000 {method 'round' of 'numpy.ndarray' objects}
#       250    0.000    0.000    0.000    0.000 arraypad.py:58(_view_roi)
#       282    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copyto)
#       250    0.000    0.000    0.000    0.000 core.py:6377(isMaskedArray)
#       250    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(iscomplexobj)
#       500    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10105b2b8}
#       500    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#       500    0.000    0.000    0.000    0.000 arraypad.py:109(<genexpr>)
#       250    0.000    0.000    0.000    0.000 core.py:263(<listcomp>)
#       250    0.000    0.000    0.001    0.000 fromnumeric.py:3764(round_)
#       498    0.000    0.000    0.001    0.000 abc.py:121(__subclasscheck__)
#       500    0.000    0.000    0.000    0.000 _interface.py:773(aslinearoperator)
#       710    0.000    0.000    0.001    0.000 _methods.py:54(_any)
#       250    0.000    0.000    0.000    0.000 core.py:264(<listcomp>)
#       500    0.000    0.000    0.000    0.000 arraypad.py:33(_slice_at_axis)
#       249    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(sum)
#       250    0.000    0.000    0.001    0.000 fromnumeric.py:3257(around)
#       500    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       250    0.000    0.000    0.000    0.000 core.py:265(<listcomp>)
#        75    0.000    0.000    4.494    0.060 _differentiable_functions.py:264(fun)
#       500    0.000    0.000    0.000    0.000 arraypad.py:120(<genexpr>)
#       250    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(copy)
#       250    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(around)
#        29    0.000    0.000   10.262    0.354 _differentiable_functions.py:170(update_grad)
#       250    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(round_)
#       251    0.000    0.000    0.000    0.000 _base.py:1301(isspmatrix)
#       500    0.000    0.000    0.000    0.000 numeric.py:1227(<dictcomp>)
#      1000    0.000    0.000    0.000    0.000 numeric.py:1136(_roll_dispatcher)
#       104    0.000    0.000   14.343    0.138 _optimize.py:275(eval)
#       249    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#       250    0.000    0.000    0.000    0.000 core.py:77(update_ab)
#       498    0.000    0.000    0.000    0.000 type_check.py:121(real)
#        74    0.000    0.000    0.000    0.000 _differentiable_functions.py:240(update_x)
#         1    0.000    0.000   14.913   14.913 {built-in method builtins.exec}
#       500    0.000    0.000    0.000    0.000 shape_base.py:1167(_tile_dispatcher)
#       748    0.000    0.000    0.000    0.000 fromnumeric.py:3351(_mean_dispatcher)
#       249    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#       777    0.000    0.000    0.000    0.000 twodim_base.py:230(_diag_dispatcher)
#       250    0.000    0.000    0.000    0.000 function_base.py:846(copy)
#       780    0.000    0.000    0.000    0.000 multiarray.py:80(empty_like)
#       257    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       104    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(array_equal)
#       210    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#       748    0.000    0.000    0.000    0.000 fromnumeric.py:1548(_diagonal_dispatcher)
#        75    0.000    0.000    0.000    0.000 _slsqp_py.py:464(_eval_constraint)
#       500    0.000    0.000    0.000    0.000 multiarray.py:664(result_type)
#       500    0.000    0.000    0.000    0.000 fromnumeric.py:1390(_resize_dispatcher)
#       500    0.000    0.000    0.000    0.000 function_base.py:4807(_meshgrid_dispatcher)
#        36    0.000    0.000    0.000    0.000 iostream.py:518(write)
#       500    0.000    0.000    0.000    0.000 function_base.py:18(_linspace_dispatcher)
#       500    0.000    0.000    0.000    0.000 fromnumeric.py:1008(_argsort_dispatcher)
#      33/7    0.000    0.000    0.000    0.000 arrayprint.py:789(recurser)
#       529    0.000    0.000    0.000    0.000 fromnumeric.py:2300(_any_dispatcher)
#       500    0.000    0.000    0.000    0.000 fromnumeric.py:3253(_around_dispatcher)
#       105    0.000    0.000    4.565    0.043 _differentiable_functions.py:249(_update_fun)
#        75    0.000    0.000    4.565    0.061 _differentiable_functions.py:154(update_fun)
#       498    0.000    0.000    0.000    0.000 type_check.py:117(_real_dispatcher)
#       502    0.000    0.000    0.000    0.000 stride_tricks.py:475(_broadcast_arrays_dispatcher)
#        29    0.000    0.000    9.849    0.340 _differentiable_functions.py:270(grad)
#       500    0.000    0.000    0.000    0.000 fromnumeric.py:193(_reshape_dispatcher)
#        29    0.000    0.000    0.000    0.000 _slsqp_py.py:483(_eval_con_normals)
#       260    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       250    0.000    0.000    0.000    0.000 _misc.py:180(_datacopied)
#        29    0.000    0.000    0.000    0.000 numeric.py:218(ones_like)
#       250    0.000    0.000    0.000    0.000 type_check.py:206(_is_type_dispatcher)
#       282    0.000    0.000    0.000    0.000 multiarray.py:1071(copyto)
#        22    0.000    0.000    0.000    0.000 arrayprint.py:1018(__call__)
#       249    0.000    0.000    0.000    0.000 fromnumeric.py:2155(_sum_dispatcher)
#         1    0.000    0.000   14.832   14.832 _minimize.py:45(minimize)
#        30    0.000    0.000   10.262    0.342 _differentiable_functions.py:254(_update_grad)
#       314    0.000    0.000    0.000    0.000 shape_base.py:19(_atleast_1d_dispatcher)
#        14    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#        38    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.dragon4_positional}
#         7    0.000    0.000    0.001    0.000 arrayprint.py:523(_array2string)
#       251    0.000    0.000    0.000    0.000 numeric.py:72(_zeros_like_dispatcher)
#        16    0.000    0.000    0.000    0.000 _ufunc_config.py:32(seterr)
#         1    0.000    0.000    0.001    0.001 equalizer.py:239(init_guess)
#        29    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(ones_like)
#       250    0.000    0.000    0.000    0.000 function_base.py:842(_copy_dispatcher)
#         7    0.000    0.000    0.001    0.000 arrayprint.py:452(_get_format_function)
#        29    0.000    0.000    0.000    0.000 _numdiff.py:193(_prepare_bounds)
#       250    0.000    0.000    0.000    0.000 arraypad.py:521(_pad_dispatcher)
#         1    0.000    0.000   14.912   14.912 equalizer.py:40(equalzie)
#         6    0.000    0.000    0.000    0.000 iostream.py:202(schedule)
#        16    0.000    0.000    0.000    0.000 _ufunc_config.py:131(geterr)
#        30    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(all)
#         9    0.000    0.000    0.001    0.000 arrayprint.py:506(wrapper)
#         7    0.000    0.000    0.001    0.000 arrayprint.py:561(array2string)
#        30    0.000    0.000    0.000    0.000 fromnumeric.py:2404(all)
#         7    0.000    0.000    0.000    0.000 arrayprint.py:907(__init__)
#        10    0.000    0.000    0.000    0.000 {method 'uniform' of 'numpy.random.mtrand.RandomState' objects}
#        29    0.000    0.000    0.000    0.000 _numdiff.py:204(<listcomp>)
#         9    0.000    0.000    0.001    0.000 arrayprint.py:1575(_array_str_implementation)
#         7    0.000    0.000    0.000    0.000 arrayprint.py:403(_get_formatdict)
#        36    0.000    0.000    0.000    0.000 iostream.py:429(_is_master_process)
#         6    0.000    0.000    0.000    0.000 threading.py:1133(is_alive)
#        22    0.000    0.000    0.000    0.000 arrayprint.py:753(_extendLine_pretty)
#         7    0.000    0.000    0.000    0.000 arrayprint.py:64(_make_options_dict)
#        22    0.000    0.000    0.000    0.000 arrayprint.py:739(_extendLine)
#        25    0.000    0.000    0.000    0.000 arrayprint.py:984(<genexpr>)
#       104    0.000    0.000    0.000    0.000 numeric.py:2384(_array_equal_dispatcher)
#        36    0.000    0.000    0.000    0.000 iostream.py:448(_schedule_flush)
#         1    0.000    0.000    0.486    0.486 _differentiable_functions.py:86(__init__)
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        16    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#        25    0.000    0.000    0.000    0.000 arrayprint.py:989(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _minimize.py:928(_add_to_array)
#         7    0.000    0.000    0.000    0.000 arrayprint.py:411(<lambda>)
#         8    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__enter__)
#        44    0.000    0.000    0.000    0.000 _constraints.py:12(_arr_to_scalar)
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.dragon4_scientific}
#         6    0.000    0.000    0.000    0.000 threading.py:1066(_wait_for_tstate_lock)
#         7    0.000    0.000    0.000    0.000 arrayprint.py:780(_formatArray)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:2675(amax)
#         6    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#         8    0.000    0.000    0.000    0.000 _ufunc_config.py:434(__exit__)
#        32    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         1    0.000    0.000   14.912   14.912 <string>:1(<module>)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amax)
#        36    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        22    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 _methods.py:91(_clip_dep_is_scalar_nan)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:2800(amin)
#         2    0.000    0.000    0.000    0.000 _constraints.py:399(old_bound_to_new)
#         2    0.000    0.000    0.000    0.000 _constraints.py:241(__init__)
#         1    0.000    0.000    0.000    0.000 equalizer.py:273(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _constraints.py:412(<listcomp>)
#         3    0.000    0.000    0.000    0.000 equalizer.py:258(<genexpr>)
#         2    0.000    0.000    0.000    0.000 arrayprint.py:1568(_guarded_repr_or_str)
#        36    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        36    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 _minimize.py:939(standardize_bounds)
#        25    0.000    0.000    0.000    0.000 arrayprint.py:993(<genexpr>)
#         4    0.000    0.000    0.000    0.000 arrayprint.py:963(<genexpr>)
#        29    0.000    0.000    0.000    0.000 numeric.py:214(_ones_like_dispatcher)
#        25    0.000    0.000    0.000    0.000 arrayprint.py:994(<genexpr>)
#         8    0.000    0.000    0.000    0.000 _ufunc_config.py:425(__init__)
#         1    0.000    0.000    0.486    0.486 _optimize.py:175(_prepare_scalar_function)
#        30    0.000    0.000    0.000    0.000 fromnumeric.py:2399(_all_dispatcher)
#         7    0.000    0.000    0.000    0.000 arrayprint.py:72(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 arrayprint.py:960(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _constraints.py:414(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _methods.py:125(_clip)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amin)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        11    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 _constraints.py:381(new_bounds_to_old)
#         1    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 _constraints.py:393(<listcomp>)
#         2    0.000    0.000    0.000    0.000 numeric.py:149(ones)
#         1    0.000    0.000    0.000    0.000 _minimize.py:898(_remove_from_bounds)
#         9    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 _constraints.py:233(_input_validation)
#         1    0.000    0.000    0.000    0.000 _slsqp_py.py:354(<listcomp>)
#         1    0.000    0.000    0.000    0.000 typing.py:271(inner)
#         1    0.000    0.000    0.000    0.000 _methods.py:106(_clip_dep_invoke_with_casting)
#         6    0.000    0.000    0.000    0.000 threading.py:536(is_set)
#         1    0.000    0.000    0.000    0.000 type_check.py:84(asfarray)
#         7    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 _minimize.py:951(standardize_constraints)
#         9    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 _optimize.py:122(__getattr__)
#         1    0.000    0.000    0.000    0.000 _constraints.py:394(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _methods.py:101(_clip_dep_is_byte_swapped)
#         1    0.000    0.000    0.000    0.000 equalizer.py:221(str_to_flags)
#         1    0.000    0.000    0.000    0.000 shape_base.py:81(atleast_2d)
#         6    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         7    0.000    0.000    0.000    0.000 arrayprint.py:898(_none_or_positive_arg)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(broadcast_to)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2083(clip)
#         1    0.000    0.000    0.000    0.000 {method 'clip' of 'numpy.ndarray' objects}
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:2670(_amax_dispatcher)
#         3    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(asfarray)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:2795(_amin_dispatcher)
#         4    0.000    0.000    0.000    0.000 arrayprint.py:965(<genexpr>)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(clip)
#         4    0.000    0.000    0.000    0.000 arrayprint.py:964(<genexpr>)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_2d)
#         4    0.000    0.000    0.000    0.000 arrayprint.py:968(<genexpr>)
#         5    0.000    0.000    0.000    0.000 equalizer.py:256(<genexpr>)
#         2    0.000    0.000    0.000    0.000 stride_tricks.py:366(broadcast_to)
#         5    0.000    0.000    0.000    0.000 equalizer.py:267(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 arrayprint.py:977(<genexpr>)
#         3    0.000    0.000    0.000    0.000 equalizer.py:255(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _optimize.py:269(_clip_x_for_func)
#         3    0.000    0.000    0.000    0.000 equalizer.py:266(<genexpr>)
#         3    0.000    0.000    0.000    0.000 equalizer.py:245(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 _minimize.py:905(_remove_from_func)
#         3    0.000    0.000    0.000    0.000 equalizer.py:248(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _methods.py:38(_amax)
#         3    0.000    0.000    0.000    0.000 equalizer.py:254(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _optimize.py:147(_check_unknown_options)
#         1    0.000    0.000    0.000    0.000 _optimize.py:255(hess)
#         3    0.000    0.000    0.000    0.000 equalizer.py:261(<genexpr>)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2079(_clip_dispatcher)
#         1    0.000    0.000    0.000    0.000 _minimize.py:675(<listcomp>)
#         1    0.000    0.000    0.000    0.000 shape_base.py:77(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 _slsqp_py.py:327(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _slsqp_py.py:329(<listcomp>)
#         2    0.000    0.000    0.000    0.000 stride_tricks.py:362(_broadcast_to_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 type_check.py:80(_asfarray_dispatcher)

# %%
from DVR.core import *
from numba import guvectorize, float64, int64

p = np.array([1,  1,  1])
x = [np.linspace(0, 1, 10), np.linspace(0, 1, 10), np.zeros(10)]
xn = [np.linspace(0, 1, 10), np.linspace(0, 1, 10), np.zeros(10)]


def f1(p, x, xn):
    V = map(delta, p, x, xn)
    return contract('ij,kl,mn', *V)


def f2(p, x, xn):
    vd = np.vectorize(delta, signature='(),(m),(n)->(m,n)')
    V = vd(p, x, xn)
    return contract('ij,kl,mn', *V)


@guvectorize([(int64, float64[:], float64[:], float64[:, :])], '(),(m),(n)->(m,n)', target='parallel')
def numbadelta(p: int, x: np.ndarray, xn: np.ndarray, Wx):
    # Symmetrized sinc DVR basis funciton, x in unit of dx
    x = x.copy()
    xn = xn.copy()
    Wx = np.sinc(x.reshape(-1, 1) - xn.reshape(1, -1))
    if p != 0:
        Wx += p * np.sinc(x.reshape(-1, 1) + xn.reshape(1, -1))
        Wx /= np.sqrt(2)
        if p == 1:
            Wx[:, 0] /= np.sqrt(2)


def f3(p, x, xn):
    V = numbadelta(p, x, xn)
    return contract('ij,kl,mn', *V)


# %timeit V = f1(p, x[:2] + [np.array([0])], xn[:2] + [np.array([0])])
# %timeit V = f2(p, x[:2] + [np.array([0.])], xn[:2] + [np.array([0.])])
# %timeit V = f2(p, x, xn)
# %timeit V = f3(p, x, xn)
# Out:
# 117 µs ± 275 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# /Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py:2410: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   args = tuple(asanyarray(arg) for arg in args)
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sin'
#
#
#
# The above exception was the direct cause of the following exception:
#
#
#
# TypeError                                 Traceback (most recent call last)
#
# /Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi Hubbard tweezer array/Computation/src/random_guess_minimization.ipynb Cell 44' in <cell line: 39>()
#
#      <a href='vscode-notebook-cell:/Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/random_guess_minimization.ipynb#X61sZmlsZQ%3D%3D?line=34'>35</a>     return contract('ij,kl,mn', *V)
#
#      <a href='vscode-notebook-cell:/Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/random_guess_minimization.ipynb#X61sZmlsZQ%3D%3D?line=37'>38</a> get_ipython().run_line_magic('timeit', 'V = f1(p, x[:2] + [np.array([0])], xn[:2] + [np.array([0])])')
#
# ---> <a href='vscode-notebook-cell:/Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/random_guess_minimization.ipynb#X61sZmlsZQ%3D%3D?line=38'>39</a> get_ipython().run_line_magic('timeit', 'V = f2(p, x[:2] + [np.array([0.])], xn[:2] + [np.array([0.])])')
#
#      <a href='vscode-notebook-cell:/Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/random_guess_minimization.ipynb#X61sZmlsZQ%3D%3D?line=39'>40</a> # %timeit V = f2(p, x, xn)
#
#      <a href='vscode-notebook-cell:/Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/random_guess_minimization.ipynb#X61sZmlsZQ%3D%3D?line=40'>41</a> get_ipython().run_line_magic('timeit', 'V = f3(p, x, xn)')
#
#
#
# File ~/mambaforge/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2305, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/interactiveshell.py?line=2302'>2303</a>     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/interactiveshell.py?line=2303'>2304</a> with self.builtin_trap:
#
# -> <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/interactiveshell.py?line=2304'>2305</a>     result = fn(*args, **kwargs)
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/interactiveshell.py?line=2305'>2306</a> return result
#
#
#
# File ~/mambaforge/lib/python3.9/site-packages/IPython/core/magics/execution.py:1162, in ExecutionMagics.timeit(self, line, cell, local_ns)
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/magics/execution.py?line=1159'>1160</a> for index in range(0, 10):
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/magics/execution.py?line=1160'>1161</a>     number = 10 ** index
#
# -> <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/magics/execution.py?line=1161'>1162</a>     time_number = timer.timeit(number)
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/magics/execution.py?line=1162'>1163</a>     if time_number >= 0.2:
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/magics/execution.py?line=1163'>1164</a>         break
#
#
#
# File ~/mambaforge/lib/python3.9/site-packages/IPython/core/magics/execution.py:156, in Timer.timeit(self, number)
#
#     <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/magics/execution.py?line=153'>154</a> gc.disable()
#
#     <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/magics/execution.py?line=154'>155</a> try:
#
# --> <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/magics/execution.py?line=155'>156</a>     timing = self.inner(it, self.timer)
#
#     <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/magics/execution.py?line=156'>157</a> finally:
#
#     <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/IPython/core/magics/execution.py?line=157'>158</a>     if gcold:
#
#
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
#
#
# /Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi Hubbard tweezer array/Computation/src/random_guess_minimization.ipynb Cell 44' in f2(p, x, xn)
#
#      <a href='vscode-notebook-cell:/Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/random_guess_minimization.ipynb#X61sZmlsZQ%3D%3D?line=13'>14</a> def f2(p, x, xn):
#
#      <a href='vscode-notebook-cell:/Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/random_guess_minimization.ipynb#X61sZmlsZQ%3D%3D?line=14'>15</a>     vd = np.vectorize(delta, signature='(),(m),(n)->(m,n)')
#
# ---> <a href='vscode-notebook-cell:/Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/random_guess_minimization.ipynb#X61sZmlsZQ%3D%3D?line=15'>16</a>     V = vd(p, x, xn)
#
#      <a href='vscode-notebook-cell:/Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/random_guess_minimization.ipynb#X61sZmlsZQ%3D%3D?line=16'>17</a>     return contract('ij,kl,mn', *V)
#
#
#
# File ~/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py:2310, in vectorize.__call__(self, *args, **kwargs)
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2306'>2307</a>     vargs = [args[_i] for _i in inds]
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2307'>2308</a>     vargs.extend([kwargs[_n] for _n in names])
#
# -> <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2309'>2310</a> return self._vectorize_call(func=func, args=vargs)
#
#
#
# File ~/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py:2384, in vectorize._vectorize_call(self, func, args)
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2381'>2382</a> """Vectorized call to `func` over positional `args`."""
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2382'>2383</a> if self.signature is not None:
#
# -> <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2383'>2384</a>     res = self._vectorize_call_with_signature(func, args)
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2384'>2385</a> elif not args:
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2385'>2386</a>     res = func()
#
#
#
# File ~/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py:2424, in vectorize._vectorize_call_with_signature(self, func, args)
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2420'>2421</a> nout = len(output_core_dims)
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2422'>2423</a> for index in np.ndindex(*broadcast_shape):
#
# -> <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2423'>2424</a>     results = func(*(arg[index] for arg in args))
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2425'>2426</a>     n_results = len(results) if isinstance(results, tuple) else 1
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=2427'>2428</a>     if nout != n_results:
#
#
#
# File ~/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi Hubbard tweezer array/Computation/src/DVR/core.py:307, in delta(p, x, xn)
#
#     <a href='file:///Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/DVR/core.py?line=304'>305</a> def delta(p: int, x: np.ndarray, xn: np.ndarray) -> np.ndarray:
#
#     <a href='file:///Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/DVR/core.py?line=305'>306</a>     # Symmetrized sinc DVR basis funciton, x in unit of dx
#
# --> <a href='file:///Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/DVR/core.py?line=306'>307</a>     Wx = np.sinc(x[:, None] - xn[None])
#
#     <a href='file:///Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/DVR/core.py?line=307'>308</a>     if p != 0:
#
#     <a href='file:///Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi%20Hubbard%20tweezer%20array/Computation/src/DVR/core.py?line=308'>309</a>         Wx += p * np.sinc(x[:, None] + xn[None])
#
#
#
# File <__array_function__ internals>:180, in sinc(*args, **kwargs)
#
#
#
# File ~/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py:3621, in sinc(x)
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=3618'>3619</a> x = np.asanyarray(x)
#
#    <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=3619'>3620</a> y = pi * where(x == 0, 1.0e-20, x)
#
# -> <a href='file:///Users/nottforestfc/mambaforge/lib/python3.9/site-packages/numpy/lib/function_base.py?line=3620'>3621</a> return sin(y)/y
#
#
#
# TypeError: loop of ufunc does not support argument 0 of type numpy.ndarray which has no callable sin method
