# %% [markdown]
# # Lattice geometries

# %%
import matplotlib.pyplot as plt
from Hubbard_core import *
import numpy as np
from positify import positify

N = 20
R0 = np.array([3, 3, 7.2])
dvr = MLWF(N,
           R0=R0,
           lattice=np.array([2, 2], dtype=int),
           band=1,
           dim=3,
           avg=1 / 2,
           sparse=True,
           symmetry=True)

x = np.linspace(-dvr.R0[0] * 0.8, dvr.R0[0] * 0.8, 500)
X = np.meshgrid(x, x)
V = dvr.Vfun(*X, 0)

plt.pcolormesh(*X, V)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1000nm
# Triangular size adjust to: [2 2]
# lattice: dx is fixed at: [0.15 0.15 0.36]w
# lattice: lattice shape is square
# lattice: Full lattice sizes: [2 2 1]
# lattice: lattice constants: [1.52 1.69 1.52]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[25 25 20] is set.
# DVR: R0=[3.76  3.845 7.2  ]w is set.

# %%
import matplotlib.pyplot as plt
from Hubbard_core import *
import numpy as np
from positify import positify

N = 20
R0 = np.array([3, 3, 7.2])
W = MLWF(N,
           R0=R0,
           lattice=np.array([9, 9], dtype=int),
           band=1,
           dim=3,
           avg=1 / 2,
           shape='Lieb',
           sparse=True,
           symmetry=True)

x = np.linspace(-W.R0[0] * 0.8, W.R0[0] * 0.8, 500)
X = np.meshgrid(x, x)
V = W.Vfun(*X, 0)

plt.pcolormesh(*X, V)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1000nm
# Lieb size adjust to: [9 9]
# Triangular size adjust to: [9 9]
# lattice: dx is fixed at: [0.15 0.15 0.36]w
# lattice: lattice shape is Lieb
# lattice: Full lattice sizes: [9 9 1]
# lattice: lattice constants: [1.52 1.69 1.52]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[60 65 20] is set.
# DVR: R0=[9.08 9.76 7.2 ]w is set.

# %%
import matplotlib.pyplot as plt
from Hubbard_core import *
import numpy as np
from positify import positify

N = 20
R0 = np.array([3, 3, 7.2])
W = MLWF(N,
           R0=R0,
           lattice=np.array([5, 5], dtype=int),
           lc=2000,
           trap=(50, 1000),
           band=1,
           dim=3,
           avg=1 / 2,
           shape='triangular',
           sparse=True,
           symmetry=True)

x = np.linspace(-W.R0[0] * 0.8, W.R0[0] * 0.8, 500)
X = np.meshgrid(x, x)
V = W.Vfun(*X, 0)

plt.pcolormesh(*X, V)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=50kHz w=1000nm
# lattice: dx is fixed at: [0.15 0.15 0.36]w
# lattice: lattice shape is triangular
# lattice: Full lattice sizes: [5 5 1]
# lattice: lattice constants: [2.         1.73205081 2.        ]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[46 43 20] is set.
# DVR: R0=[7.         6.46410162 7.2       ]w is set.

# %%
import matplotlib.pyplot as plt
from Hubbard_core import *
import numpy as np
from positify import positify

N = 20
R0 = np.array([3, 3, 7.2])
W = MLWF(N,
           R0=R0,
           lattice=np.array([9, 9], dtype=int),
           lc=2000,
           trap=(50, 1000),
           band=1,
           dim=3,
           avg=1 / 2,
           shape='honeycomb',
           sparse=True,
           symmetry=True)

x = np.linspace(-W.R0[0] * 0.8, W.R0[0] * 0.8, 500)
X = np.meshgrid(x, x)
V = W.Vfun(*X, 0)

plt.pcolormesh(*X, V)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=50kHz w=1000nm
# Honeycomb lattice size adjust to: [9 9]
# lattice: dx is fixed at: [0.15 0.15 0.36]w
# lattice: lattice shape is honeycomb
# lattice: Full lattice sizes: [9 9 1]
# lattice: lattice constants: [2. 2. 2.]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[73 73 20] is set.
# DVR: R0=[11.  11.   7.2]w is set.

# %%
import matplotlib.pyplot as plt
from Hubbard_core import *
import numpy as np
from positify import positify

N = 20
R0 = np.array([3, 3, 7.2])
W = MLWF(N,
           R0=R0,
           lattice=np.array([9, 9], dtype=int),
           lc=2000,
           trap=(50, 1000),
           band=1,
           dim=3,
           avg=1 / 2,
           shape='kagome',
           sparse=True,
           symmetry=True)

x = np.linspace(-W.R0[0] * 0.8, W.R0[0] * 0.8, 500)
X = np.meshgrid(x, x)
V = W.Vfun(*X, 0)

plt.pcolormesh(*X, V)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=50kHz w=1000nm
# Kagome lattice size adjust to: [10  9]
# lattice: dx is fixed at: [0.15 0.15 0.36]w
# lattice: lattice shape is kagome
# lattice: Full lattice sizes: [9 9 1]
# lattice: lattice constants: [2.         1.73205081 2.        ]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[73 66 20] is set.
# DVR: R0=[11.          9.92820323  7.2       ]w is set.
