# %% [markdown]
# # Sinc DVR dynamics for 3D teweezer potential

# %%
# Directives on Jupyter
# %reset
# Auto reload bootstrap.py
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Full diagonalization

# %%
from DVR3d_full import *
import matplotlib.pyplot as plt

Nmax = 8
# WARNING: do not run N >40 on PC
N, dE, E1 = N_convergence(range(1, Nmax + 1), R0)

f = plt.figure(figsize=(20, 6))
ax1 = f.add_subplot(1, 2, 1)
for i in range(k):
    ax1.semilogy(N[1:], abs(dE[:, i]))
ax1.set_xlabel('$N$')
ax1.set_ylabel('$\Delta E/V_0$')
ax1.set_title(
    'Convergence of energies vs N for 3D tweezer potential, fixing R = {} w'.
    format(R0[0] / w))

# %% [markdown]
# ## TO-DO:
#
# <!-- 1. Calculate ground state of time-average potential $T+V/2$ -->
# 2. Consider effect of gravity and others
#
# ## 2D test

# %%
import numpy as np
from dynamics import *
import matplotlib.pyplot as plt
from dynamics_sho_classical import *
from opt_einsum import contract
from einops import rearrange, reduce, repeat

T = 10
t_step = T / 20
n = np.array([30, 30, 0])
dx = 1/3 * np.ones(3, dtype=float)
x0 = np.array([0.5, 0.25, 0])
t_list = np.arange(0 * T, 2 * T, t_step)
x_vs_t = np.array([]).reshape(0, 4)

psi0 = coherent_state(n, dx, np.zeros(3))
peak_pos = np.zeros(3, dtype=float)

def firstfun(x, y, z):
    return shftdVfun(x, y, z, x0)

def lastfun(x, y, z):
    return shftdVfun(x, y, z, -x0)

E1, W1 = H_solver(n, dx, potential=firstfun, model='sho')
E2, W2 = H_solver(n, dx, potential=lastfun, model='sho')
E_lsit = [E1, E2]
W_list = [W1, W2]

def psi(x, psi1):
    xn = [np.arange(-n[i], n[i]+1) * dx[i] for i in range(3)]

    def f(x, xn, dx):
        if xn.size == 1:
            return np.ones((1, 1))
        else:
            return 1/np.sqrt(dx) * np.sinc((np.array([x])[:, None] - xn[None])/dx)

    f3d = contract('ij,kl,mn->ikmjln', f(x[0], xn[0], dx[0]),
                    f(x[1], xn[1], dx[1]), f(x[2], xn[2], dx[2]))
    f3d = rearrange(f3d, 'i k m j l n -> i k m (j l n)')
    psi_x = f3d @ psi1
    return psi_x

psi1 = psi0
for t in t_list:
    def target(x): return -abs(psi(x, psi1))
    peak_pos = fmin(target, peak_pos, disp=False)
    x_vs_t = np.append(x_vs_t, np.insert(
        peak_pos[:], 0, t)[None, :], axis=0)
    psi1 = wavepocket_dynamics(psi1, t, t_step, T, E_lsit, W_list)
sol = ODE_solver(T, t_list, t_step, x0)

f = plt.figure(figsize=(10, 6))
coord = ['x', 'y', 'z']
for i in range(3):
    if n[i] > 0:
        plt.plot(x_vs_t[:, 0], x_vs_t[:, i+1],
                    label='quantum {}'.format(coord[i]))
        plt.plot(sol.t, sol.y[i, :], label='classical {}'.format(coord[i]))
plt.title(
    'Wave packet peak trace x vs t w/ T={:.3g}, $\Delta t$={:.3g}, $\omega$={}, $|x_0|$={}, $\Delta x$={:.3g}, R={:g}'.format(T, t_step, w, x0, dx[0], n[0] * dx[0]))
plt.xlabel('t')
plt.ylabel('x')
plt.legend()
# Out:
# H_mat: model is harmonic potential.
# H_mat: model is harmonic potential.
# H_mat: model is harmonic potential.

# %%
import numpy as np
from dynamics import *
import matplotlib.pyplot as plt
from dynamics_sho_classical import *
from opt_einsum import contract
from einops import rearrange, reduce, repeat
from scipy.optimize import fmin


def run():
    T = 10
    t_step = T / 80
    n = np.array([30, 0, 0])
    dx = 1/3 * np.ones(3, dtype=float)
    x0 = np.array([0.5, 0.25, 0])
    t_list = np.arange(0 * T, 2 * T, t_step)
    x_vs_t = np.array([]).reshape(0, 4)

    psi0 = coherent_state(n, dx, np.zeros(3))
    peak_pos = np.zeros(3, dtype=float)

    def firstfun(x, y, z):
        return shftdVfun(x, y, z, x0)

    def lastfun(x, y, z):
        return shftdVfun(x, y, z, -x0)

    E1, W1 = H_solver(n, dx, potential=firstfun, model='sho')
    E2, W2 = H_solver(n, dx, potential=lastfun, model='sho')
    E_lsit = [E1, E2]
    W_list = [W1, W2]

    def psi(x, psi1):
        xn = [np.arange(-n[i], n[i]+1) * dx[i] for i in range(3)]

        def f(x, xn, dx):
            if xn.size == 1:
                return np.ones((1, 1))
            else:
                return 1/np.sqrt(dx) * np.sinc((np.array([x])[:, None] - xn[None])/dx)

        f3d = contract('ij,kl,mn->ikmjln', f(x[0], xn[0], dx[0]),
                        f(x[1], xn[1], dx[1]), f(x[2], xn[2], dx[2]))
        f3d = rearrange(f3d, 'i k m j l n -> i k m (j l n)')
        psi_x = f3d @ psi1
        return psi_x

    psi1 = psi0
    for t in t_list:
        def target(x): return -abs(psi(x, psi1))
        peak_pos = fmin(target, peak_pos, disp=False)
        x_vs_t = np.append(x_vs_t, np.insert(
            peak_pos[:], 0, t)[None, :], axis=0)
        psi1 = wavepocket_dynamics(psi1, t, t_step, T, E_lsit, W_list)
    sol = ODE_solver(T, t_list, t_step, x0)

    f = plt.figure(figsize=(10, 6))
    coord = ['x', 'y', 'z']
    for i in range(3):
        if n[i] > 0:
            plt.plot(x_vs_t[:, 0], x_vs_t[:, i+1],
                        label='quantum {}'.format(coord[i]))
            plt.plot(sol.t, sol.y[i, :], label='classical {}'.format(coord[i]))
    plt.title(
        'Wave packet peak trace x vs t w/ T={:.3g}, $\Delta t$={:.3g}, $\omega$={}, $|x_0|$={}, $\Delta x$={:.3g}, R={:g}'.format(T, t_step, w, x0, dx[0], n[0] * dx[0]))
    plt.xlabel('t')
    plt.ylabel('x')
    plt.legend()


# %prun run()
# Out:
# H_mat: model is harmonic potential.
# H_mat: model is harmonic potential.
# H_mat: model is harmonic potential.
#          4136519 function calls (4081489 primitive calls) in 2.676 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      8976    0.202    0.000    1.292    0.000 contract.py:93(contract_path)
#      8976    0.124    0.000    0.155    0.000 paths.py:63(ssa_to_linear)
#       160    0.117    0.001    2.428    0.015 optimize.py:593(_minimize_neldermead)
# 53856/8976    0.113    0.000    0.262    0.000 paths.py:190(_optimal_iterate)
# 88157/78673    0.094    0.000    0.331    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       320    0.091    0.000    0.094    0.000 dynamics.py:27(int_evo_ops)
#     26901    0.087    0.000    0.237    0.000 237774272.py:36(f)
#     53856    0.082    0.000    0.143    0.000 paths.py:100(calc_k12_flops)
#      8967    0.079    0.000    0.114    0.000 237774272.py:34(<listcomp>)
#       160    0.076    0.000    0.170    0.001 dynamics.py:192(coherent_state_dynamics)
#      8967    0.070    0.000    2.147    0.000 237774272.py:33(psi)
#    107712    0.069    0.000    0.193    0.000 parser.py:154(<genexpr>)
#     17952    0.065    0.000    0.065    0.000 {built-in method numpy.core._multiarray_umath.c_einsum}
#     17952    0.064    0.000    0.095    0.000 blas.py:12(can_blas)
#    179544    0.058    0.000    0.085    0.000 {built-in method builtins.max}
#    134640    0.051    0.000    0.051    0.000 helpers.py:53(compute_size_by_dict)
#      8967    0.049    0.000    0.081    0.000 function_base.py:3399(sinc)
#      8976    0.047    0.000    1.639    0.000 contract.py:378(contract)
#     35898    0.047    0.000    0.047    0.000 {built-in method numpy.arange}
#     17952    0.046    0.000    0.239    0.000 parser.py:141(find_output_shape)
#      8976    0.038    0.000    0.291    0.000 contract.py:530(_core_contract)
#    206492    0.036    0.000    0.036    0.000 {method 'count' of 'str' objects}
#     17952    0.035    0.000    0.065    0.000 helpers.py:82(find_contraction)
#      8976    0.033    0.000    0.066    0.000 parser.py:246(parse_einsum_input)
#      8976    0.032    0.000    0.451    0.000 paths.py:152(optimal)
#     80784    0.032    0.000    0.083    0.000 helpers.py:137(flop_count)
#     89760    0.032    0.000    0.060    0.000 parser.py:155(<listcomp>)
# 397232/397231    0.028    0.000    0.028    0.000 {built-in method builtins.len}
#    179520    0.028    0.000    0.028    0.000 {method 'find' of 'str' objects}
#    179520    0.027    0.000    0.027    0.000 parser.py:155(<genexpr>)
#     17952    0.027    0.000    0.197    0.000 contract.py:333(_einsum)
#      9242    0.025    0.000    0.025    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     17964    0.024    0.000    0.046    0.000 {built-in method builtins.all}
#     54015    0.023    0.000    0.023    0.000 {built-in method builtins.sorted}
#    233376    0.022    0.000    0.022    0.000 parser.py:21(is_valid_einsum_char)
#      8967    0.019    0.000    0.064    0.000 einops.py:202(apply)
#     18853    0.018    0.000    0.018    0.000 {built-in method numpy.array}
#    162894    0.017    0.000    0.017    0.000 {method 'append' of 'list' objects}
#    143625    0.015    0.000    0.015    0.000 {method 'pop' of 'list' objects}
#      9746    0.014    0.000    0.014    0.000 {built-in method builtins.abs}
#     53856    0.014    0.000    0.014    0.000 paths.py:74(<genexpr>)
#         3    0.013    0.004    0.013    0.004 linalg.py:1336(eigh)
#      8967    0.012    0.000    2.204    0.000 optimize.py:462(function_wrapper)
#      8967    0.012    0.000    0.081    0.000 einops.py:327(reduce)
#     17979    0.012    0.000    0.012    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     17935    0.012    0.000    0.050    0.000 numeric.py:149(ones)
#     17952    0.011    0.000    0.218    0.000 sharing.py:148(cached_einsum)
#     53856    0.011    0.000    0.016    0.000 helpers.py:126(<genexpr>)
#    125987    0.011    0.000    0.011    0.000 {method 'pop' of 'dict' objects}
#      8967    0.010    0.000    2.171    0.000 237774272.py:50(target)
#     53856    0.010    0.000    0.010    0.000 {method 'union' of 'frozenset' objects}
#      8976    0.009    0.000    0.020    0.000 contract.py:244(<listcomp>)
#     89760    0.009    0.000    0.009    0.000 einsumfunc.py:989(_einsum_dispatcher)
#     35944    0.009    0.000    0.009    0.000 {method 'split' of 'str' objects}
#     71192    0.009    0.000    0.009    0.000 {built-in method builtins.isinstance}
#     17937    0.008    0.000    0.032    0.000 <__array_function__ internals>:2(copyto)
#     17954    0.008    0.000    0.017    0.000 {built-in method builtins.sum}
#      4521    0.008    0.000    0.008    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#      9042    0.008    0.000    0.008    0.000 {method 'take' of 'numpy.ndarray' objects}
#     17952    0.008    0.000    0.012    0.000 contract.py:289(<listcomp>)
#      8976    0.008    0.000    0.461    0.000 paths.py:1072(auto)
#     17952    0.008    0.000    0.110    0.000 <__array_function__ internals>:2(einsum)
#     35904    0.008    0.000    0.008    0.000 {method 'union' of 'set' objects}
#     17952    0.007    0.000    0.011    0.000 contract.py:552(<listcomp>)
#     35904    0.007    0.000    0.009    0.000 contract.py:253(<genexpr>)
#      8976    0.007    0.000    0.009    0.000 contract.py:510(infer_backend)
#      4875    0.007    0.000    0.024    0.000 fromnumeric.py:69(_wrapreduction)
#     18416    0.007    0.000    0.007    0.000 {built-in method numpy.empty}
#      8976    0.007    0.000    0.017    0.000 contract.py:514(parse_backend)
#      8976    0.007    0.000    0.017    0.000 parser.py:277(<listcomp>)
#      8976    0.007    0.000    0.007    0.000 contract.py:214(<listcomp>)
#     17952    0.007    0.000    0.010    0.000 sharing.py:23(currently_sharing)
#      8967    0.007    0.000    0.090    0.000 einops.py:393(rearrange)
#     17952    0.007    0.000    0.010    0.000 contract.py:290(<listcomp>)
#     17952    0.007    0.000    0.052    0.000 parser.py:35(has_valid_einsum_chars_only)
#      8967    0.006    0.000    0.011    0.000 _backends.py:22(get_backend)
#     13585    0.006    0.000    0.024    0.000 fromnumeric.py:51(_wrapfunc)
#     26928    0.006    0.000    0.010    0.000 parser.py:158(possibly_convert_to_numpy)
#      8967    0.006    0.000    0.008    0.000 einops.py:26(_reduce_axes)
#     35921    0.006    0.000    0.006    0.000 {method 'join' of 'str' objects}
#     17952    0.005    0.000    0.070    0.000 einsumfunc.py:997(einsum)
#       160    0.005    0.000    0.175    0.001 dynamics.py:209(wavepocket_dynamics)
#     17934    0.005    0.000    0.017    0.000 _backends.py:83(reshape)
#      8967    0.005    0.000    0.092    0.000 <__array_function__ internals>:2(sinc)
#      8967    0.005    0.000    0.021    0.000 <__array_function__ internals>:2(copy)
#      4682    0.004    0.000    0.027    0.000 fromnumeric.py:2638(amax)
#      9042    0.004    0.000    0.017    0.000 fromnumeric.py:93(take)
#      9130    0.004    0.000    0.004    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#     17954    0.004    0.000    0.004    0.000 dispatch.py:60(get_func)
#     42588    0.004    0.000    0.004    0.000 {method 'items' of 'dict' objects}
#       163    0.004    0.000    0.013    0.000 rk.py:14(rk_step)
#      8967    0.004    0.000    0.030    0.000 <__array_function__ internals>:2(where)
#     27013    0.004    0.000    0.004    0.000 {built-in method builtins.hasattr}
#      9042    0.004    0.000    0.025    0.000 <__array_function__ internals>:2(take)
#      4521    0.004    0.000    0.008    0.000 fromnumeric.py:1718(ravel)
#     17953    0.004    0.000    0.004    0.000 {method 'replace' of 'str' objects}
#      8976    0.004    0.000    0.004    0.000 contract.py:218(<listcomp>)
#      4521    0.003    0.000    0.015    0.000 fromnumeric.py:1006(argsort)
#      8967    0.003    0.000    0.004    0.000 _backends.py:147(is_appropriate_type)
#      4875    0.003    0.000    0.003    0.000 fromnumeric.py:70(<dictcomp>)
#     17953    0.003    0.000    0.003    0.000 {built-in method _thread.get_ident}
#      4521    0.003    0.000    0.020    0.000 <__array_function__ internals>:2(argsort)
#         1    0.003    0.003    2.676    2.676 237774272.py:10(run)
#      8967    0.003    0.000    0.011    0.000 function_base.py:726(copy)
#      8976    0.002    0.000    0.002    0.000 paths.py:1122(get_path_fn)
#      8976    0.002    0.000    0.002    0.000 contract.py:74(_choose_memory_arg)
#     13864    0.002    0.000    0.002    0.000 {built-in method numpy.asanyarray}
#       160    0.002    0.000    0.005    0.000 function_base.py:4567(insert)
#      8967    0.002    0.000    0.007    0.000 _backends.py:86(transpose)
#      4682    0.002    0.000    0.032    0.000 <__array_function__ internals>:2(amax)
#      4707    0.002    0.000    0.002    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      4521    0.002    0.000    0.012    0.000 <__array_function__ internals>:2(ravel)
#     14547    0.002    0.000    0.002    0.000 {built-in method builtins.getattr}
#      8967    0.002    0.000    0.002    0.000 _backends.py:79(shape)
#     17937    0.002    0.000    0.002    0.000 multiarray.py:1071(copyto)
#       980    0.002    0.000    0.005    0.000 dynamics_sho_classical.py:29(EoM)
#      8976    0.002    0.000    0.002    0.000 contract.py:475(<dictcomp>)
#      8976    0.002    0.000    0.002    0.000 dispatch.py:94(has_tensordot)
#      1162    0.002    0.000    0.002    0.000 {built-in method numpy.zeros}
#       163    0.002    0.000    0.017    0.000 rk.py:111(_step_impl)
#       160    0.002    0.000    2.430    0.015 optimize.py:469(fmin)
#       169    0.002    0.000    0.003    0.000 twodim_base.py:161(eye)
#         1    0.002    0.002    0.007    0.007 font_manager.py:1311(_findfont_cached)
#       980    0.002    0.000    0.002    0.000 dynamics_sho_classical.py:8(force)
#     10418    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#      8967    0.001    0.000    0.001    0.000 multiarray.py:341(where)
#       386    0.001    0.000    0.001    0.000 font_manager.py:1188(score_stretch)
#      8967    0.001    0.000    0.001    0.000 function_base.py:722(_copy_dispatcher)
#      8976    0.001    0.000    0.001    0.000 dispatch.py:76(has_einsum)
#      8967    0.001    0.000    0.001    0.000 function_base.py:3395(_sinc_dispatcher)
#      9042    0.001    0.000    0.001    0.000 fromnumeric.py:89(_take_dispatcher)
#      8976    0.001    0.000    0.001    0.000 contract.py:489(<listcomp>)
#      9203    0.001    0.000    0.001    0.000 {built-in method builtins.callable}
#       386    0.001    0.000    0.002    0.000 font_manager.py:1130(score_family)
#         3    0.001    0.000    0.008    0.003 DVR3d_full.py:137(H_mat)
#       160    0.001    0.000    0.002    0.000 type_check.py:84(asfarray)
#       980    0.001    0.000    0.003    0.000 dynamics_sho_classical.py:12(f)
#       320    0.001    0.000    0.001    0.000 numeric.py:1335(normalize_axis_tuple)
#       160    0.001    0.000    0.002    0.000 numeric.py:1398(moveaxis)
#      1628    0.001    0.000    0.001    0.000 {built-in method numpy.asarray}
#      4521    0.001    0.000    0.001    0.000 fromnumeric.py:1002(_argsort_dispatcher)
#         7    0.001    0.000    0.001    0.000 socket.py:480(send)
#      2159    0.001    0.000    0.001    0.000 __init__.py:653(__getitem__)
#      4521    0.001    0.000    0.001    0.000 fromnumeric.py:1714(_ravel_dispatcher)
#      4682    0.001    0.000    0.001    0.000 fromnumeric.py:2633(_amax_dispatcher)
#       160    0.001    0.000    0.001    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#      1323    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(dot)
# 1445/1217    0.000    0.000    0.001    0.000 artist.py:290(stale)
#       166    0.000    0.000    0.002    0.000 artist.py:1046(update)
#       166    0.000    0.000    0.001    0.000 linalg.py:2363(norm)
#       177    0.000    0.000    0.001    0.000 __init__.py:1691(normalize_kwargs)
#       160    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(asfarray)
#       386    0.000    0.000    0.001    0.000 font_manager.py:1206(score_weight)
#       980    0.000    0.000    0.006    0.000 base.py:136(fun)
#       163    0.000    0.000    0.001    0.000 numerictypes.py:358(issubdtype)
#        72    0.000    0.000    0.001    0.000 artist.py:149(__init__)
#       500    0.000    0.000    0.001    0.000 dynamics_sho_classical.py:16(firstfun)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#       980    0.000    0.000    0.006    0.000 base.py:19(fun_wrapped)
#       163    0.000    0.000    0.001    0.000 rk.py:105(_estimate_error)
#         3    0.000    0.000    0.000    0.000 DVR3d_full.py:73(kinetic_offdiag)
#       326    0.000    0.000    0.001    0.000 numerictypes.py:284(issubclass_)
#       332    0.000    0.000    0.000    0.000 __init__.py:2014(_setattr_cm)
#       348    0.000    0.000    0.000    0.000 __init__.py:276(process)
#       480    0.000    0.000    0.001    0.000 dynamics_sho_classical.py:19(lastfun)
#         3    0.000    0.000    0.001    0.000 DVR3d_full.py:79(Tmat_1d)
#        22    0.000    0.000    0.002    0.000 lines.py:276(__init__)
#       911    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       177    0.000    0.000    0.000    0.000 __init__.py:1730(<dictcomp>)
#       980    0.000    0.000    0.005    0.000 dynamics_sho_classical.py:37(dydt)
#      2159    0.000    0.000    0.000    0.000 {function RcParams.__getitem__ at 0x7f85a87950d0}
#        61    0.000    0.000    0.001    0.000 font_manager.py:658(__init__)
#       160    0.000    0.000    0.001    0.000 function_base.py:4762(append)
#       160    0.000    0.000    0.000    0.000 optimize.py:454(_wrap_function)
#       890    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#    132/14    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#       163    0.000    0.000    0.017    0.000 base.py:159(step)
#       386    0.000    0.000    0.000    0.000 font_manager.py:1122(_expand_aliases)
#       191    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(concatenate)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2776(__init__)
#         1    0.000    0.000    0.017    0.017 ivp.py:156(solve_ivp)
#         3    0.000    0.000    0.001    0.000 DVR3d_full.py:55(Vmat)
#       890    0.000    0.000    0.001    0.000 abc.py:96(__instancecheck__)
#       163    0.000    0.000    0.002    0.000 rk.py:108(_estimate_error_norm)
#       166    0.000    0.000    0.001    0.000 common.py:59(norm)
#       161    0.000    0.000    0.001    0.000 fromnumeric.py:2763(amin)
#       123    0.000    0.000    0.000    0.000 transforms.py:207(set_children)
#       320    0.000    0.000    0.000    0.000 numeric.py:1385(<listcomp>)
#         9    0.000    0.000    0.000    0.000 stride_tricks.py:339(_broadcast_to)
#         3    0.000    0.000    0.004    0.001 DVR3d_full.py:94(Tmat)
#       160    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(moveaxis)
#       160    0.000    0.000    0.006    0.000 <__array_function__ internals>:2(insert)
#       379    0.000    0.000    0.000    0.000 __init__.py:101(check_in_list)
#      1445    0.000    0.000    0.000    0.000 artist.py:832(get_animated)
#         8    0.000    0.000    0.000    0.000 __init__.py:119(_weak_or_strong_ref)
#       336    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#       410    0.000    0.000    0.000    0.000 __init__.py:1799(_str_equal)
#       161    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(amin)
#       345    0.000    0.000    0.000    0.000 artist.py:405(pchanged)
#         6    0.000    0.000    0.004    0.001 axis.py:57(__init__)
#       163    0.000    0.000    0.000    0.000 {method 'conj' of 'numpy.ndarray' objects}
#       166    0.000    0.000    0.000    0.000 contextlib.py:82(__init__)
#        64    0.000    0.000    0.000    0.000 font_manager.py:826(set_weight)
#       388    0.000    0.000    0.000    0.000 __init__.py:1424(debug)
#      1323    0.000    0.000    0.000    0.000 multiarray.py:736(dot)
#       127    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.001    0.000 axis.py:349(_apply_params)
#       160    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(append)
#    150/69    0.000    0.000    0.000    0.000 transforms.py:180(_invalidate_internal)
#        70    0.000    0.000    0.001    0.000 text.py:162(update)
#        16    0.000    0.000    0.000    0.000 pathlib.py:64(parse_parts)
#       190    0.000    0.000    0.000    0.000 artist.py:81(_stale_axes_callback)
#        22    0.000    0.000    0.002    0.000 text.py:115(__init__)
#        16    0.000    0.000    0.000    0.000 function_base.py:1164(diff)
#       160    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#       802    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#       255    0.000    0.000    0.000    0.000 transforms.py:107(__init__)
#       388    0.000    0.000    0.000    0.000 __init__.py:1689(isEnabledFor)
#        36    0.000    0.000    0.001    0.000 markers.py:295(_set_marker)
#        32    0.000    0.000    0.000    0.000 axis.py:1607(_set_formatter)
#       166    0.000    0.000    0.000    0.000 contextlib.py:117(__exit__)
#        91    0.000    0.000    0.000    0.000 colors.py:152(to_rgba)
#        46    0.000    0.000    0.000    0.000 font_manager.py:710(__hash__)
#       356    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        61    0.000    0.000    0.000    0.000 font_manager.py:844(set_stretch)
#        16    0.000    0.000    0.000    0.000 ticker.py:1986(_validate_steps)
#        16    0.000    0.000    0.008    0.000 ticker.py:433(__init__)
#         1    0.000    0.000    0.000    0.000 shape_base.py:81(atleast_2d)
#       105    0.000    0.000    0.002    0.000 artist.py:1159(set)
#       160    0.000    0.000    0.000    0.000 optimize.py:145(_check_unknown_options)
#       134    0.000    0.000    0.000    0.000 transforms.py:1783(__init__)
#         8    0.000    0.000    0.000    0.000 lines.py:649(recache)
#        91    0.000    0.000    0.000    0.000 __init__.py:65(check_isinstance)
#       166    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(norm)
#        15    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       322    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#        91    0.000    0.000    0.000    0.000 __init__.py:184(__init__)
#       168    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#       166    0.000    0.000    0.000    0.000 contextlib.py:238(helper)
#       166    0.000    0.000    0.000    0.000 contextlib.py:108(__enter__)
#        79    0.000    0.000    0.000    0.000 font_manager.py:862(set_size)
#       137    0.000    0.000    0.000    0.000 colors.py:106(_is_nth_color)
#       142    0.000    0.000    0.000    0.000 re.py:289(_compile)
#        38    0.000    0.000    0.000    0.000 transforms.py:767(__init__)
#        70    0.000    0.000    0.000    0.000 markers.py:237(_recache)
#        54    0.000    0.000    0.000    0.000 transforms.py:2351(__init__)
#        12    0.000    0.000    0.000    0.000 __init__.py:132(check_shape)
#       164    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        11    0.000    0.000    0.000    0.000 stride_tricks.py:414(_broadcast_shape)
#        18    0.000    0.000    0.001    0.000 artist.py:759(set_clip_path)
#        12    0.000    0.000    0.000    0.000 cycler.py:165(keys)
#       160    0.000    0.000    0.000    0.000 type_check.py:80(_asfarray_dispatcher)
#       386    0.000    0.000    0.000    0.000 font_manager.py:1224(score_size)
#       138    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#        12    0.000    0.000    0.000    0.000 {built-in method posix.lstat}
#       138    0.000    0.000    0.000    0.000 re.py:188(match)
#       386    0.000    0.000    0.000    0.000 font_manager.py:1160(score_style)
#         7    0.000    0.000    0.001    0.000 patches.py:59(__init__)
#        66    0.000    0.000    0.000    0.000 lines.py:1149(_set_markercolor)
#       568    0.000    0.000    0.000    0.000 artist.py:266(axes)
#     28/24    0.000    0.000    0.000    0.000 spines.py:330(get_spine_transform)
#        73    0.000    0.000    0.000    0.000 artist.py:723(set_figure)
#        16    0.000    0.000    0.001    0.000 ticker.py:2007(set_params)
#       432    0.000    0.000    0.000    0.000 font_manager.py:739(get_style)
#        22    0.000    0.000    0.000    0.000 lines.py:1087(set_linestyle)
#       386    0.000    0.000    0.000    0.000 font_manager.py:1177(score_variant)
#       432    0.000    0.000    0.000    0.000 font_manager.py:761(get_stretch)
#       432    0.000    0.000    0.000    0.000 font_manager.py:746(get_variant)
#         1    0.000    0.000    0.001    0.001 figure.py:2154(__init__)
#       432    0.000    0.000    0.000    0.000 font_manager.py:727(get_family)
#        16    0.000    0.000    0.009    0.001 scale.py:104(set_default_locators_and_formatters)
#       432    0.000    0.000    0.000    0.000 font_manager.py:752(get_weight)
#         1    0.000    0.000    0.008    0.008 _base.py:1182(cla)
#       386    0.000    0.000    0.000    0.000 font_manager.py:769(get_size)
#         3    0.000    0.000    0.000    0.000 dynamics.py:188(shftdVfun)
#        39    0.000    0.000    0.000    0.000 transforms.py:1900(__init__)
#         1    0.000    0.000    0.002    0.002 legend.py:296(__init__)
#       105    0.000    0.000    0.002    0.000 artist.py:116(<lambda>)
#        74    0.000    0.000    0.000    0.000 artist.py:1001(set_visible)
#        59    0.000    0.000    0.000    0.000 transforms.py:2508(composite_transform_factory)
#        16    0.000    0.000    0.000    0.000 ticker.py:2001(_staircase)
#         3    0.000    0.000    0.000    0.000 DVR3d_full.py:49(Vsho)
#        61    0.000    0.000    0.000    0.000 font_manager.py:807(set_style)
#       160    0.000    0.000    0.000    0.000 numeric.py:1460(<listcomp>)
#         1    0.000    0.000    0.000    0.000 einops.py:214(_prepare_transformation_recipe)
#        16    0.000    0.000    0.007    0.000 font_manager.py:1248(findfont)
#        10    0.000    0.000    0.000    0.000 cycler.py:364(by_key)
#        16    0.000    0.000    0.001    0.000 patches.py:747(get_patch_transform)
#         1    0.000    0.000    0.000    0.000 base.py:115(__init__)
#       108    0.000    0.000    0.000    0.000 enum.py:313(__call__)
#         1    0.000    0.000    0.019    0.019 _base.py:553(__init__)
#       249    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#      12/6    0.000    0.000    0.000    0.000 units.py:181(get_converter)
#        11    0.000    0.000    0.000    0.000 stride_tricks.py:478(broadcast_arrays)
#        61    0.000    0.000    0.000    0.000 font_manager.py:817(set_variant)
#       172    0.000    0.000    0.000    0.000 linalg.py:112(isComplexType)
#        16    0.000    0.000    0.000    0.000 axis.py:1633(set_major_locator)
#        32    0.000    0.000    0.000    0.000 transforms.py:2044(translate)
#         7    0.000    0.000    0.001    0.000 iostream.py:206(schedule)
#        12    0.000    0.000    0.009    0.001 axis.py:790(clear)
#         2    0.000    0.000    0.000    0.000 function_base.py:23(linspace)
#         1    0.000    0.000    0.000    0.000 common.py:64(select_initial_step)
#        16    0.000    0.000    0.000    0.000 pathlib.py:658(_parse_args)
#        69    0.000    0.000    0.000    0.000 transforms.py:170(invalidate)
#         1    0.000    0.000    0.018    0.018 dynamics_sho_classical.py:36(ODE_solver)
#         1    0.000    0.000    0.000    0.000 rk.py:85(__init__)
#       419    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        60    0.000    0.000    0.000    0.000 artist.py:426(set_transform)
#        16    0.000    0.000    0.009    0.001 axis.py:759(_set_scale)
#         8    0.000    0.000    0.004    0.001 axis.py:850(set_tick_params)
#        24    0.000    0.000    0.000    0.000 text.py:936(set_color)
#       191    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#        19    0.000    0.000    0.000    0.000 transforms.py:1100(__init__)
#       192    0.000    0.000    0.000    0.000 {built-in method sys.intern}
#        13    0.000    0.000    0.000    0.000 transforms.py:2057(scale)
#         2    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.update_path_extents}
#        36    0.000    0.000    0.000    0.000 markers.py:266(_set_fillstyle)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:493(_parse)
#         1    0.000    0.000    0.001    0.001 legend.py:716(_init_legend_box)
#        16    0.000    0.000    0.000    0.000 axis.py:1649(set_minor_locator)
#        22    0.000    0.000    0.000    0.000 fromnumeric.py:38(_wrapit)
#         6    0.000    0.000    0.001    0.000 iostream.py:500(write)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:896(fillFormat)
#       160    0.000    0.000    0.000    0.000 function_base.py:4758(_append_dispatcher)
#        36    0.000    0.000    0.001    0.000 markers.py:219(__init__)
#        16    0.000    0.000    0.000    0.000 transforms.py:1996(rotate)
#        39    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        40    0.000    0.000    0.000    0.000 lines.py:630(set_data)
#        23    0.000    0.000    0.000    0.000 text.py:241(set_rotation_mode)
#        39    0.000    0.000    0.000    0.000 text.py:1195(set_verticalalignment)
#       112    0.000    0.000    0.000    0.000 cycler.py:239(__iter__)
#       166    0.000    0.000    0.000    0.000 {built-in method builtins.delattr}
#        16    0.000    0.000    0.000    0.000 axis.py:830(reset_ticks)
#        79    0.000    0.000    0.000    0.000 function_base.py:244(iterable)
#       160    0.000    0.000    0.000    0.000 function_base.py:4563(_insert_dispatcher)
#        10    0.000    0.000    0.000    0.000 shape_base.py:612(column_stack)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:71(_compile)
#        96    0.000    0.000    0.000    0.000 font_manager.py:1304(<genexpr>)
#         3    0.000    0.000    0.000    0.000 twodim_base.py:234(diag)
#       122    0.000    0.000    0.000    0.000 font_manager.py:1022(_normalize_font_family)
#        41    0.000    0.000    0.000    0.000 text.py:957(set_horizontalalignment)
#         2    0.000    0.000    0.008    0.004 axis.py:638(__init__)
#       108    0.000    0.000    0.000    0.000 artist.py:271(axes)
#        63    0.000    0.000    0.000    0.000 lines.py:61(_scale_dashes)
#        25    0.000    0.000    0.000    0.000 font_manager.py:943(copy)
#       160    0.000    0.000    0.000    0.000 numeric.py:1394(_moveaxis_dispatcher)
#     47/33    0.000    0.000    0.000    0.000 transforms.py:2380(_invalidate_internal)
#        23    0.000    0.000    0.001    0.000 text.py:1251(set_fontproperties)
#         1    0.000    0.000    0.000    0.000 gridspec.py:145(get_grid_positions)
#        16    0.000    0.000    0.001    0.000 ticker.py:1945(__init__)
#        46    0.000    0.000    0.000    0.000 colors.py:124(_check_color_like)
#        61    0.000    0.000    0.000    0.000 font_manager.py:794(set_family)
#        59    0.000    0.000    0.000    0.000 transforms.py:1348(__add__)
#         4    0.000    0.000    0.000    0.000 spines.py:34(__init__)
#        17    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        46    0.000    0.000    0.000    0.000 colors.py:111(is_color_like)
#        12    0.000    0.000    0.000    0.000 path.py:99(__init__)
#        21    0.000    0.000    0.000    0.000 fromnumeric.py:2268(any)
#         3    0.000    0.000    0.013    0.004 <__array_function__ internals>:2(eigh)
#        72    0.000    0.000    0.000    0.000 <string>:1(__new__)
#    132/14    0.000    0.000    0.000    0.000 abc.py:100(__subclasscheck__)
#         3    0.000    0.000    0.002    0.001 axis.py:414(__init__)
#         3    0.000    0.000    0.000    0.000 function_base.py:4248(meshgrid)
#         2    0.000    0.000    0.001    0.000 _base.py:406(_plot_args)
#        18    0.000    0.000    0.000    0.000 patches.py:739(_convert_units)
#        61    0.000    0.000    0.000    0.000 font_manager.py:915(set_math_fontfamily)
#    116/86    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        49    0.000    0.000    0.000    0.000 lines.py:1222(set_xdata)
#        18    0.000    0.000    0.000    0.000 transforms.py:2586(__init__)
#        22    0.000    0.000    0.000    0.000 lines.py:1069(set_linewidth)
#        22    0.000    0.000    0.000    0.000 lines.py:1034(set_drawstyle)
#         3    0.000    0.000    0.002    0.001 axis.py:475(__init__)
#         1    0.000    0.000    0.000    0.000 common.py:43(validate_tol)
#         1    0.000    0.000    0.000    0.000 figure.py:186(__init__)
#         6    0.000    0.000    0.001    0.000 fromnumeric.py:2933(prod)
#        22    0.000    0.000    0.000    0.000 __init__.py:1277(is_math_text)
#         3    0.000    0.000    0.020    0.007 DVR3d_full.py:158(H_solver)
#        22    0.000    0.000    0.000    0.000 lines.py:1335(set_dash_capstyle)
#        19    0.000    0.000    0.000    0.000 transforms.py:822(from_extents)
#        16    0.000    0.000    0.001    0.000 ticker.py:2740(__init__)
#        14    0.000    0.000    0.000    0.000 transforms.py:2678(__init__)
#        29    0.000    0.000    0.000    0.000 lines.py:31(_get_dash_pattern)
#       161    0.000    0.000    0.000    0.000 fromnumeric.py:2758(_amin_dispatcher)
#        20    0.000    0.000    0.000    0.000 patches.py:331(_set_edgecolor)
#         3    0.000    0.000    0.000    0.000 function_base.py:4360(<listcomp>)
#       166    0.000    0.000    0.000    0.000 linalg.py:2359(_norm_dispatcher)
#        16    0.000    0.000    0.000    0.000 __init__.py:512(_get_data_path)
#         8    0.000    0.000    0.000    0.000 axis.py:889(_translate_tick_kw)
#        16    0.000    0.000    0.000    0.000 scale.py:582(scale_factory)
#         3    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#        89    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x1005b26e8}
#       108    0.000    0.000    0.000    0.000 enum.py:631(__new__)
#        16    0.000    0.000    0.000    0.000 pathlib.py:1039(__new__)
#         8    0.000    0.000    0.000    0.000 __init__.py:214(connect)
#     29/15    0.000    0.000    0.000    0.000 _base.py:839(get_xaxis_transform)
#        16    0.000    0.000    0.000    0.000 pathlib.py:718(__str__)
#        49    0.000    0.000    0.000    0.000 lines.py:1234(set_ydata)
#         1    0.000    0.000    0.000    0.000 gridspec.py:668(get_position)
#        16    0.000    0.000    0.000    0.000 transforms.py:2032(rotate_deg_around)
#        20    0.000    0.000    0.000    0.000 patches.py:357(_set_facecolor)
#     29/15    0.000    0.000    0.000    0.000 _base.py:915(get_yaxis_transform)
#         1    0.000    0.000    0.000    0.000 posixpath.py:396(_joinrealpath)
#         4    0.000    0.000    0.004    0.001 axis.py:1394(grid)
#        32    0.000    0.000    0.000    0.000 pathlib.py:293(splitroot)
#         1    0.000    0.000    2.676    2.676 {built-in method builtins.exec}
#        22    0.000    0.000    0.000    0.000 lines.py:1022(set_color)
#        16    0.000    0.000    0.000    0.000 parsing.py:48(add_axis_name)
#        21    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(any)
#        16    0.000    0.000    0.000    0.000 pathlib.py:678(_from_parts)
#         7    0.000    0.000    0.000    0.000 patches.py:418(set_linestyle)
#        11    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(broadcast_arrays)
#         4    0.000    0.000    0.000    0.000 __init__.py:1301(_check_1d)
#     20/11    0.000    0.000    0.000    0.000 offsetbox.py:216(axes)
#         3    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#        49    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:3608(set_xlim)
#        10    0.000    0.000    0.000    0.000 offsetbox.py:194(__init__)
#        12    0.000    0.000    0.000    0.000 lines.py:1135(set_marker)
#        24    0.000    0.000    0.000    0.000 lines.py:713(set_transform)
#        16    0.000    0.000    0.001    0.000 patches.py:276(get_transform)
#        12    0.000    0.000    0.000    0.000 path.py:191(_update_values)
#        16    0.000    0.000    0.000    0.000 transforms.py:2012(rotate_deg)
#         7    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         4    0.000    0.000    0.000    0.000 _base.py:2482(_process_unit_info)
#        12    0.000    0.000    0.000    0.000 posixpath.py:71(join)
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.dragon4_positional}
#         3    0.000    0.000    0.000    0.000 offsetbox.py:699(__init__)
#        46    0.000    0.000    0.000    0.000 artist.py:242(convert_xunits)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1694(__init__)
#        22    0.000    0.000    0.000    0.000 lines.py:1291(set_dash_joinstyle)
#         6    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(product)
#         1    0.000    0.000    0.012    0.012 dynamics.py:200(coherent_state)
#         1    0.000    0.000    0.009    0.009 _base.py:741(_init_axis)
#        28    0.000    0.000    0.000    0.000 __init__.py:1290(_to_unmasked_float_array)
#        92    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 legend_handler.py:303(create_artists)
#         3    0.000    0.000    0.000    0.000 colors.py:195(_to_rgba_no_colorcycle)
#        25    0.000    0.000    0.000    0.000 font_manager.py:687(_from_any)
#        38    0.000    0.000    0.000    0.000 figure.py:46(_stale_figure_callback)
#        16    0.000    0.000    0.000    0.000 patches.py:842(get_bbox)
#         6    0.000    0.000    0.000    0.000 transforms.py:2285(__init__)
#       5/4    0.000    0.000    0.000    0.000 transforms.py:1791(__eq__)
#         6    0.000    0.000    0.000    0.000 linalg.py:125(_realType)
#         3    0.000    0.000    0.000    0.000 linalg.py:135(_commonType)
#        18    0.000    0.000    0.000    0.000 __init__.py:171(check_getitem)
#         1    0.000    0.000    0.001    0.001 pyplot.py:665(figure)
#        22    0.000    0.000    0.000    0.000 lines.py:1349(set_solid_capstyle)
#        64    0.000    0.000    0.000    0.000 ticker.py:183(set_axis)
#        19    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(reshape)
#        22    0.000    0.000    0.000    0.000 lines.py:1305(set_solid_joinstyle)
#         1    0.000    0.000    0.000    0.000 einops.py:136(reconstruct_from_shape)
#         2    0.000    0.000    0.000    0.000 parsing.py:29(__init__)
#         1    0.000    0.000    0.001    0.001 backend_bases.py:3487(new_figure_manager)
#         3    0.000    0.000    0.000    0.000 function_base.py:4373(<listcomp>)
#        46    0.000    0.000    0.000    0.000 artist.py:254(convert_yunits)
#         7    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 transforms.py:1735(_set)
#        39    0.000    0.000    0.000    0.000 sre_parse.py:233(__next)
#         2    0.000    0.000    0.001    0.000 _base.py:3349(tick_params)
#         8    0.000    0.000    0.000    0.000 weakref.py:44(__new__)
#        22    0.000    0.000    0.000    0.000 text.py:1265(set_usetex)
#         2    0.000    0.000    0.001    0.001 _axes.py:1388(plot)
#        13    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#        32    0.000    0.000    0.000    0.000 axis.py:551(locator)
#         6    0.000    0.000    0.000    0.000 axis.py:202(_apply_tickdir)
#        19    0.000    0.000    0.000    0.000 fromnumeric.py:198(reshape)
#        12    0.000    0.000    0.000    0.000 patches.py:398(set_linewidth)
#         2    0.000    0.000    0.000    0.000 _base.py:2302(_update_line_limits)
#        22    0.000    0.000    0.000    0.000 lines.py:1208(set_markersize)
#        32    0.000    0.000    0.000    0.000 axis.py:562(formatter)
#       4/1    0.000    0.000    0.000    0.000 arrayprint.py:751(recurser)
#        17    0.000    0.000    0.000    0.000 text.py:1052(set_fontsize)
#        12    0.000    0.000    0.000    0.000 parsing.py:123(check_axis_name)
#         2    0.000    0.000    0.000    0.000 _base.py:1493(_set_title_offset_trans)
#         1    0.000    0.000    0.000    0.000 _base.py:803(_set_lim_and_transforms)
#        38    0.000    0.000    0.000    0.000 text.py:1209(set_text)
#      10/1    0.000    0.000    0.000    0.000 offsetbox.py:204(set_figure)
#        16    0.000    0.000    0.000    0.000 pathlib.py:701(_format_parsed_parts)
#         2    0.000    0.000    0.000    0.000 transforms.py:2839(nonsingular)
#         1    0.000    0.000    0.000    0.000 base.py:4(check_arguments)
#         4    0.000    0.000    0.001    0.000 _base.py:242(__call__)
#         1    0.000    0.000    0.000    0.000 237774272.py:25(lastfun)
#       6/4    0.000    0.000    0.005    0.001 axis.py:581(__get__)
#         2    0.000    0.000    0.000    0.000 transforms.py:869(update_from_path)
#        33    0.000    0.000    0.000    0.000 stride_tricks.py:540(<genexpr>)
#        11    0.000    0.000    0.000    0.000 stride_tricks.py:536(<listcomp>)
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:544(<listcomp>)
#        17    0.000    0.000    0.000    0.000 transforms.py:803(unit)
#        18    0.000    0.000    0.000    0.000 artist.py:1096(set_zorder)
#        22    0.000    0.000    0.000    0.000 lines.py:1193(set_markeredgewidth)
#         4    0.000    0.000    0.000    0.000 warnings.py:130(filterwarnings)
#         7    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#        30    0.000    0.000    0.000    0.000 axis.py:340(_set_artist_props)
#         4    0.000    0.000    0.000    0.000 spines.py:423(linear_spine)
#         6    0.000    0.000    0.000    0.000 iostream.py:437(_schedule_flush)
#        74    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#         7    0.000    0.000    0.000    0.000 __init__.py:872(get_siblings)
#        16    0.000    0.000    0.000    0.000 transforms.py:266(x0)
#         6    0.000    0.000    0.000    0.000 iostream.py:418(_is_master_process)
#         3    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#        70    0.000    0.000    0.000    0.000 axis.py:357(<genexpr>)
#        21    0.000    0.000    0.000    0.000 artist.py:439(get_transform)
#         4    0.000    0.000    0.000    0.000 _base.py:3591(_validate_converted_limits)
#        50    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diff)
#         2    0.000    0.000    0.000    0.000 _base.py:2274(add_line)
#        61    0.000    0.000    0.000    0.000 font_manager.py:887(set_file)
#        22    0.000    0.000    0.000    0.000 lines.py:492(set_pickradius)
#         1    0.000    0.000    0.008    0.008 axis.py:2013(__init__)
#         7    0.000    0.000    0.000    0.000 _pylab_helpers.py:105(get_active)
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#       114    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        23    0.000    0.000    0.000    0.000 text.py:1149(set_x)
#         4    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#        22    0.000    0.000    0.000    0.000 lines.py:1010(set_antialiased)
#         5    0.000    0.000    0.000    0.000 transforms.py:2462(__init__)
#         7    0.000    0.000    0.000    0.000 patches.py:511(set_hatch)
#         7    0.000    0.000    0.000    0.000 iostream.py:96(_event_pipe)
#        11    0.000    0.000    0.000    0.000 patches.py:477(set_capstyle)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1719(_fix_ipython_backend2gui)
#         1    0.000    0.000    0.002    0.002 _axes.py:186(legend)
#         3    0.000    0.000    0.000    0.000 _base.py:863(get_xaxis_text1_transform)
#         5    0.000    0.000    0.000    0.000 _base.py:2942(_get_axis_map)
#        12    0.000    0.000    0.000    0.000 __init__.py:1661(safe_first_element)
#        36    0.000    0.000    0.000    0.000 __init__.py:152(<genexpr>)
#        22    0.000    0.000    0.000    0.000 lines.py:1173(set_markerfacecolor)
#         3    0.000    0.000    0.000    0.000 arrayprint.py:980(__call__)
#        12    0.000    0.000    0.000    0.000 posixpath.py:164(islink)
#         2    0.000    0.000    0.000    0.000 transforms.py:1070(set)
#         6    0.000    0.000    0.000    0.000 _base.py:2939(_get_axis_list)
#         6    0.000    0.000    0.001    0.000 fromnumeric.py:3742(product)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(meshgrid)
#         5    0.000    0.000    0.000    0.000 _base.py:1099(_set_artist_props)
#         8    0.000    0.000    0.000    0.000 transforms.py:1850(is_separable)
#         2    0.000    0.000    0.000    0.000 {method 'min' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 patches.py:708(__init__)
#         2    0.000    0.000    0.000    0.000 lines.py:1267(update_from)
#         8    0.000    0.000    0.000    0.000 transforms.py:2327(blended_transform_factory)
#         3    0.000    0.000    0.000    0.000 legend.py:1097(_get_legend_handles)
#         5    0.000    0.000    0.001    0.000 deprecation.py:381(wrapper)
#        16    0.000    0.000    0.000    0.000 {built-in method math.cos}
#         2    0.000    0.000    0.003    0.001 axis.py:934(set_clip_path)
#         7    0.000    0.000    0.000    0.000 artist.py:960(set_alpha)
#         8    0.000    0.000    0.000    0.000 units.py:56(_is_natively_supported)
#         4    0.000    0.000    0.000    0.000 spines.py:294(set_position)
#        38    0.000    0.000    0.000    0.000 sre_parse.py:254(get)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:174(getwidth)
#         2    0.000    0.000    0.000    0.000 _base.py:347(_makeline)
#         1    0.000    0.000    0.000    0.000 _base.py:3939(set_ylim)
#         2    0.000    0.000    0.001    0.000 legend_handler.py:93(legend_artist)
#         7    0.000    0.000    0.000    0.000 patches.py:455(set_fill)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:416(_get_format_function)
#         6    0.000    0.000    0.001    0.000 axis.py:236(set_clip_path)
#        24    0.000    0.000    0.000    0.000 text.py:1160(set_y)
#        30    0.000    0.000    0.000    0.000 offsetbox.py:320(get_children)
#         1    0.000    0.000    0.000    0.000 gridspec.py:569(_from_subplot_args)
#         3    0.000    0.000    0.000    0.000 linalg.py:107(_makearray)
#        32    0.000    0.000    0.000    0.000 axis.py:687(isDefault_majloc)
#         3    0.000    0.000    0.000    0.000 axis.py:442(_apply_tickdir)
#        24    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        38    0.000    0.000    0.000    0.000 sre_parse.py:172(append)
#         7    0.000    0.000    0.000    0.000 hatch.py:182(_validate_hatch_pattern)
#        39    0.000    0.000    0.000    0.000 transforms.py:1052(get_points)
#        22    0.000    0.000    0.000    0.000 lines.py:537(set_markevery)
#         8    0.000    0.000    0.000    0.000 lines.py:996(get_path)
#     14/10    0.000    0.000    0.004    0.000 deprecation.py:291(wrapper)
#         6    0.000    0.000    0.000    0.000 axis.py:190(_set_labelrotation)
#        22    0.000    0.000    0.000    0.000 text.py:1283(set_parse_math)
#         1    0.000    0.000    0.001    0.001 axis.py:2279(__init__)
#         2    0.000    0.000    0.000    0.000 artist.py:1138(update_from)
#         1    0.000    0.000    0.000    0.000 _axes.py:93(set_title)
#         6    0.000    0.000    0.000    0.000 axis.py:1437(update_units)
#        62    0.000    0.000    0.000    0.000 axis.py:558(formatter)
#        16    0.000    0.000    0.000    0.000 axis.py:1567(set_major_formatter)
#        28    0.000    0.000    0.000    0.000 spines.py:549(__getattr__)
#        13    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 _base.py:320(_getdefaults)
#         3    0.000    0.000    0.000    0.000 _base.py:939(get_yaxis_text1_transform)
#         6    0.000    0.000    0.019    0.003 figure.py:1487(gca)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:485(_array2string)
#         2    0.000    0.000    0.004    0.002 _base.py:3186(grid)
#        22    0.000    0.000    0.000    0.000 lines.py:1183(set_markerfacecoloralt)
#     28/24    0.000    0.000    0.000    0.000 spines.py:200(_ensure_position_is_set)
#         2    0.000    0.000    0.000    0.000 getipython.py:17(get_ipython)
#         6    0.000    0.000    0.000    0.000 pyplot.py:833(gcf)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(column_stack)
#         3    0.000    0.000    0.000    0.000 axis.py:503(_apply_tickdir)
#         1    0.000    0.000    0.019    0.019 figure.py:646(add_subplot)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:937(parse)
#        36    0.000    0.000    0.000    0.000 stride_tricks.py:344(<genexpr>)
#         2    0.000    0.000    0.020    0.010 pyplot.py:2755(plot)
#         5    0.000    0.000    0.000    0.000 offsetbox.py:373(__init__)
#         1    0.000    0.000    0.000    0.000 _base.py:751(set_figure)
#        10    0.000    0.000    0.000    0.000 artist.py:869(set_clip_on)
#        38    0.000    0.000    0.000    0.000 sre_parse.py:164(__getitem__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:32(seterr)
#         1    0.000    0.000    0.019    0.019 _subplots.py:14(__init__)
#        15    0.000    0.000    0.000    0.000 font_manager.py:721(__eq__)
#        22    0.000    0.000    0.000    0.000 lines.py:1163(set_markeredgecolor)
#        32    0.000    0.000    0.000    0.000 axis.py:703(isDefault_minloc)
#         1    0.000    0.000    2.676    2.676 <string>:1(<module>)
#         3    0.000    0.000    0.000    0.000 axis.py:453(update_position)
#         1    0.000    0.000    0.000    0.000 _base.py:3455(set_xlabel)
#         2    0.000    0.000    0.000    0.000 _base.py:786(_request_autoscale_view)
#         4    0.000    0.000    0.000    0.000 legend.py:690(get_legend_handler)
#         1    0.000    0.000    0.000    0.000 posixpath.py:334(normpath)
#         6    0.000    0.000    0.000    0.000 index_tricks.py:912(diag_indices)
#         2    0.000    0.000    0.000    0.000 transforms.py:1408(contains_branch_seperately)
#        12    0.000    0.000    0.000    0.000 patches.py:346(set_edgecolor)
#         6    0.000    0.000    0.019    0.003 pyplot.py:2260(gca)
#        32    0.000    0.000    0.000    0.000 axis.py:695(isDefault_majfmt)
#         2    0.000    0.000    0.000    0.000 offsetbox.py:579(__init__)
#        18    0.000    0.000    0.000    0.000 _base.py:2940(<genexpr>)
#        10    0.000    0.000    0.000    0.000 shape_base.py:608(_column_stack_dispatcher)
#         1    0.000    0.000    0.000    0.000 pyplot.py:854(get_fignums)
#         1    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         2    0.000    0.000    0.000    0.000 figure.py:84(add)
#         3    0.000    0.000    0.000    0.000 axis.py:514(update_position)
#        16    0.000    0.000    0.000    0.000 pathlib.py:1049(_init)
#         3    0.000    0.000    0.000    0.000 legend.py:560(_set_artist_props)
# ...
#         1    0.000    0.000    0.000    0.000 colors.py:287(to_rgba_array)
#         4    0.000    0.000    0.000    0.000 axis.py:541(__init__)
#        16    0.000    0.000    0.000    0.000 scale.py:97(__init__)
#         2    0.000    0.000    0.000    0.000 figure.py:2369(axes)
#        11    0.000    0.000    0.000    0.000 stride_tricks.py:474(_broadcast_arrays_dispatcher)
#         1    0.000    0.000    0.000    0.000 dynamics.py:201(firstfun)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#         2    0.000    0.000    0.000    0.000 legend.py:655(get_default_handler_map)
#         3    0.000    0.000    0.000    0.000 text.py:1104(set_fontweight)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(full_like)
#         2    0.000    0.000    0.000    0.000 legend_handler.py:84(adjust_drawing_area)
#        14    0.000    0.000    0.000    0.000 axis.py:392(<dictcomp>)
#         9    0.000    0.000    0.000    0.000 __init__.py:826(<listcomp>)
#         4    0.000    0.000    0.000    0.000 axis.py:752(get_transform)
#         4    0.000    0.000    0.000    0.000 scale.py:116(get_transform)
#         2    0.000    0.000    0.000    0.000 __init__.py:817(__init__)
#        12    0.000    0.000    0.000    0.000 {method 'isalnum' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#         1    0.000    0.000    0.000    0.000 transforms.py:797(frozen)
#         1    0.000    0.000    0.000    0.000 figure.py:1481(sca)
#         2    0.000    0.000    0.000    0.000 _base.py:223(__init__)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:375(<lambda>)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         4    0.000    0.000    0.000    0.000 colors.py:226(<genexpr>)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:921(fix_flags)
#         1    0.000    0.000    0.000    0.000 axis.py:2239(get_minpos)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(vstack)
#         2    0.000    0.000    0.000    0.000 _base.py:338(_setdefaults)
#        12    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#         1    0.000    0.000    0.000    0.000 arrayprint.py:742(_formatArray)
#         1    0.000    0.000    0.000    0.000 posixpath.py:372(abspath)
#         6    0.000    0.000    0.000    0.000 einops.py:292(<listcomp>)
#         2    0.000    0.000    0.000    0.000 transforms.py:2311(get_matrix)
#         4    0.000    0.000    0.000    0.000 transforms.py:2409(<lambda>)
#         1    0.000    0.000    0.002    0.002 pyplot.py:2653(legend)
#         1    0.000    0.000    0.000    0.000 figure.py:1928(_set_artist_props)
#        12    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 transforms.py:374(width)
#         1    0.000    0.000    0.000    0.000 patches.py:391(set_alpha)
#         1    0.000    0.000    0.000    0.000 rcsetup.py:152(validate_axisbelow)
#         1    0.000    0.000    0.000    0.000 figure.py:71(_entry_from_axes)
#         1    0.000    0.000    0.000    0.000 legend.py:571(_set_loc)
#         2    0.000    0.000    0.000    0.000 __init__.py:1810(_str_lower_equal)
#         1    0.000    0.000    0.000    0.000 figure.py:2412(set_tight_layout)
#         1    0.000    0.000    0.000    0.000 gridspec.py:101(set_width_ratios)
#         2    0.000    0.000    0.000    0.000 legend_handler.py:67(_update_prop)
#         1    0.000    0.000    0.000    0.000 gridspec.py:435(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 _base.py:328(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#         1    0.000    0.000    0.000    0.000 pyplot.py:310(draw_if_interactive)
#         2    0.000    0.000    0.000    0.000 legend_handler.py:73(_default_update_prop)
#         7    0.000    0.000    0.000    0.000 einops.py:308(<genexpr>)
#         1    0.000    0.000    0.000    0.000 font_manager.py:172(_cached_realpath)
#         6    0.000    0.000    0.000    0.000 einops.py:286(<setcomp>)
#         8    0.000    0.000    0.000    0.000 path.py:200(vertices)
#         8    0.000    0.000    0.000    0.000 __init__.py:1619(<lambda>)
#        12    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 gridspec.py:123(set_height_ratios)
#         4    0.000    0.000    0.000    0.000 transforms.py:1363(_iter_break_from_left_to_right)
#        12    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISLNK}
#         2    0.000    0.000    0.000    0.000 _base.py:2170(_deprecate_noninstance)
#         7    0.000    0.000    0.000    0.000 artist.py:1072(get_label)
#         1    0.000    0.000    0.000    0.000 {method 'symmetric_difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 gridspec.py:559(__init__)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         2    0.000    0.000    0.000    0.000 __init__.py:570(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 sre_compile.py:453(_get_iscased)
#         7    0.000    0.000    0.000    0.000 artist.py:418(is_transform_set)
#         1    0.000    0.000    0.000    0.000 transforms.py:808(null)
#         2    0.000    0.000    0.000    0.000 transforms.py:1726(__eq__)
#         4    0.000    0.000    0.000    0.000 transforms.py:1772(<lambda>)
#         1    0.000    0.000    0.000    0.000 patches.py:2146(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 einops.py:271(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(unravel_index)
#         6    0.000    0.000    0.000    0.000 einops.py:285(<setcomp>)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3127(ndim)
#         3    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 _base.py:2539(<listcomp>)
#         1    0.000    0.000    0.000    0.000 figure.py:2894(<lambda>)
#         2    0.000    0.000    0.000    0.000 axis.py:1352(get_major_locator)
#         1    0.000    0.000    0.000    0.000 __init__.py:98(get_projection_class)
#        12    0.000    0.000    0.000    0.000 transforms.py:1375(depth)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2795(notify_axes_change)
#         2    0.000    0.000    0.000    0.000 figure.py:2533(set_canvas)
#         2    0.000    0.000    0.000    0.000 numeric.py:1858(isscalar)
#         1    0.000    0.000    0.000    0.000 spines.py:536(__init__)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:425(__init__)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(tile)
#         3    0.000    0.000    0.000    0.000 twodim_base.py:230(_diag_dispatcher)
#         4    0.000    0.000    0.000    0.000 legend_handler.py:160(get_numpoints)
#         1    0.000    0.000    0.000    0.000 axis.py:2501(get_minpos)
#         2    0.000    0.000    0.000    0.000 configurable.py:554(initialized)
#         8    0.000    0.000    0.000    0.000 artist.py:1111(sticky_edges)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:286(tell)
#         1    0.000    0.000    0.000    0.000 decorators.py:41(wrapper)
#         1    0.000    0.000    0.000    0.000 __init__.py:2059(__init__)
#         2    0.000    0.000    0.000    0.000 legend_handler.py:268(__getitem__)
#         1    0.000    0.000    0.000    0.000 237774272.py:22(firstfun)
#         1    0.000    0.000    0.000    0.000 __init__.py:227(_releaseLock)
#         2    0.000    0.000    0.000    0.000 widgets.py:36(__init__)
#         2    0.000    0.000    0.000    0.000 figure.py:112(__contains__)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:492(_get_charset_prefix)
#         2    0.000    0.000    0.000    0.000 offsetbox.py:613(get_transform)
#         2    0.000    0.000    0.000    0.000 configurable.py:510(instance)
#         1    0.000    0.000    0.000    0.000 shape_base.py:218(_vhstack_dispatcher)
#         4    0.000    0.000    0.000    0.000 einops.py:18(_product)
#         5    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 linalg.py:1080(_eigvalsh_dispatcher)
#         1    0.000    0.000    0.000    0.000 transforms.py:259(frozen)
#         4    0.000    0.000    0.000    0.000 figure.py:69(<listcomp>)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2362(_all_dispatcher)
#         4    0.000    0.000    0.000    0.000 einops.py:191(<listcomp>)
#         6    0.000    0.000    0.000    0.000 axis.py:148(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 einops.py:291(<listcomp>)
#         2    0.000    0.000    0.000    0.000 sre_parse.py:81(groups)
#         4    0.000    0.000    0.000    0.000 axis.py:1426(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 _base.py:458(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _base.py:788(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:434(__exit__)
#         1    0.000    0.000    0.000    0.000 _base.py:3437(set_axis_on)
#         4    0.000    0.000    0.000    0.000 einops.py:305(<listcomp>)
#         3    0.000    0.000    0.000    0.000 gridspec.py:75(get_geometry)
#         3    0.000    0.000    0.000    0.000 function_base.py:4243(_meshgrid_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#         2    0.000    0.000    0.000    0.000 sre_compile.py:595(isstring)
#         1    0.000    0.000    0.000    0.000 copyreg.py:90(__newobj__)
#         1    0.000    0.000    0.000    0.000 figure.py:2890(add_axobserver)
#         1    0.000    0.000    0.000    0.000 transforms.py:1030(minposx)
#         2    0.000    0.000    0.000    0.000 optimize.py:120(__getattr__)
#         1    0.000    0.000    0.000    0.000 common.py:26(warn_extraneous)
#         2    0.000    0.000    0.000    0.000 _methods.py:42(_amin)
#         1    0.000    0.000    0.000    0.000 einops.py:272(<listcomp>)
#         4    0.000    0.000    0.000    0.000 arrayprint.py:955(<genexpr>)
#         4    0.000    0.000    0.000    0.000 enum.py:753(value)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:76(__init__)
#         1    0.000    0.000    0.000    0.000 patches.py:2145(<listcomp>)
#         2    0.000    0.000    0.000    0.000 figure.py:72(<genexpr>)
#         2    0.000    0.000    0.000    0.000 legend_handler.py:262(__init__)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:66(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 einops.py:310(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 axis.py:755(get_scale)
#         1    0.000    0.000    0.000    0.000 patches.py:2435(__init__)
#         2    0.000    0.000    0.000    0.000 _methods.py:38(_amax)
#         3    0.000    0.000    0.000    0.000 backend_bases.py:1715(<lambda>)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:111(__init__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:698(__init__)
#         1    0.000    0.000    0.000    0.000 transforms.py:380(height)
#         1    0.000    0.000    0.000    0.000 _base.py:4206(set_navigate)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:160(__len__)
#         1    0.000    0.000    0.000    0.000 __init__.py:73(get_projection_class)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 axis.py:1492(have_units)
#         1    0.000    0.000    0.000    0.000 _methods.py:60(_all)
#         4    0.000    0.000    0.000    0.000 arrayprint.py:956(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _base.py:4222(set_navigate_mode)
#         1    0.000    0.000    0.000    0.000 transforms.py:1041(minposy)
#         5    0.000    0.000    0.000    0.000 artist.py:1298(mouseover)
#         1    0.000    0.000    0.000    0.000 legend.py:676(get_legend_handler_map)
#         1    0.000    0.000    0.000    0.000 __init__.py:193(_checkLevel)
#         1    0.000    0.000    0.000    0.000 gridspec.py:190(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1180(is_interactive)
#         2    0.000    0.000    0.000    0.000 shape_base.py:1243(<genexpr>)
#         1    0.000    0.000    0.000    0.000 gridspec.py:198(<listcomp>)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:2454(_cumsum_dispatcher)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISREG}
#         1    0.000    0.000    0.000    0.000 artist.py:629(set_snap)
#         1    0.000    0.000    0.000    0.000 spines.py:582(__iter__)
#         2    0.000    0.000    0.000    0.000 scale.py:79(limit_range_for_scale)
#         1    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 multiarray.py:664(result_type)
#         2    0.000    0.000    0.000    0.000 path.py:214(codes)
#         1    0.000    0.000    0.000    0.000 gridspec.py:620(num2)
#         1    0.000    0.000    0.000    0.000 _base.py:611(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 path.py:245(should_simplify)
#         1    0.000    0.000    0.000    0.000 text.py:1171(set_rotation)
#         1    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:776(__init__)
#         2    0.000    0.000    0.000    0.000 figure.py:2385(_get_dpi)
#         1    0.000    0.000    0.000    0.000 gridspec.py:616(num2)
#         2    0.000    0.000    0.000    0.000 __init__.py:818(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 multiarray.py:80(empty_like)
#         2    0.000    0.000    0.000    0.000 numeric.py:353(_full_like_dispatcher)
#         1    0.000    0.000    0.000    0.000 legend.py:941(set_bbox_to_anchor)
#         1    0.000    0.000    0.000    0.000 offsetbox.py:257(set_offset)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3123(_ndim_dispatcher)
#         2    0.000    0.000    0.000    0.000 axis.py:547(locator)
#         2    0.000    0.000    0.000    0.000 path.py:233(simplify_threshold)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:249(match)
#         1    0.000    0.000    0.000    0.000 __init__.py:109(__call__)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2852(set_window_title)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:860(_none_or_positive_arg)
#         2    0.000    0.000    0.000    0.000 function_base.py:18(_linspace_dispatcher)
#         2    0.000    0.000    0.000    0.000 artist.py:855(get_clip_path)
#         1    0.000    0.000    0.000    0.000 artist.py:1033(set_in_layout)
#         2    0.000    0.000    0.000    0.000 artist.py:828(get_visible)
#         1    0.000    0.000    0.000    0.000 einops.py:195(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 multiarray.py:1021(unravel_index)
#         1    0.000    0.000    0.000    0.000 gridspec.py:627(get_gridspec)
#         1    0.000    0.000    0.000    0.000 shape_base.py:1167(_tile_dispatcher)
#         1    0.000    0.000    0.000    0.000 shape_base.py:77(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 transforms.py:1019(minpos)

# %%
import numpy as np
from dynamics_sho import *
import matplotlib.pyplot as plt
from dynamics_sho_classical import *
from opt_einsum import contract
from einops import rearrange, reduce, repeat
from scipy.optimize import fmin


def run():
    # 3D harmonic potential
    print("3D harmonic potential starts.")
    # Rough estimation on memory:
    # grid point = [2n+1 2n+1 2n+1]
    # typical n choice n = 20 or 15, dx = 0.4
    # n = 15, size of matrix ~ 7G
    # n = 20, size of matrix ~ 36G
    # n = 30, size of matrix ~ 380G
    N = 15
    n = np.array([N, N, 0])
    # dx = 1 / 3 * np.ones(3, dtype=float)
    dx = 0.4 * np.ones(3, dtype=float)
    Ndim = np.product(2 * n + 1)
    print("n={}, dx={}, matrix size={:g}".format(n, dx, Ndim))
    mem = 2**(2 * np.log2(Ndim) + 3 - 30)
    print("Estimated matrix memory usage: {:g} GiB".format(mem))
    psi0 = initial_state(n, dx, avg=1/2, potential=Vfun)
    print('Initial state preparation finished.')

    E1, W1 = H_solver(n, dx, avg=1, potential=Vfun)
    E2, W2 = H_solver(n, dx, avg=0)
    E_list = [E1, E2]
    W_list = [W1, W2]
    print('Stroboscopic states preparation finished.')

    for freq in [10.**i for i in range(-1, 2)]:  # frequency unit, V0 ~ 104.52kHz
        t1 = 1 / (2 * freq)  # time period of free system, in unit of 1/V0 ~ 1E-5 s
        # time period of stroboscopic potential system, in unit of 1/V0 ~ 1E-5 s
        t2 = 1 / (2 * freq)
        t_step = t1 + t2
        print("freq={:g} starts.".format(freq))

        if t_step < (t1 + t2):
            print("Dynamic time step is too small.")
            exit(1)

        U = one_period_evo(E_list, W_list, t1, t2)
        rho_rt = np.array([1])
        t = np.array([0])
        t_count = 0
        E, W = sla.schur(U)
        psi = W.conj().T @ psi0
        psi1 = psi0.conj().T @ W
        n_period = int(t_step / (t1 + t2))
        print('matrix power p in each time step: {:g}.'.format(n_period))

        while t_count < 5E1:
            psi = dynamics_by_long_time(t_step,
                                        t1 + t2,
                                        E,
                                        W,
                                        psi,
                                        denseoutput=True)
            rho_rt = np.append(rho_rt, psi1 @ psi)
            t_count += t_step
            t = np.append(t, t_count)
            t_vs_rho = np.concatenate((t[:, None], (abs(rho_rt)**2)[:, None]), axis=1)
            np.savetxt('{} {} {:g} sho.csv'.format(n, dx, freq),
                    t_vs_rho,
                    delimiter=',')
            if t_count % (t_step * 1E3) == 0:
                print("freq={:.2g} t={:.3g} finished.".format(freq, t_count))
        print("freq={:.2g} finished.".format(freq))


# %prun run()
# Out:
# 3D harmonic potential starts.
# n=[15 15  0], dx=[0.4 0.4 0.4], matrix size=961
# Estimated matrix memory usage: 0.00688077 GiB
# Initial state preparation finished.
# Stroboscopic states preparation finished.
# freq=0.1 starts.
# matrix power p in each time step: 1.
# freq=0.1 finished.
# freq=1 starts.
# matrix power p in each time step: 1.
# freq=1 finished.
# freq=10 starts.
# matrix power p in each time step: 1.
# freq=10 finished.
#          405418 function calls (398696 primitive calls) in 14.630 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3   10.570    3.523   10.576    3.525 decomp_schur.py:17(schur)
#       555    1.770    0.003    1.770    0.003 dynamics_sho.py:82(dynamics_by_long_time)
#         3    0.592    0.197    0.592    0.197 linalg.py:1336(eigh)
#         6    0.589    0.098    0.589    0.098 dynamics_sho.py:27(int_evo_ops)
#         3    0.294    0.098    0.883    0.294 dynamics_sho.py:69(one_period_evo)
#       555    0.274    0.000    0.510    0.001 npyio.py:1202(savetxt)
#      1110    0.068    0.000    0.073    0.000 {built-in method io.open}
#      1110    0.047    0.000    0.047    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#         1    0.037    0.037   14.631   14.631 1447296840.py:10(run)
# 7267/4482    0.027    0.000    1.194    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        18    0.021    0.001    0.021    0.001 {built-in method numpy.core._multiarray_umath.c_einsum}
#    127095    0.020    0.000    0.020    0.000 {method 'write' of '_io.TextIOWrapper' objects}
#       556    0.020    0.000    0.047    0.000 arrayprint.py:896(fillFormat)
#         3    0.014    0.005    0.048    0.016 DVR3d_sho_full.py:100(H_mat)
#      2234    0.013    0.000    0.013    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       555    0.012    0.000    0.012    0.000 {built-in method posix.getcwd}
# 4448/1112    0.012    0.000    0.029    0.000 arrayprint.py:751(recurser)
#       555    0.010    0.000    0.011    0.000 {built-in method builtins.__build_class__}
#  1122/566    0.010    0.000    0.156    0.000 {method 'format' of 'str' objects}
#      1112    0.006    0.000    0.122    0.000 arrayprint.py:485(_array2string)
#       556    0.006    0.000    0.024    0.000 arrayprint.py:1185(__init__)
#      1112    0.006    0.000    0.085    0.000 arrayprint.py:416(_get_format_function)
#      1110    0.006    0.000    0.031    0.000 function_base.py:4762(append)
#      1668    0.006    0.000    0.007    0.000 arrayprint.py:980(__call__)
#       558    0.006    0.000    0.006    0.000 {built-in method builtins.abs}
#         3    0.005    0.002    0.005    0.002 function_base.py:422(asarray_chkfinite)
#      1112    0.005    0.000    0.145    0.000 arrayprint.py:523(array2string)
#      1112    0.005    0.000    0.010    0.000 arrayprint.py:61(_make_options_dict)
#      1665    0.005    0.000    0.019    0.000 _datasource.py:302(_isurl)
#      1112    0.005    0.000    0.128    0.000 arrayprint.py:468(wrapper)
#      2220    0.005    0.000    0.017    0.000 parse.py:369(urlparse)
#      3336    0.004    0.000    0.004    0.000 {built-in method numpy.core._multiarray_umath.dragon4_positional}
#      2232    0.004    0.000    0.004    0.000 {built-in method numpy.asanyarray}
#        15    0.004    0.000    0.004    0.000 {built-in method numpy.zeros}
#      1112    0.004    0.000    0.004    0.000 arrayprint.py:367(_get_formatdict)
#      1665    0.004    0.000    0.006    0.000 posixpath.py:334(normpath)
#      2220    0.004    0.000    0.010    0.000 parse.py:425(urlsplit)
#      2231    0.004    0.000    0.017    0.000 fromnumeric.py:69(_wrapreduction)
#     13951    0.003    0.000    0.005    0.000 {built-in method builtins.isinstance}
#      1112    0.003    0.000    0.003    0.000 {built-in method builtins.locals}
#       555    0.003    0.000    0.003    0.000 {built-in method posix.stat}
#      1112    0.003    0.000    0.007    0.000 _ufunc_config.py:32(seterr)
#      1110    0.003    0.000    0.004    0.000 posixpath.py:71(join)
#      2224    0.003    0.000    0.006    0.000 arrayprint.py:946(<genexpr>)
#        15    0.003    0.000    0.003    0.000 {method 'conj' of 'numpy.ndarray' objects}
#     35447    0.003    0.000    0.003    0.000 {built-in method builtins.len}
#         3    0.003    0.001    0.028    0.009 DVR3d_sho_full.py:65(Tmat)
#      1110    0.003    0.000    0.009    0.000 fromnumeric.py:1718(ravel)
#      1112    0.003    0.000    0.003    0.000 _ufunc_config.py:131(geterr)
#      1110    0.003    0.000    0.003    0.000 {built-in method _locale.nl_langinfo}
#      2775    0.003    0.000    0.004    0.000 _datasource.py:130(keys)
#      3336    0.003    0.000    0.003    0.000 arrayprint.py:701(_extendLine)
#      4440    0.003    0.000    0.004    0.000 parse.py:420(_remove_unsafe_bytes_from_url)
#      1110    0.002    0.000    0.042    0.000 <__array_function__ internals>:2(append)
#      1112    0.002    0.000    0.147    0.000 arrayprint.py:1534(_array_str_implementation)
#      1110    0.002    0.000    0.006    0.000 _datasource.py:417(_sanitize_relative_path)
#      4440    0.002    0.000    0.003    0.000 parse.py:113(_coerce_args)
#      3336    0.002    0.000    0.007    0.000 arrayprint.py:715(_extendLine_pretty)
#      2960    0.002    0.000    0.003    0.000 {built-in method builtins.max}
#      1665    0.002    0.000    0.003    0.000 genericpath.py:121(_splitext)
#      1110    0.002    0.000    0.002    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      1110    0.002    0.000    0.011    0.000 _datasource.py:293(_possible_names)
#      1668    0.002    0.000    0.016    0.000 <__array_function__ internals>:2(concatenate)
#       556    0.002    0.000    0.049    0.000 arrayprint.py:869(__init__)
#      1665    0.002    0.000    0.010    0.000 _datasource.py:263(_iszip)
#      1110    0.002    0.000    0.005    0.000 _bootlocale.py:33(getpreferredencoding)
#      1668    0.002    0.000    0.002    0.000 arrayprint.py:1193(__call__)
#      1112    0.002    0.000    0.015    0.000 fromnumeric.py:2638(amax)
#       555    0.002    0.000    0.023    0.000 posixpath.py:372(abspath)
#       555    0.002    0.000    0.068    0.000 _datasource.py:487(open)
#       555    0.002    0.000    0.037    0.000 _datasource.py:344(_findfile)
#      1665    0.002    0.000    0.005    0.000 posixpath.py:117(splitext)
#       555    0.002    0.000    0.025    0.000 _datasource.py:246(__init__)
#      1112    0.001    0.000    0.030    0.000 arrayprint.py:742(_formatArray)
#     13338    0.001    0.000    0.001    0.000 {method 'replace' of 'str' objects}
#       555    0.001    0.000    0.012    0.000 _datasource.py:375(abspath)
#      1112    0.001    0.000    0.001    0.000 arrayprint.py:66(<dictcomp>)
#       556    0.001    0.000    0.025    0.000 arrayprint.py:374(<lambda>)
#      2224    0.001    0.000    0.008    0.000 arrayprint.py:951(<genexpr>)
#      3885    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#      3369    0.001    0.000    0.001    0.000 {method 'split' of 'str' objects}
#      1110    0.001    0.000    0.012    0.000 <__array_function__ internals>:2(ravel)
#       555    0.001    0.000    0.094    0.000 _datasource.py:155(open)
#       555    0.001    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#      2231    0.001    0.000    0.001    0.000 fromnumeric.py:70(<dictcomp>)
#      3330    0.001    0.000    0.001    0.000 {method 'rfind' of 'str' objects}
#      1112    0.001    0.000    0.001    0.000 {built-in method numpy.seterrobj}
#      3361    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#      1112    0.001    0.000    0.005    0.000 fromnumeric.py:2763(amin)
#      1112    0.001    0.000    0.017    0.000 <__array_function__ internals>:2(amax)
#       555    0.001    0.000    0.001    0.000 type_check.py:303(iscomplexobj)
#      4456    0.001    0.000    0.001    0.000 {built-in method builtins.issubclass}
#        35    0.001    0.000    0.001    0.000 socket.py:480(send)
#       555    0.001    0.000    0.001    0.000 npyio.py:1330(WriteWrap)
#      9070    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      3336    0.001    0.000    0.001    0.000 {method 'splitlines' of 'str' objects}
#         1    0.001    0.001    0.001    0.001 blas.py:259(find_best_blas_type)
#      2242    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#       555    0.001    0.000    0.513    0.001 <__array_function__ internals>:2(savetxt)
#      6660    0.001    0.000    0.001    0.000 {method 'lstrip' of 'str' objects}
#      2224    0.001    0.000    0.001    0.000 {built-in method numpy.geterrobj}
#       555    0.001    0.000    0.002    0.000 posixpath.py:60(isabs)
#       556    0.001    0.000    0.050    0.000 arrayprint.py:375(<lambda>)
#      7215    0.001    0.000    0.001    0.000 {built-in method posix.fspath}
#       556    0.001    0.000    0.006    0.000 _ufunc_config.py:429(__enter__)
#      1112    0.001    0.000    0.007    0.000 <__array_function__ internals>:2(amin)
#       555    0.001    0.000    0.004    0.000 genericpath.py:16(exists)
#      2223    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x1029286e8}
#      1112    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#      1665    0.001    0.000    0.001    0.000 posixpath.py:131(splitdrive)
#      1665    0.001    0.000    0.001    0.000 posixpath.py:41(_get_sep)
#      3330    0.001    0.000    0.001    0.000 _datasource.py:103(_load)
#      1110    0.001    0.000    0.001    0.000 codecs.py:186(__init__)
#      1701    0.001    0.000    0.001    0.000 {method 'join' of 'str' objects}
#         6    0.001    0.000    0.001    0.000 DVR3d_sho_full.py:50(Tmat_1d)
#       555    0.001    0.000    0.002    0.000 <__array_function__ internals>:2(iscomplexobj)
#      1665    0.001    0.000    0.001    0.000 {method 'endswith' of 'str' objects}
#       555    0.001    0.000    0.005    0.000 _datasource.py:431(exists)
#      1112    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#       555    0.000    0.000    0.001    0.000 py3k.py:48(asstr)
#      1673    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#      1110    0.000    0.000    0.000    0.000 function_base.py:4758(_append_dispatcher)
#      1112    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 DVR3d_sho_full.py:44(kinetic_offdiag)
#       556    0.000    0.000    0.002    0.000 _ufunc_config.py:434(__exit__)
#      1112    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#      2224    0.000    0.000    0.001    0.000 arrayprint.py:955(<genexpr>)
#      1130    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#      2775    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#      4440    0.000    0.000    0.000    0.000 parse.py:102(_noop)
#      1112    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       762    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#       556    0.000    0.000    0.000    0.000 _ufunc_config.py:425(__init__)
#         9    0.000    0.000    0.002    0.000 contract.py:93(contract_path)
#      1668    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#      2224    0.000    0.000    0.000    0.000 arrayprint.py:956(<genexpr>)
#         9    0.000    0.000    0.000    0.000 paths.py:63(ssa_to_linear)
#       555    0.000    0.000    0.001    0.000 abc.py:96(__instancecheck__)
#       555    0.000    0.000    0.001    0.000 _datasource.py:256(__del__)
#      1112    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         3    0.000    0.000    0.005    0.002 DVR3d_sho_full.py:26(Vmat)
#       555    0.000    0.000    0.000    0.000 _datasource.py:149(__getitem__)
#       555    0.000    0.000    0.000    0.000 _iotools.py:38(_is_string_like)
#       582    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#      1110    0.000    0.000    0.000    0.000 fromnumeric.py:1714(_ravel_dispatcher)
#       555    0.000    0.000    0.002    0.000 _datasource.py:280(_splitzipext)
#         3    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.generic' objects}
#        36    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         3    0.000    0.000    0.004    0.001 twodim_base.py:234(diag)
#      54/9    0.000    0.000    0.000    0.000 paths.py:190(_optimal_iterate)
#      1112    0.000    0.000    0.000    0.000 fromnumeric.py:2633(_amax_dispatcher)
#        54    0.000    0.000    0.000    0.000 paths.py:100(calc_k12_flops)
#         9    0.000    0.000    0.000    0.000 stride_tricks.py:339(_broadcast_to)
#       555    0.000    0.000    0.000    0.000 type_check.py:206(_is_type_dispatcher)
#       556    0.000    0.000    0.000    0.000 arrayprint.py:860(_none_or_positive_arg)
#      1112    0.000    0.000    0.000    0.000 fromnumeric.py:2758(_amin_dispatcher)
#         9    0.000    0.000    0.024    0.003 contract.py:378(contract)
#         9    0.000    0.000    0.022    0.002 contract.py:530(_core_contract)
#        28    0.000    0.000    0.001    0.000 iostream.py:500(write)
#        35    0.000    0.000    0.001    0.000 iostream.py:206(schedule)
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:478(broadcast_arrays)
#       555    0.000    0.000    0.000    0.000 npyio.py:1196(_savetxt_dispatcher)
#         9    0.000    0.000    0.001    0.000 paths.py:152(optimal)
#         9    0.000    0.000    0.000    0.000 parser.py:246(parse_einsum_input)
#        25    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        14    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#         9    0.000    0.000    0.000    0.000 twodim_base.py:161(eye)
#        18    0.000    0.000    0.000    0.000 blas.py:12(can_blas)
#         3    0.000    0.000    0.000    0.000 DVR3d_sho_full.py:20(Vfun)
#       108    0.000    0.000    0.000    0.000 parser.py:154(<genexpr>)
#       135    0.000    0.000    0.000    0.000 helpers.py:53(compute_size_by_dict)
#        24    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#        18    0.000    0.000    0.000    0.000 helpers.py:82(find_contraction)
#        18    0.000    0.000    0.021    0.001 contract.py:333(_einsum)
#        35    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        45    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:414(_broadcast_shape)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(product)
#        81    0.000    0.000    0.000    0.000 helpers.py:137(flop_count)
#         3    0.000    0.000    0.639    0.213 DVR3d_sho_full.py:113(H_solver)
#        28    0.000    0.000    0.000    0.000 iostream.py:418(_is_master_process)
#         9    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.001    0.000 function_base.py:4248(meshgrid)
#         3    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#        54    0.000    0.000    0.000    0.000 paths.py:74(<genexpr>)
#        90    0.000    0.000    0.000    0.000 parser.py:155(<listcomp>)
#        35    0.000    0.000    0.000    0.000 iostream.py:96(_event_pipe)
#       183    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         3    0.000    0.000    0.001    0.000 blas.py:383(getter)
#       180    0.000    0.000    0.000    0.000 parser.py:155(<genexpr>)
#        35    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#         9    0.000    0.000    0.000    0.000 contract.py:510(infer_backend)
#        28    0.000    0.000    0.000    0.000 iostream.py:437(_schedule_flush)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:2933(prod)
#       234    0.000    0.000    0.000    0.000 parser.py:21(is_valid_einsum_char)
#        18    0.000    0.000    0.021    0.001 sharing.py:148(cached_einsum)
#         3    0.000    0.000    0.000    0.000 function_base.py:4360(<listcomp>)
#        18    0.000    0.000    0.000    0.000 parser.py:141(find_output_shape)
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#       144    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        18    0.000    0.000    0.021    0.001 <__array_function__ internals>:2(einsum)
#        18    0.000    0.000    0.000    0.000 sharing.py:23(currently_sharing)
#         6    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.001    0.001 blas.py:325(_get_funcs)
#         1    0.000    0.000   14.631   14.631 {built-in method builtins.exec}
#        54    0.000    0.000    0.000    0.000 {method 'union' of 'frozenset' objects}
#         9    0.000    0.000    0.000    0.000 parser.py:277(<listcomp>)
#         9    0.000    0.000    0.001    0.000 paths.py:1072(auto)
#         1    0.000    0.000   14.631   14.631 <string>:1(<module>)
#        18    0.000    0.000    0.021    0.001 einsumfunc.py:997(einsum)
#         9    0.000    0.000    0.000    0.000 contract.py:514(parse_backend)
#         9    0.000    0.000    0.000    0.000 contract.py:244(<listcomp>)
#       126    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        90    0.000    0.000    0.000    0.000 einsumfunc.py:989(_einsum_dispatcher)
#         3    0.000    0.000    0.000    0.000 linalg.py:135(_commonType)
#        28    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        54    0.000    0.000    0.000    0.000 helpers.py:126(<genexpr>)
#         6    0.000    0.000    0.000    0.000 linalg.py:125(_realType)
#        27    0.000    0.000    0.000    0.000 parser.py:158(possibly_convert_to_numpy)
#         3    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(meshgrid)
#        36    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#        18    0.000    0.000    0.000    0.000 parser.py:35(has_valid_einsum_chars_only)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.269    0.269 dynamics_sho.py:20(initial_state)
#         9    0.000    0.000    0.000    0.000 contract.py:214(<listcomp>)
#         9    0.000    0.000    0.000    0.000 function_base.py:244(iterable)
#        36    0.000    0.000    0.000    0.000 contract.py:253(<genexpr>)
#        35    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 linalg.py:102(get_linalg_error_extobj)
#        18    0.000    0.000    0.000    0.000 contract.py:289(<listcomp>)
#         3    0.000    0.000    0.000    0.000 linalg.py:193(_assert_stacked_2d)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:3742(product)
#         9    0.000    0.000    0.000    0.000 contract.py:475(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:544(<listcomp>)
#        12    0.000    0.000    0.000    0.000 index_tricks.py:912(diag_indices)
#         3    0.000    0.000    0.000    0.000 linalg.py:107(_makearray)
#        20    0.000    0.000    0.000    0.000 dispatch.py:60(get_func)
#        18    0.000    0.000    0.000    0.000 contract.py:552(<listcomp>)
#         3    0.000    0.000    0.592    0.197 <__array_function__ internals>:2(eigh)
#        35    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#         3    0.000    0.000    0.000    0.000 linalg.py:199(_assert_stacked_square)
#         3    0.000    0.000    0.000    0.000 _methods.py:60(_all)
#        18    0.000    0.000    0.000    0.000 contract.py:290(<listcomp>)
#         6    0.000    0.000    0.000    0.000 stride_tricks.py:540(<genexpr>)
#         9    0.000    0.000    0.000    0.000 paths.py:1122(get_path_fn)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         9    0.000    0.000    0.000    0.000 contract.py:218(<listcomp>)
#         9    0.000    0.000    0.000    0.000 dispatch.py:94(has_tensordot)
#         3    0.000    0.000    0.000    0.000 function_base.py:4373(<listcomp>)
#        36    0.000    0.000    0.000    0.000 stride_tricks.py:344(<genexpr>)
#         9    0.000    0.000    0.000    0.000 contract.py:74(_choose_memory_arg)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(prod)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(broadcast_arrays)
#         9    0.000    0.000    0.000    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#         6    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:2928(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         3    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         1    0.000    0.000    0.001    0.001 lapack.py:896(get_lapack_funcs)
#         9    0.000    0.000    0.000    0.000 dispatch.py:76(has_einsum)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         3    0.000    0.000    0.004    0.001 <__array_function__ internals>:2(diag)
#         1    0.000    0.000    0.000    0.000 1447296840.py:36(<listcomp>)
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:536(<listcomp>)
#         3    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#         1    0.000    0.000    0.000    0.000 numeric.py:149(ones)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#         6    0.000    0.000    0.000    0.000 linalg.py:112(isComplexType)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 os.py:1073(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 linalg.py:1080(_eigvalsh_dispatcher)
#         3    0.000    0.000    0.000    0.000 misc.py:180(_datacopied)
#         9    0.000    0.000    0.000    0.000 contract.py:489(<listcomp>)
#         1    0.000    0.000    0.000    0.000 abc.py:100(__subclasscheck__)
#         3    0.000    0.000    0.000    0.000 twodim_base.py:230(_diag_dispatcher)
#         3    0.000    0.000    0.000    0.000 parse.py:402(_checknetloc)
#         3    0.000    0.000    0.000    0.000 function_base.py:4243(_meshgrid_dispatcher)
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:474(_broadcast_arrays_dispatcher)
#         1    0.000    0.000    0.000    0.000 multiarray.py:1071(copyto)
