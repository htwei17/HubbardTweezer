# %%
import numpy as np
import os
import sys
# Add ../src to the path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir, "src")))

from HubbardTweezer.tools import reportIO

rep = reportIO.get_report("C:\\Users\\Nottforestfc\\OneDrive - Rice University\\Documents\\Research\\Hubbard Tweezer Parameters\\output\\Hubbard\\3D_8x1_square_None_neq.ini")
matrix = reportIO.a(rep, "Singleband_Parameters", "t_ij")
matrix += np.diag(reportIO.a(rep, "Singleband_Parameters", "V_i"))

# %%
from matplotlib import  colormaps
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# Define a custom colormap
cmap_colors = [(1, 1, 1), (1, 0, 0)]  # White to Red
n_bins = 100  # Discretizes the interpolation into bins
custom_cmap = LinearSegmentedColormap.from_list('custom_cmap', cmap_colors, N=n_bins)

# Create a heatmap
plt.imshow(abs(matrix), cmap=custom_cmap, interpolation='nearest', vmin=0, vmax=0.5)
# plt.colorbar(label='Value')
# plt.imshow(abs(matrix), cmap='hot_r', interpolation='nearest', vmin=0, vmax=0.5)


# Optionally, add text annotations for each cell value
for i in range(matrix.shape[0]):
    plt.text(i, i, f"$\mu_{{{i}}}$", ha="center", va="center")
    if i < matrix.shape[0] - 1:
        plt.text(i, i+1, f"$t_{{{i}{i+1}}}$", ha="center", va="center")
        plt.text(i+1, i, f"$t_{{{i+1}{i}}}$", ha="center", va="center")

# Remove ticks and labels
plt.tick_params(
    axis="both",  # changes apply to both x and y axes
    which="both",  # both major and minor ticks are affected
    bottom=False,  # ticks along the bottom edge are off
    top=False,  # ticks along the top edge are off
    left=False,  # ticks along the left edge are off
    right=False,  # ticks along the right edge are off
    labelbottom=False,  # labels along the bottom edge are off
    labelleft=False,  # labels along the left edge are off
)

# %%
import numpy as np

mat = np.eye(8)

from matplotlib import  colormaps
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# Define a custom colormap
cmap_colors = [(1, 1, 1), (1, 0, 0)]  # White to Red
n_bins = 100  # Discretizes the interpolation into bins
custom_cmap = LinearSegmentedColormap.from_list('custom_cmap', cmap_colors, N=n_bins)

# Create a heatmap
plt.imshow(abs(mat), cmap=custom_cmap, interpolation='nearest', vmin=0, vmax=0.5)
# plt.colorbar(label='Value')
# plt.imshow(abs(matrix), cmap='hot_r', interpolation='nearest', vmin=0, vmax=0.5)


# Optionally, add text annotations for each cell value
# Adjust font size
plt.rcParams.update({'font.size': 22})
for i in range(matrix.shape[0]):
        plt.text(i, i, f"$E_{{{i+1}}}$", ha="center", va="center")
        
        

# Remove ticks and labels
plt.tick_params(
    axis="both",  # changes apply to both x and y axes
    which="both",  # both major and minor ticks are affected
    bottom=False,  # ticks along the bottom edge are off
    top=False,  # ticks along the top edge are off
    left=False,  # ticks along the left edge are off
    right=False,  # ticks along the right edge are off
    labelbottom=False,  # labels along the bottom edge are off
    labelleft=False,  # labels along the left edge are off
)
