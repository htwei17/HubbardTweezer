# %%
# Directives on Jupyter
# %reset
# Auto reload bootstrap.py
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np

import sys
import os

module_path = os.path.abspath(os.path.join("../src"))
if module_path not in sys.path:
    sys.path.append(module_path)

output_path = os.path.abspath("../../../OneDrive - Rice University/Documents/Research/Hubbard Tweezer Parameters/output/GB/")

from HubbardTweezer.Hubbard.plot import *
from HubbardTweezer.Hubbard.io import *

# %%
"test/test_site_target.ini"
# Out:
# True

# %%
any([np.array([1, 2]) is not None, None is not None, np.array([1, 2]) is not None])
# Out:
# True

# %%
any([np.array([1, 2]), [[1, 2], None], np.array([1, 2])])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 any([np.array([1, 2]), [[1, 2], None], np.array([1, 2])])
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
