# %% [markdown]
# # Finite size scaling of 1D Gaussian potential

# %%
# Directives on Jupyter
# %reset
# Auto reload bootstrap.py
# %load_ext autoreload
# %autoreload 2

import numpy as np

# %% [markdown]
# ## Finite size varying N, fixing R

# %%
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os
from plot_dynamics import *

N_list = range(20, 31, 2)
N = 18
# N_list = range(N, N + 1, 2)
R = 3 * np.array([1, 1, 2.4])
freq_list = np.arange(200, 250, 20)
an = 0
d = 1
length = 1
sn = 1000.0

p = plot(
    cvg='N',
    quantity='gs',
    N=N,
    R0=R,
    #  trap=(156, 1.18E-6),
    freq_list=freq_list,
    dim=d,
    model='Gaussian',
    wavefunc=True,
    realtime=False,
    symmetry=True,
    absorber=True)

ax = None
for i in range(len(N_list)):
    ax = plot_dynamics([N_list[i]],
                       R0_list=[R for i in range(len([N_list[i]]))],
                       ax=ax,
                       dvr=p,
                       length=length,
                       avg_no=an,
                       fit=True)
# Out:
# param_set: model is Gaussian potential.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.  3.  7.2]w is set.
# ['x']-reflection symmetry is used.
# DVR: dx=[0.15 0.   0.  ]w is set.
# DVR: n=[20  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05 0.   0.  ]w is set.
# DVR: dx=[0.15 0.   0.  ]w is set.
# DVR: n=[20  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05 0.   0.  ]w is set.
# DVR: dx=[0.15 0.   0.  ]w is set.
# DVR: n=[20  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05 0.   0.  ]w is set.
# DVR: dx=[0.15 0.   0.  ]w is set.
# DVR: n=[20  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05 0.   0.  ]w is set.
# DVR: dx=[0.15 0.   0.  ]w is set.
# DVR: n=[20  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05 0.   0.  ]w is set.
# DVR: dx=[0.15 0.   0.  ]w is set.
# DVR: n=[20  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05 0.   0.  ]w is set.
# DVR: dx=[0.14 0.   0.  ]w is set.
# DVR: n=[22  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95 0.   0.  ]w is set.
# DVR: dx=[0.14 0.   0.  ]w is set.
# DVR: n=[22  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95 0.   0.  ]w is set.
# DVR: dx=[0.14 0.   0.  ]w is set.
# DVR: n=[22  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95 0.   0.  ]w is set.
# DVR: dx=[0.14 0.   0.  ]w is set.
# DVR: n=[22  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95 0.   0.  ]w is set.
# DVR: dx=[0.14 0.   0.  ]w is set.
# DVR: n=[22  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95 0.   0.  ]w is set.
# DVR: dx=[0.14 0.   0.  ]w is set.
# DVR: n=[22  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95 0.   0.  ]w is set.
# DVR: dx=[0.12 0.   0.  ]w is set.
# DVR: n=[24  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.12 0.   0.  ]w is set.
# DVR: n=[24  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.12 0.   0.  ]w is set.
# DVR: n=[24  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.12 0.   0.  ]w is set.
# DVR: n=[24  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.12 0.   0.  ]w is set.
# DVR: n=[24  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.12 0.   0.  ]w is set.
# DVR: n=[24  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.12 0.   0.  ]w is set.
# DVR: n=[26  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04 0.   0.  ]w is set.
# DVR: dx=[0.12 0.   0.  ]w is set.
# DVR: n=[26  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04 0.   0.  ]w is set.
# DVR: dx=[0.12 0.   0.  ]w is set.
# DVR: n=[26  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04 0.   0.  ]w is set.
# DVR: dx=[0.12 0.   0.  ]w is set.
# DVR: n=[26  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04 0.   0.  ]w is set.
# DVR: dx=[0.12 0.   0.  ]w is set.
# DVR: n=[26  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04 0.   0.  ]w is set.
# DVR: dx=[0.12 0.   0.  ]w is set.
# DVR: n=[26  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04 0.   0.  ]w is set.
# DVR: dx=[0.11 0.   0.  ]w is set.
# DVR: n=[28  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96 0.   0.  ]w is set.
# DVR: dx=[0.11 0.   0.  ]w is set.
# DVR: n=[28  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96 0.   0.  ]w is set.
# DVR: dx=[0.11 0.   0.  ]w is set.
# DVR: n=[28  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96 0.   0.  ]w is set.
# DVR: dx=[0.11 0.   0.  ]w is set.
# DVR: n=[28  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96 0.   0.  ]w is set.
# DVR: dx=[0.11 0.   0.  ]w is set.
# DVR: n=[28  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96 0.   0.  ]w is set.
# DVR: dx=[0.11 0.   0.  ]w is set.
# DVR: n=[28  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96 0.   0.  ]w is set.
# DVR: dx=[0.1 0.  0. ]w is set.
# DVR: n=[30  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.1 0.  0. ]w is set.
# DVR: n=[30  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.1 0.  0. ]w is set.
# DVR: n=[30  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.1 0.  0. ]w is set.
# DVR: n=[30  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.1 0.  0. ]w is set.
# DVR: n=[30  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.1 0.  0. ]w is set.
# DVR: n=[30  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.

# %%
from plot_dynamics import *
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os

N_list = range(16, 31, 1)
# N = 18
d = 1
R = 3 * np.array([1, 1, 2.4])
freq_list = np.arange(200, 250, 10)
an = 0
length = 1
# t0 = 17.9
t0 = np.inf
L = 1
sn = 1000.0
st = get_stop_time(freq_list)
st_list = [i * st for i in np.array([1E-2, .1, .5, 1, 5])]
gamma = 57.04

# for i in range(len(N_list)):
#     dvr = dynamics(
#         N=N_list[i],
#         R0=R,
#         freq_list=freq_list,
#         dim=d,
#         model='Gaussian',
#         wavefunc=False,
#         realtime=False,
#         symmetry=True,
#         #    ab_param=(gamma, L),
#         absorber=True)
#     DVR_exe(dvr)

# os.system('mv -f *.h5 ../output')

p = plot(cvg='N',
         quantity='gs',
         N=N_list[0],
         R0=R,
         freq_list=freq_list,
         dim=d,
         model='Gaussian',
         wavefunc=True,
         realtime=False,
         symmetry=True,
         absorber=True)

ax = plot_lifetime(
    N_list,
    R0_list=[R for i in range(len(N_list))],
    dvr=p,
    avg_no=an,
    length=2,
    #  tau=t0,
    #  file=True,
    extrapolte=-12)
# Out:
# param_set: model is Gaussian potential.
# DVR: dx=[0.19]w is set.
# DVR: n=[16] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21  0  0] by adding absorber.
# DVR: R=[3.94]w is set.
# ['x']-reflection symmetry is used.
# DVR: dx=[0.19]w is set.
# DVR: n=[16] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21  0  0] by adding absorber.
# DVR: R=[3.94]w is set.
# DVR: dx=[0.18]w is set.
# DVR: n=[17] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[4.06]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.16]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.13]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[24] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[25] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[26] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[27] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[28] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[29] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [39  0  0] by adding absorber.
# DVR: R=[4.03]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[30] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.19]w is set.
# DVR: n=[16] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21  0  0] by adding absorber.
# DVR: R=[3.94]w is set.
# DVR: dx=[0.18]w is set.
# DVR: n=[17] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[4.06]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.16]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.13]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[24] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[25] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[26] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[27] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[28] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[29] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [39  0  0] by adding absorber.
# DVR: R=[4.03]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[30] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.19]w is set.
# DVR: n=[16] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21  0  0] by adding absorber.
# DVR: R=[3.94]w is set.
# DVR: dx=[0.18]w is set.
# DVR: n=[17] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[4.06]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.16]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.13]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[24] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[25] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[26] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[27] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[28] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[29] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [39  0  0] by adding absorber.
# DVR: R=[4.03]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[30] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.19]w is set.
# DVR: n=[16] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21  0  0] by adding absorber.
# DVR: R=[3.94]w is set.
# DVR: dx=[0.18]w is set.
# DVR: n=[17] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[4.06]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.16]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.13]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[24] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[25] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[26] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[27] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[28] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[29] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [39  0  0] by adding absorber.
# DVR: R=[4.03]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[30] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.19]w is set.
# DVR: n=[16] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21  0  0] by adding absorber.
# DVR: R=[3.94]w is set.
# DVR: dx=[0.18]w is set.
# DVR: n=[17] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[4.06]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.16]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.13]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[24] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[25] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[26] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[27] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[28] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[29] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [39  0  0] by adding absorber.
# DVR: R=[4.03]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[30] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.19]w is set.
# DVR: n=[16] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21  0  0] by adding absorber.
# DVR: R=[3.94]w is set.
# DVR: dx=[0.18]w is set.
# DVR: n=[17] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[4.06]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.16]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.13]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[24] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[25] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[26] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[27] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[28] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[29] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [39  0  0] by adding absorber.
# DVR: R=[4.03]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[30] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.19]w is set.
# DVR: n=[16] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21  0  0] by adding absorber.
# DVR: R=[3.94]w is set.
# DVR: dx=[0.18]w is set.
# DVR: n=[17] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[4.06]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.16]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.13]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[24] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[25] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[26] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[27] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[28] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[29] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [39  0  0] by adding absorber.
# DVR: R=[4.03]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[30] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.19]w is set.
# DVR: n=[16] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21  0  0] by adding absorber.
# DVR: R=[3.94]w is set.
# DVR: dx=[0.18]w is set.
# DVR: n=[17] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[4.06]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.16]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.13]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[24] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[25] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[26] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[27] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[28] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[29] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [39  0  0] by adding absorber.
# DVR: R=[4.03]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[30] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.19]w is set.
# DVR: n=[16] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21  0  0] by adding absorber.
# DVR: R=[3.94]w is set.
# DVR: dx=[0.18]w is set.
# DVR: n=[17] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[4.06]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.16]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.13]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[24] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[25] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[26] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[27] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[28] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[29] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [39  0  0] by adding absorber.
# DVR: R=[4.03]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[30] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.19]w is set.
# DVR: n=[16] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21  0  0] by adding absorber.
# DVR: R=[3.94]w is set.
# DVR: dx=[0.18]w is set.
# DVR: n=[17] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[4.06]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.16]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.05]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.14]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[3.95]w is set.
# DVR: dx=[0.13]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[24] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[25] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.12]w is set.
# DVR: n=[26] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[4.04]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[27] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.11]w is set.
# DVR: n=[28] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [37  0  0] by adding absorber.
# DVR: R=[3.96]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[29] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [39  0  0] by adding absorber.
# DVR: R=[4.03]w is set.
# DVR: dx=[0.1]w is set.
# DVR: n=[30] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [40  0  0] by adding absorber.
# DVR: R=[4.]w is set.

# %% [markdown]
# ## Finite size varying R, fixing dx

# %%
from plot_dynamics import *
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os

N_list = range(16, 31, 1)
N = 18
d = 1
freq_list = np.arange(200, 250, 10)
an = 0
length = 1
# t0 = 17.9
t0 = np.inf
L = 1
sn = 1000.0
st = get_stop_time(freq_list)
dx = 3 / 18 * np.array([1, 1, 2.4], dtype=float)
R0_list = [dx * n for n in N_list]

# for i in range(len(R0_list)):
#     dvr = dynamics(
#         N=N_list[i],
#         R0=R0_list[i],
#         freq_list=freq_list,
#         dim=d,
#         model='Gaussian',
#         wavefunc=False,
#         realtime=False,
#         symmetry=True,
#         absorber=True)
#     DVR_exe(dvr)

# os.system('mv -f *.h5 ../output')

p = plot(cvg='R',
         quantity='gs',
         N=N_list[0],
         R0=R0_list[0],
         freq_list=freq_list,
         dim=d,
         model='Gaussian',
         wavefunc=True,
         realtime=False,
         symmetry=True,
         absorber=True)

ax = plot_lifetime(
    N_list,
    R0_list,
    dvr=p,
    avg_no=an,
    length=2,
    #  tau=t0,
    #  file=True,
    extrapolte=-12)
# Out:
# param_set: model is Gaussian potential.
# DVR: dx=[0.17]w is set.
# DVR: n=[16] is set.
# DVR: R0=[2.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22  0  0] by adding absorber.
# DVR: R=[3.67]w is set.
# ['x']-reflection symmetry is used.
# DVR: dx=[0.17]w is set.
# DVR: n=[16] is set.
# DVR: R0=[2.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22  0  0] by adding absorber.
# DVR: R=[3.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[17] is set.
# DVR: R0=[2.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[3.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[4.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [26  0  0] by adding absorber.
# DVR: R=[4.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[4.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[24] is set.
# DVR: R0=[4.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [30  0  0] by adding absorber.
# DVR: R=[5.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[25] is set.
# DVR: R0=[4.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[5.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[26] is set.
# DVR: R0=[4.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[5.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[27] is set.
# DVR: R0=[4.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[5.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[28] is set.
# DVR: R0=[4.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [34  0  0] by adding absorber.
# DVR: R=[5.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[29] is set.
# DVR: R0=[4.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[5.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[30] is set.
# DVR: R0=[5.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[6.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[16] is set.
# DVR: R0=[2.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22  0  0] by adding absorber.
# DVR: R=[3.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[17] is set.
# DVR: R0=[2.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[3.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[4.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [26  0  0] by adding absorber.
# DVR: R=[4.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[4.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[24] is set.
# DVR: R0=[4.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [30  0  0] by adding absorber.
# DVR: R=[5.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[25] is set.
# DVR: R0=[4.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[5.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[26] is set.
# DVR: R0=[4.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[5.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[27] is set.
# DVR: R0=[4.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[5.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[28] is set.
# DVR: R0=[4.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [34  0  0] by adding absorber.
# DVR: R=[5.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[29] is set.
# DVR: R0=[4.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[5.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[30] is set.
# DVR: R0=[5.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[6.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[16] is set.
# DVR: R0=[2.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22  0  0] by adding absorber.
# DVR: R=[3.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[17] is set.
# DVR: R0=[2.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[3.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[4.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [26  0  0] by adding absorber.
# DVR: R=[4.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[4.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[24] is set.
# DVR: R0=[4.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [30  0  0] by adding absorber.
# DVR: R=[5.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[25] is set.
# DVR: R0=[4.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[5.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[26] is set.
# DVR: R0=[4.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[5.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[27] is set.
# DVR: R0=[4.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[5.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[28] is set.
# DVR: R0=[4.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [34  0  0] by adding absorber.
# DVR: R=[5.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[29] is set.
# DVR: R0=[4.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[5.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[30] is set.
# DVR: R0=[5.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[6.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[16] is set.
# DVR: R0=[2.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22  0  0] by adding absorber.
# DVR: R=[3.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[17] is set.
# DVR: R0=[2.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[3.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[4.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [26  0  0] by adding absorber.
# DVR: R=[4.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[4.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[24] is set.
# DVR: R0=[4.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [30  0  0] by adding absorber.
# DVR: R=[5.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[25] is set.
# DVR: R0=[4.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[5.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[26] is set.
# DVR: R0=[4.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[5.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[27] is set.
# DVR: R0=[4.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[5.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[28] is set.
# DVR: R0=[4.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [34  0  0] by adding absorber.
# DVR: R=[5.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[29] is set.
# DVR: R0=[4.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[5.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[30] is set.
# DVR: R0=[5.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[6.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[16] is set.
# DVR: R0=[2.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22  0  0] by adding absorber.
# DVR: R=[3.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[17] is set.
# DVR: R0=[2.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[3.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[4.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [26  0  0] by adding absorber.
# DVR: R=[4.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[4.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[24] is set.
# DVR: R0=[4.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [30  0  0] by adding absorber.
# DVR: R=[5.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[25] is set.
# DVR: R0=[4.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[5.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[26] is set.
# DVR: R0=[4.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[5.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[27] is set.
# DVR: R0=[4.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[5.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[28] is set.
# DVR: R0=[4.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [34  0  0] by adding absorber.
# DVR: R=[5.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[29] is set.
# DVR: R0=[4.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[5.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[30] is set.
# DVR: R0=[5.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[6.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[16] is set.
# DVR: R0=[2.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22  0  0] by adding absorber.
# DVR: R=[3.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[17] is set.
# DVR: R0=[2.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[3.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[4.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [26  0  0] by adding absorber.
# DVR: R=[4.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[4.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[24] is set.
# DVR: R0=[4.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [30  0  0] by adding absorber.
# DVR: R=[5.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[25] is set.
# DVR: R0=[4.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[5.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[26] is set.
# DVR: R0=[4.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[5.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[27] is set.
# DVR: R0=[4.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[5.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[28] is set.
# DVR: R0=[4.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [34  0  0] by adding absorber.
# DVR: R=[5.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[29] is set.
# DVR: R0=[4.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[5.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[30] is set.
# DVR: R0=[5.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[6.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[16] is set.
# DVR: R0=[2.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22  0  0] by adding absorber.
# DVR: R=[3.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[17] is set.
# DVR: R0=[2.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[3.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[4.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [26  0  0] by adding absorber.
# DVR: R=[4.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[4.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[24] is set.
# DVR: R0=[4.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [30  0  0] by adding absorber.
# DVR: R=[5.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[25] is set.
# DVR: R0=[4.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[5.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[26] is set.
# DVR: R0=[4.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[5.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[27] is set.
# DVR: R0=[4.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[5.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[28] is set.
# DVR: R0=[4.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [34  0  0] by adding absorber.
# DVR: R=[5.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[29] is set.
# DVR: R0=[4.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[5.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[30] is set.
# DVR: R0=[5.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[6.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[16] is set.
# DVR: R0=[2.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22  0  0] by adding absorber.
# DVR: R=[3.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[17] is set.
# DVR: R0=[2.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[3.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[4.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [26  0  0] by adding absorber.
# DVR: R=[4.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[4.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[24] is set.
# DVR: R0=[4.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [30  0  0] by adding absorber.
# DVR: R=[5.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[25] is set.
# DVR: R0=[4.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[5.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[26] is set.
# DVR: R0=[4.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[5.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[27] is set.
# DVR: R0=[4.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[5.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[28] is set.
# DVR: R0=[4.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [34  0  0] by adding absorber.
# DVR: R=[5.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[29] is set.
# DVR: R0=[4.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[5.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[30] is set.
# DVR: R0=[5.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[6.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[16] is set.
# DVR: R0=[2.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22  0  0] by adding absorber.
# DVR: R=[3.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[17] is set.
# DVR: R0=[2.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[3.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[4.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [26  0  0] by adding absorber.
# DVR: R=[4.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[4.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[24] is set.
# DVR: R0=[4.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [30  0  0] by adding absorber.
# DVR: R=[5.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[25] is set.
# DVR: R0=[4.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[5.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[26] is set.
# DVR: R0=[4.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[5.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[27] is set.
# DVR: R0=[4.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[5.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[28] is set.
# DVR: R0=[4.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [34  0  0] by adding absorber.
# DVR: R=[5.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[29] is set.
# DVR: R0=[4.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[5.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[30] is set.
# DVR: R0=[5.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[6.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[16] is set.
# DVR: R0=[2.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22  0  0] by adding absorber.
# DVR: R=[3.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[17] is set.
# DVR: R0=[2.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23  0  0] by adding absorber.
# DVR: R=[3.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[18] is set.
# DVR: R0=[3.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[19] is set.
# DVR: R0=[3.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25  0  0] by adding absorber.
# DVR: R=[4.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [26  0  0] by adding absorber.
# DVR: R=[4.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[21] is set.
# DVR: R0=[3.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27  0  0] by adding absorber.
# DVR: R=[4.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[22] is set.
# DVR: R0=[3.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [28  0  0] by adding absorber.
# DVR: R=[4.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[23] is set.
# DVR: R0=[3.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [29  0  0] by adding absorber.
# DVR: R=[4.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[24] is set.
# DVR: R0=[4.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [30  0  0] by adding absorber.
# DVR: R=[5.]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[25] is set.
# DVR: R0=[4.17]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [31  0  0] by adding absorber.
# DVR: R=[5.17]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[26] is set.
# DVR: R0=[4.33]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [32  0  0] by adding absorber.
# DVR: R=[5.33]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[27] is set.
# DVR: R0=[4.5]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [33  0  0] by adding absorber.
# DVR: R=[5.5]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[28] is set.
# DVR: R0=[4.67]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [34  0  0] by adding absorber.
# DVR: R=[5.67]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[29] is set.
# DVR: R0=[4.83]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [35  0  0] by adding absorber.
# DVR: R=[5.83]w is set.
# DVR: dx=[0.17]w is set.
# DVR: n=[30] is set.
# DVR: R0=[5.]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [36  0  0] by adding absorber.
# DVR: R=[6.]w is set.

# %% [markdown]
# ### Check stop time

# %%
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os
from plot_dynamics import *

d = 1
N = 18
N_list = range(N, N + 1, 2)
R = 3 * np.array([1, 1, 2.4])
freq_list = np.arange(100, 250, 10)
an = 0
# t0 = 17.9
t0 = np.inf
L = 1
sn = 1000.0
st = get_stop_time(freq_list)
st_list = [i * st for i in np.array([1E-2, .1, .5, 1, 5])]
gamma = 57.04

# for i in range(len(st_list)):
#     dvr = dynamics(N=N,
#                    R0=R,
#                    freq_list=freq_list,
#                    time=(sn, st_list[i]),
#                    dim=d,
#                    model='Gaussian',
#                    wavefunc=False,
#                    realtime=False,
#                    symmetry=True,
#                    ab_param=(gamma, L),
#                    absorber=True)
#     DVR_exe(dvr)

# os.system('mv -f *.h5 ../output')

st_list = [i * st for i in np.array([1E-2, .1, .5, 1, 5])]
ax = None
for i in range(len(st_list)):
    p = plot(cvg='N',
             quantity='gs',
             N=N,
             R0=R,
             freq_list=freq_list,
             dim=d,
             time=(sn, st_list[i]),
             model='Gaussian',
             wavefunc=False,
             realtime=False,
             symmetry=True,
             ab_param=(gamma, L),
             absorber=True)
    ax = plot_lifetime(N_list,
                       R0_list=[R for i in range(len(N_list))],
                       dvr=p,
                       ext_ax=ax,
                       err=False,
                       avg_no=an,
                       tau=t0)
# Out:
# param_set: model is Gaussian potential.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.  3.  7.2]w is set.
# ['x']-reflection symmetry is used.
# Dynamic time step=3.5023e-06 is too small compared to driving period 1e-05. Set time step to driving period.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# param_set: model is Gaussian potential.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.  3.  7.2]w is set.
# ['x']-reflection symmetry is used.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# param_set: model is Gaussian potential.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.  3.  7.2]w is set.
# ['x']-reflection symmetry is used.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# param_set: model is Gaussian potential.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.  3.  7.2]w is set.
# ['x']-reflection symmetry is used.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# param_set: model is Gaussian potential.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4.  3.  7.2]w is set.
# ['x']-reflection symmetry is used.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
# DVR: dx=[0.17 0.   0.  ]w is set.
# DVR: n=[18  0  0] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24  0  0] by adding absorber.
# DVR: R=[4. 0. 0.]w is set.
