# %% [markdown]
# # Equalization

# %%
# Directives on Jupyter
# %reset
# Auto reload bootstrap.py
# %load_ext autoreload
# %autoreload 2

import numpy as np

# %% [markdown]
# ### Waseem 1D parameters

# %%
from plot_Hubbard import *
import numpy as np
from positify import positify

N = 20
R0 = np.array([3, 3, 7.2])
G = Graph(N,
          R0=R0,
          lattice=np.array([4], dtype=int),
          band=1,
          dim=1,
          avg=1 / 2,
          sparse=True,
          equalize=True,
          symmetry=True)
G.draw_graph('adjust')
# Out:
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# ['x']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1000nm
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes: [4 1 1]
# lattice: lattice constants: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 80 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [2 1 0 3]
# Order of Wannier function is set to match trap site.
#
# Current offset: [1. 1.]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 46 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 1 0 3]
# Order of Wannier function is set to match trap site.
# Current cost: 1.014906753709483
#
#
# Current offset: [1.00000001 1.        ]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 60 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 3 0 2]
# Order of Wannier function is set to match trap site.
# Current cost: 1.0149062971260887
#
#
# Current offset: [1.         1.00000001]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 70 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 0 3 2]
# Order of Wannier function is set to match trap site.
# Current cost: 1.0149072338037175
#
#
# Current offset: [1.1 0.9]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 58 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 3 2 1]
# Order of Wannier function is set to match trap site.
# Current cost: 8.114477265627192
#
#
# Current offset: [1.09999999 0.9       ]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 65 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 3 2 0]
# Order of Wannier function is set to match trap site.
# Current cost: 8.114476782525395
#
#
# Current offset: [1.1        0.90000001]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 69 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 3 2 0]
# Order of Wannier function is set to match trap site.
# Current cost: 8.114476818467764
#
#
# Current offset: [1.01733211 0.98266789]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 49 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 2 1 3]
# Order of Wannier function is set to match trap site.
# Current cost: 0.5713327079812717
#
#
# Current offset: [1.01733212 0.98266789]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 61 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.571333111377809
#
#
# Current offset: [1.01733211 0.9826679 ]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 66 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 3 0 2]
# Order of Wannier function is set to match trap site.
# Current cost: 0.5713322062362022
#
#
# Current offset: [1.00881444 0.99118556]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 66 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.20868435031242158
#
#
# Current offset: [1.00881445 0.99118556]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 62 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 0 1]
# Order of Wannier function is set to match trap site.
# Current cost: 0.2086838722104132
#
#
# Current offset: [1.00881444 0.99118557]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 65 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 0 2 1]
# Order of Wannier function is set to match trap site.
# Current cost: 0.20868479187529118
#
#
# Current offset: [1.01310717 0.98689283]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 48 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 3 2 1]
# Order of Wannier function is set to match trap site.
# Current cost: 0.18494913242633554
#
#
# Current offset: [1.01310718 0.98689283]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 48 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 1 0 2]
# Order of Wannier function is set to match trap site.
# Current cost: 0.18494954139597525
#
#
# Current offset: [1.01310717 0.98689284]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 62 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 0 1 2]
# Order of Wannier function is set to match trap site.
# Current cost: 0.18494864038126085
#
#
# Current offset: [1.01098279 0.98901721]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 67 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 0 1]
# Order of Wannier function is set to match trap site.
# Current cost: 0.01585793422060545
#
#
# Current offset: [1.0109828  0.98901721]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 69 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 3 2 1]
# Order of Wannier function is set to match trap site.
# Current cost: 0.015857284182747504
#
#
# Current offset: [1.01098279 0.98901722]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 73 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [2 3 0 1]
# Order of Wannier function is set to match trap site.
# Current cost: 0.015857829467066042
#
#
# Current offset: [1.05741426 0.96341889]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 61 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 2 0 3]
# Order of Wannier function is set to match trap site.
# Current cost: 3.424496032171443
#
#
# Current offset: [1.05741427 0.96341889]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 63 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 0 1 2]
# Order of Wannier function is set to match trap site.
# Current cost: 3.4244966134164296
#
#
# Current offset: [1.05741426 0.9634189 ]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 60 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 2 3 0]
# Order of Wannier function is set to match trap site.
# Current cost: 3.4244957553359443
#
#
# Current offset: [1.01669218 0.98586954]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 64 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 0 1 2]
# Order of Wannier function is set to match trap site.
# Current cost: 0.4090541991651829
#
#
# Current offset: [1.01669219 0.98586954]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 63 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 1 3 2]
# Order of Wannier function is set to match trap site.
# Current cost: 0.4090547455495457
#
#
# Current offset: [1.01669218 0.98586955]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 55 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 1 3 2]
# Order of Wannier function is set to match trap site.
# Current cost: 0.4090539077071447
#
#
# Current offset: [1.01171803 0.98861186]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 89 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [2 3 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.042192963151138276
#
#
# Current offset: [1.01171804 0.98861186]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 62 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.042193440847236925
#
#
# Current offset: [1.01171803 0.98861187]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 66 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 2 1 3]
# Order of Wannier function is set to match trap site.
# Current cost: 0.042192553088732564
#
#
# Current offset: [1.01114319 0.98892878]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 77 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 3 2 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.009020161169191621
#
#
# Current offset: [1.0111432  0.98892878]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 58 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 0 3 1]
# Order of Wannier function is set to match trap site.
# Current cost: 0.009019755095972658
#
#
# Current offset: [1.01114319 0.98892879]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 71 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 0 1 3]
# Order of Wannier function is set to match trap site.
# Current cost: 0.009019602878805115
#
#
# Current offset: [1.01457722 0.99074123]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 51 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 3 2 1]
# Order of Wannier function is set to match trap site.
# Current cost: 0.2562299262196958
#
#
# Current offset: [1.01457723 0.99074123]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 49 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 1 2 3]
# Order of Wannier function is set to match trap site.
# Current cost: 0.25623052757606785
#
#
# Current offset: [1.01457722 0.99074124]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 57 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 1 2 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.2562302626958026
#
#
# Current offset: [1.01162534 0.98918325]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 74 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 0 1 3]
# Order of Wannier function is set to match trap site.
# Current cost: 0.02915669702658331
#
#
# Current offset: [1.01162535 0.98918325]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 68 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 0 2 1]
# Order of Wannier function is set to match trap site.
# Current cost: 0.02915731949739103
#
#
# Current offset: [1.01162534 0.98918326]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 67 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 1 2 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.029156964283439512
#
#
# Current offset: [1.01124596 0.98898301]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 56 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 0 2 3]
# Order of Wannier function is set to match trap site.
# Current cost: 0.0037570865138292775
#
#
# Current offset: [1.01124597 0.98898301]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 65 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 3 1 2]
# Order of Wannier function is set to match trap site.
# Current cost: 0.0037573739751935366
#
#
# Current offset: [1.01124596 0.98898302]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 69 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.0037565086638344024
#
#
# Current offset: [1.01125486 0.98920668]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 56 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.011943255149922711
#
#
# Current offset: [1.01125487 0.98920668]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 68 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 1 3 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.011943401883347894
#
#
# Current offset: [1.01125486 0.98920669]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 73 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.011943926059966142
#
#
# Current offset: [1.01124781 0.98902959]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 60 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 2 0 3]
# Order of Wannier function is set to match trap site.
# Current cost: 0.0018067254960158052
#
#
# Current offset: [1.01124782 0.98902959]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 73 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [0 3 2 1]
# Order of Wannier function is set to match trap site.
# Current cost: 0.0018073776929885008
#
#
# Current offset: [1.01124781 0.9890296 ]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 45 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 0 3 2]
# Order of Wannier function is set to match trap site.
# Current cost: 0.0018066273020835894
#
#
# Current offset: [1.01114933 0.98911149]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 50 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 2 3 1]
# Order of Wannier function is set to match trap site.
# Current cost: 0.006797598765166938
#
#
# Current offset: [1.01114934 0.98911149]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 63 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.006797133470437922
#
#
# Current offset: [1.01114933 0.9891115 ]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 59 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 2 3 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.006798106873851194
#
#
# Current offset: [1.01122821 0.98904589]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 74 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.0009397840321005147
#
#
# Current offset: [1.01122822 0.98904589]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 52 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 0.0009401698335991367
#
#
# Current offset: [1.01122821 0.9890459 ]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 67 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 0 3 2]
# Order of Wannier function is set to match trap site.
# Current cost: 0.0009403532051378371
#
#
# Current offset: [1.01118931 0.9890278 ]
# ...
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 77 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 7.42087482588382e-08
#
#
# Current offset: [-1.49938635  0.         -0.49646894  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 72 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 1 3 0]
# Order of Wannier function is set to match trap site.
# Current cost: 7.660165467957937e-08
#
#
# Current offset: [-1.49938634  0.         -0.49646894  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 69 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 3 0 2]
# Order of Wannier function is set to match trap site.
# Current cost: 7.505142832045917e-08
#
#
# Current offset: [-1.49938635  0.         -0.49646893  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 57 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 1 0 2]
# Order of Wannier function is set to match trap site.
# Current cost: 7.556856931348063e-08
#
#
# Current offset: [-1.49938635  0.         -0.49646894  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 55 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 2 0 1]
# Order of Wannier function is set to match trap site.
# Current cost: 7.507536435189753e-08
#
#
# Current offset: [-1.49938634  0.         -0.49646894  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 66 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 1 0 3]
# Order of Wannier function is set to match trap site.
# Current cost: 7.499158893721107e-08
#
#
# Current offset: [-1.49938635  0.         -0.49646893  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 68 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 2 0 3]
# Order of Wannier function is set to match trap site.
# Current cost: 7.901276505732024e-08
#
#
# Current offset: [-1.49938635  0.         -0.49646894  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 60 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 3 2 1]
# Order of Wannier function is set to match trap site.
# Current cost: 7.766574251674602e-08
#
#
# Current offset: [-1.49938634  0.         -0.49646894  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 75 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 7.497130662194486e-08
#
#
# Current offset: [-1.49938635  0.         -0.49646893  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 62 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 1 0 3]
# Order of Wannier function is set to match trap site.
# Current cost: 7.295670183875932e-08
#
#
# Current offset: [-1.49938635  0.         -0.49646894  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 54 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 2 1 3]
# Order of Wannier function is set to match trap site.
# Current cost: 7.572145088064972e-08
#
#
# Current offset: [-1.49938634  0.         -0.49646894  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 70 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 1 0]
# Order of Wannier function is set to match trap site.
# Current cost: 7.499146258975022e-08
#
#
# Current offset: [-1.49938635  0.         -0.49646893  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 59 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 0 1]
# Order of Wannier function is set to match trap site.
# Current cost: 7.596253994769479e-08
#
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# Tunneling homogenized.
#
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 52 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 1 0 3]
# Order of Wannier function is set to match trap site.
#
# Start to plot graph...

# %%
from plot_Hubbard import *
import numpy as np
from positify import positify

N = 20
R0 = np.array([3, 3, 7.2])
G = Graph(N,
          R0=R0,
          lattice=np.array([4], dtype=int),
          band=1,
          dim=1,
          avg=1 / 2,
          sparse=True,
          equalize=True,
          symmetry=True)
G.draw_graph('adjust')
# Out:
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# ['x']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1000nm
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes: [4 1 1]
# lattice: lattice constants: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 60 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [3 1 2 0]
# Order of Wannier function is set to match trap site.
#
# Current trap depths: [1. 1.]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 68 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 3 0 2]
# Order of Wannier function is set to match trap site.
# Current total cost: 1.0149067356411194
#
#
# Current trap depths: [1.00000001 1.        ]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 83 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 1.0149062810568912
#
#
# Current trap depths: [1.         1.00000001]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 67 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [0 3 2 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 1.0149072299698811
#
#
# Current trap depths: [1.1 0.9]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 77 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [0 2 1 3]
# Order of Wannier function is set to match trap site.
# Current total cost: 8.1144772256734
#
#
# Current trap depths: [1.09999999 0.9       ]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 47 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 1 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 8.114476778140899
#
#
# Current trap depths: [1.1        0.90000001]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 62 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 2 3 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 8.114476802496625
#
#
# Current trap depths: [1.01711345 0.98288655]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 65 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 0 2 3]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.5513258804668646
#
#
# Current trap depths: [1.01711346 0.98288655]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 47 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 3 2 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.5513263001320319
#
#
# Current trap depths: [1.01711345 0.98288656]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 60 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 2 0 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.5513253649453304
#
#
# Current trap depths: [1.00861906 0.99138094]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 64 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 0 2 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.22653389963754697
#
#
# Current trap depths: [1.00861907 0.99138094]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 78 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [1 2 0 3]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.22653343683158558
#
#
# Current trap depths: [1.00861906 0.99138095]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 73 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 1 0 3]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.2265343564169954
#
#
# Current trap depths: [1.01283053 0.98716947]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 58 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 0 2 3]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.15969815042517074
#
#
# Current trap depths: [1.01283054 0.98716947]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 66 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 1 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.15969858070798898
#
#
# Current trap depths: [1.01283053 0.98716948]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 47 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 0 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.15969764993726393
#
#
# Current trap depths: [1.01071207 0.98928793]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 71 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 3 2 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.03680973138206633
#
#
# Current trap depths: [1.01071208 0.98928793]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 75 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 0 2 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.03680915247028049
#
#
# Current trap depths: [1.01071207 0.98928794]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 76 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [0 2 3 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.03681000859782134
#
#
# Current trap depths: [1.01172706 0.98827294]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 55 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 1 0 3]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.05953506969121048
#
#
# Current trap depths: [1.01172707 0.98827294]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 67 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 1 2 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.059535385098815174
#
#
# Current trap depths: [1.01172706 0.98827295]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 55 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 1 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.05953449931818356
#
#
# Current trap depths: [1.01071207 0.98928793]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 55 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 0 1 3]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.036809737781751596
#
#
# Current trap depths: [1.01071208 0.98928793]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 58 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 0 1 2]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.03680913943051856
#
#
# Current trap depths: [1.01071207 0.98928794]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 63 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 1 2 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.036809998559610715
#
#
# Current trap depths: [1.1 0.9]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 65 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 0 2 3]
# Order of Wannier function is set to match trap site.
# Current total cost: 8.114477262845757
#
#
# Current trap depths: [1.09999999 0.9       ]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 59 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 2 3 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 8.114476777518963
#
#
# Current trap depths: [1.1        0.90000001]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 71 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 1 3 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 8.11447677158945
#
#
# Current trap depths: [1.02306649 0.97693351]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 76 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [0 1 2 3]
# Order of Wannier function is set to match trap site.
# Current total cost: 1.096081456613849
#
#
# Current trap depths: [1.0230665  0.97693351]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 66 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 0 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 1.0960819193909432
#
#
# Current trap depths: [1.02306649 0.97693352]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 66 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 1 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 1.0960809731888568
#
#
# Current trap depths: [1.01248465 0.98751535]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 52 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 2 3 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.12816302197428572
#
#
# Current trap depths: [1.01248466 0.98751535]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 64 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 1 0 2]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.12816342768833905
#
#
# Current trap depths: [1.01248465 0.98751536]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 70 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.12816251378592863
#
#
# Current trap depths: [1.01108485 0.98891515]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 53 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 3 1 2]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.012413587089559372
#
#
# Current trap depths: [1.01108486 0.98891515]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 60 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.012413082491447139
#
#
# Current trap depths: [1.01108485 0.98891516]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 70 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 2 1 3]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.012413121830010981
#
#
# Current trap depths: [1.01160786 0.98896249]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 50 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 0 3 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.025794033006028935
#
#
# Current trap depths: [1.01160787 0.98896249]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 53 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 0 1 2]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.02579469345833147
#
#
# Current trap depths: [1.01160786 0.9889625 ]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 68 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 1 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.025793945465755506
#
#
# Current trap depths: [1.01122103 0.98892747]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 61 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 3 1 2]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.007203919972006463
#
#
# Current trap depths: [1.01122104 0.98892747]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 78 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [2 0 3 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.007203869073234412
#
#
# Current trap depths: [1.01122103 0.98892748]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 60 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 3 2 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.007203247073817952
#
#
# Current trap depths: [1.01144374 0.98934078]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 60 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 3 2 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.026074785572111746
#
#
# Current trap depths: [1.01144375 0.98934078]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 66 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 1 0]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.026075190701101567
#
#
# Current trap depths: [1.01144374 0.98934079]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 53 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 0 3 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.026075344516857123
#
#
# Current trap depths: [1.01126582 0.98901061]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 71 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 3 2 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.0033073283067656003
#
#
# Current trap depths: [1.01126583 0.98901061]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 69 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [2 1 0 3]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.0033078956883286163
#
#
# Current trap depths: [1.01126582 0.98901062]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 54 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 2 0 3]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.0033070337796621283
#
#
# Current trap depths: [1.01117995 0.98914847]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 52 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 3 0 1]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.007976958539265028
#
#
# Current trap depths: [1.01117996 0.98914847]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 50 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 0 1 2]
# Order of Wannier function is set to match trap site.
# Current total cost: 0.007976752866210036
#
#
# Current trap depths: [1.01117995 0.98914848]
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# ...
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 78 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 66 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 2 1 3]
# Order of Wannier function is set to match trap site.
# Finite scale factor a=0.08 is included.
# Tunneling cost t=6.200986914482994e-08
# Onsite potential cost v=0.06705335960425574
# Current total cost: 0.005364330778209604
#
#
# Current trap centers: [-1.49938634  0.         -0.49646894  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 53 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 58 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 1 3 2]
# Order of Wannier function is set to match trap site.
# Finite scale factor a=0.08 is included.
# Tunneling cost t=3.858928292803588e-08
# Onsite potential cost v=0.06705316112703731
# Current total cost: 0.005364291479445913
#
#
# Current trap centers: [-1.49938633  0.         -0.49646894  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 57 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 3 2 0]
# Order of Wannier function is set to match trap site.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 62 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 1 2 3]
# Order of Wannier function is set to match trap site.
# Finite scale factor a=0.08 is included.
# Tunneling cost t=4.751855164137951e-08
# Onsite potential cost v=0.06705315470629952
# Current total cost: 0.005364299895055603
#
#
# Current trap centers: [-1.49938634  0.         -0.49646893  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 51 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 1 2 0]
# Order of Wannier function is set to match trap site.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 57 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 3 2 0]
# Order of Wannier function is set to match trap site.
# Finite scale factor a=0.08 is included.
# Tunneling cost t=6.226292267785919e-08
# Onsite potential cost v=0.06705334452110985
# Current total cost: 0.005364329824611466
#
#
# Current trap centers: [-1.49938634  0.         -0.49646894  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 63 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 2 3 0]
# Order of Wannier function is set to match trap site.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 51 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 1 2 0]
# Order of Wannier function is set to match trap site.
# Finite scale factor a=0.08 is included.
# Tunneling cost t=3.878151147190857e-08
# Onsite potential cost v=0.06705314171125454
# Current total cost: 0.005364290118411835
#
#
# Current trap centers: [-1.49938633  0.         -0.49646894  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 68 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 2 1 0]
# Order of Wannier function is set to match trap site.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 55 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 1 2 0]
# Order of Wannier function is set to match trap site.
# Finite scale factor a=0.08 is included.
# Tunneling cost t=4.673371289035833e-08
# Onsite potential cost v=0.06705315710919121
# Current total cost: 0.0053642993024481875
#
#
# Current trap centers: [-1.49938634  0.         -0.49646893  0.        ]
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 60 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [2 1 3 0]
# Order of Wannier function is set to match trap site.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 65 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [3 1 2 0]
# Order of Wannier function is set to match trap site.
# Finite scale factor a=0.08 is included.
# Tunneling cost t=6.160067600779592e-08
# Onsite potential cost v=0.06705335590988856
# Current total cost: 0.005364330073467093
#
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes updated to: [4 1 1]
# lattice: lattice constants updated to: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# Tunneling homogenized.
#
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 49 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [1 2 0 3]
# Order of Wannier function is set to match trap site.
#
# Start to plot graph...

# %%
G.draw_graph()
# Out:
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 49 iterations, 0.01 seconds.
#
# Trap site position of Wannier functions: [0 2 3 1]
# Order of Wannier function is set to match trap site.
#
# Start to plot graph...

# %%
from plot_Hubbard import *
import numpy as np
from positify import positify

N = 20
R0 = np.array([3, 3, 7.2])
G = Graph(N,
          R0=R0,
          lattice=np.array([4], dtype=int),
          band=1,
          dim=1,
          avg=1 / 2,
          sparse=True,
          symmetry=True)
G.Voff = np.array([1.01122067, 0.9890345, 0.9890345, 1.01122067])
G.trap_centers = np.array([[-1.49938633, -0.], [-0.49646893, -0.],
                           [0.49646893, -0.], [1.49938633, -0.]])
G.draw_graph()
# Out:
# DVR: dx=[0.15]w is set.
# DVR: n=[20] is set.
# DVR: R0=[3.]w is set.
# ['x']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1000nm
# lattice: dx is fixed at: [0.15 0.   0.  ]w
# lattice: Full lattice sizes: [4 1 1]
# lattice: lattice constants: [1.52 1.69 1.52]w
# DVR: dx=[0.15]w is set.
# DVR: n=[35] is set.
# DVR: R0=[5.28]w is set.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian sparse diagonalization is enabled. Lowest 4 states are to be calculated.
# H_op: n=[35] dx=[0.15]w p=[-1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.00 MiB.
# Optimizing...
# Terminated - min grad norm reached after 63 iterations, 0.02 seconds.
#
# Trap site position of Wannier functions: [0 2 3 1]
# Order of Wannier function is set to match trap site.
#
# Start to plot graph...

# %%
G.
# Out:
# {0: '-94.6', 1: '-94.7', 2: '-94.7', 3: '-94.6'}
