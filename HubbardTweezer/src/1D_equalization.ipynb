# %% [markdown]
# # 1D equalization analysis

# %% [markdown]
# ### 8x1 chain no waist

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists, G.sf = read_trap(report)
G.draw_graph(nnn=True, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
nnt = G.nn_tunneling(G.A)
xlinks, ylinks, txTarget, tyTarget = G.xy_links(nnt)
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None, txTarget))}')
print(
    f't_err = {np.sqrt(G.t_cost_func(G.A, (xlinks, ylinks), (txTarget, tyTarget)))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None, txTarget))}')
# Out:
# V = [ 1.05081005 -0.3276607  -0.36048292 -0.36266644 -0.36266644 -0.36048292
#  -0.3276607   1.05081005]
# t = [0.62065988 0.50139018 0.49634266 0.49601698 0.49634266 0.50139018
#  0.62065988]
# U = [0.57223066 0.52368636 0.50915316 0.5150087  0.5150087  0.50915316
#  0.52368636 0.57223066]
# V_err = 1.1379941876064814
# t_err = 0.10373867367104843
# U_err = 0.046718414763182115

# %% [markdown]
# #### `'vT'`

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'vT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 method=meth,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists, G.sf = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
nnt = G.nn_tunneling(G.A)
xlinks, ylinks, txTarget, tyTarget = G.xy_links(nnt)
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None, txTarget))}')
print(
    f't_err = {np.sqrt(G.t_cost_func(G.A, (xlinks, ylinks), (txTarget, tyTarget)))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None, txTarget))}')
# Out:
# V = [-3.27915473e-11  9.06652531e-12  1.16671117e-11  1.20792265e-11
#   1.20721211e-11  1.16529009e-11  9.05941988e-12 -3.27844418e-11]
# t = [0.53325749 0.53325749 0.53325749 0.53325749 0.53325749 0.53325749
#  0.53325749]
# U = [0.60331758 0.50025087 0.48694056 0.49177927 0.49177927 0.48694056
#  0.50025087 0.60331758]
# V_err = 3.5567928684576277e-11
# t_err = 5.044862535574151e-11
# U_err = 0.09003172223830472

# %% [markdown]
# #### `'UvT'`

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'UvT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 method=meth,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists, G.sf = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
nnt = G.nn_tunneling(G.A)
xlinks, ylinks, txTarget, tyTarget = G.xy_links(nnt)
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None, txTarget))}')
print(
    f't_err = {np.sqrt(G.t_cost_func(G.A, (xlinks, ylinks), (txTarget, tyTarget)))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None, txTarget))}')
# Out:
# V = [ 0.00205415 -0.00121466 -0.00056146 -0.00027802 -0.00027802 -0.00056146
#  -0.00121466  0.00205415]
# t = [0.53668405 0.52364942 0.52138543 0.52206825 0.52138543 0.52364942
#  0.53668405]
# U = [0.60283701 0.50195998 0.49051934 0.49558737 0.49558737 0.49051934
#  0.50195998 0.60283701]
# V_err = 0.002343091190684621
# t_err = 0.012343348193458467
# U_err = 0.0881849490436977

# %% [markdown]
# ##### `'Uv'`

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'Uv'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 method=meth,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists, G.sf = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
cv = np.sqrt(G.v_cost_func(G.A, None, G.sf))
ct = np.sqrt(G.t_cost_func(G.A, None, None))
cu = np.sqrt(G.u_cost_func(G.U, None, G.sf))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {cv}')
print(f't_err = {ct}')
print(f'U_err = {cu}')
# Out:
# V = [ 0.00172453 -0.00164595  0.00020525 -0.00028383 -0.00028383  0.00020525
#  -0.00164595  0.00172453]
# t = [1.06951717 0.11220047 0.86495601 0.15559306 0.86495601 0.11220047
#  1.06951717]
# U = [0.55765598 0.51357912 0.53007212 0.52153277 0.52153277 0.53007212
#  0.51357912 0.55765598]
# V_err = 0.002259253593601141
# t_err = 0.6973927818686859
# U_err = 0.031156829099811673

# %% [markdown]
# This is making a SSH like pattern that can actually pretty well equalize both $U$ and $V$, which was previously thought to be hard due to competing.

# %% [markdown]
# #### UT: error part

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'UT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 method=meth,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists, G.sf = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
cv = np.sqrt(G.v_cost_func(G.A, None, G.sf))
ct = np.sqrt(G.t_cost_func(G.A, None, None))
cu = np.sqrt(G.u_cost_func(G.U, None, G.sf))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {cv}')
print(f't_err = {ct}')
print(f'U_err = {cu}')
# Out:
# V = [ 1.46684801 -0.32282016 -0.63043175 -0.5135961  -0.5135961  -0.63043175
#  -0.32282016  1.46684801]
# t = [0.54934748 0.52835622 0.50732172 0.50008385 0.50732172 0.52835622
#  0.54934748]
# U = [0.5714015  0.52764335 0.51003247 0.51207277 0.51207277 0.51003247
#  0.52764335 0.5714015 ]
# V_err = 1.6014275371000053
# t_err = 0.03568647370485024
# U_err = 0.046309929481967715

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'UT'
meth = 'NM'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 method=meth,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists, G.sf = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
cv = np.sqrt(G.v_cost_func(G.A, None, G.sf))
ct = np.sqrt(G.t_cost_func(G.A, None, None))
cu = np.sqrt(G.u_cost_func(G.U, None, G.sf))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {cv}')
print(f't_err = {ct}')
print(f'U_err = {cu}')
# Out:
# V = [ 1.37812785 -0.20454042 -0.47798958 -0.69559785 -0.69559785 -0.47798958
#  -0.20454042  1.37812785]
# t = [0.54686798 0.5389516  0.52587876 0.49842691 0.52587876 0.5389516
#  0.54686798]
# U = [0.55517168 0.53134525 0.49793091 0.51823059 0.51823059 0.49793091
#  0.53134525 0.55517168]
# V_err = 1.527336381562989
# t_err = 0.029654463511321894
# U_err = 0.038969457380866865

# %% [markdown]
# ### 8x1 chain $x$ waist

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = 'x'
eqt = 'Uv'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 method=meth,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists, G.sf = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
cv = np.sqrt(G.v_cost_func(G.A, None, G.sf))
ct = np.sqrt(G.t_cost_func(G.A, None, None))
cu = np.sqrt(G.u_cost_func(G.U, None, G.sf))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {cv}')
print(f't_err = {ct}')
print(f'U_err = {cu}')
# Out:
# V = [ 2.52299515e-10 -2.81730195e-11 -6.66062761e-11 -1.57534430e-10
#  -1.57548641e-10 -6.66133815e-11 -2.81659140e-11  2.52299515e-10]
# t = [0.93980672 0.27840557 0.63118346 0.36266622 0.63118346 0.27840557
#  0.93980672]
# U = [0.53001972 0.53001972 0.53001972 0.53001972 0.53001972 0.53001972
#  0.53001972 0.53001972]
# V_err = 2.8702114226359724e-10
# t_err = 0.45753940033730117
# U_err = 2.9967588386926266e-11

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = 'x'
eqt = 'UvT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 method=meth,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists, G.sf = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
nnt = G.nn_tunneling(G.A)
xlinks, ylinks, txTarget, tyTarget = G.xy_links(nnt)
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None, txTarget))}')
print(
    f't_err = {np.sqrt(G.t_cost_func(G.A, (xlinks, ylinks), (txTarget, tyTarget)))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None, txTarget))}')
# Out:
# V = [-9.94759830e-14  7.81597009e-14  0.00000000e+00  3.55271368e-14
#   2.13162821e-14 -7.10542736e-15  6.39488462e-14 -9.94759830e-14]
# t = [0.53325749 0.53325749 0.53325749 0.53325749 0.53325749 0.53325749
#  0.53325749]
# U = [0.53001972 0.53001972 0.53001972 0.53001972 0.53001972 0.53001972
#  0.53001972 0.53001972]
# V_err = 1.1813821740009321e-13
# t_err = 7.712642150443393e-14
# U_err = 1.2186384304909499e-14

# %% [markdown]
# ### 4x1 chain no waist UT

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 4
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'UT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 method=meth,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/Convergence analysis/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
c = rep.a(report, "Equalization_Log", "cost_func_value")

import matplotlib.pyplot as plt

plt.plot(c, 'o')
plt.ylim(1e-2, 0.1)
plt.yscale('log')

# %%
plt.plot(c, '-')
plt.yscale('log')

# %% [markdown]
# 19 evaluations, 18 peaks in the func evals
#
# Usually when Voff is varied a little bit to calculate gradient, the func val is greatly shifted to ~1

# %%
G.symm_unfold(G.trap_centers, np.array([[-1.50191679,  0.],
                                        [-0.49426382,  0.]]), graph=True)
G.symm_unfold(G.Voff, np.array([0.99107376, 1.00888942]))
G.sf = .5828346670502338
G.singleband_Hubbard(u=True)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
cv = np.sqrt(G.v_cost_func(G.A, None, G.sf))
ct = np.sqrt(G.t_cost_func(G.A, None, None))
cu = np.sqrt(G.u_cost_func(G.U, None, G.sf))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {cv}')
print(f't_err = {ct}')
print(f'U_err = {cu}')
# Out:
# V = [ 0.91709976 -0.91709976 -0.91709976  0.91709976]
# t = [0.26926703 0.28590869 0.26926703]
# U = [1.15051069 1.09589021 1.09589021 1.15051069]
# V_err = 1.573516143744224
# t_err = 0.02854638782803843
# U_err = 0.04685761177883136

# %%
cvec = np.array([cu, ct, cv])
w = np.array([1, 1, 0])
la.norm(w @ cvec)
# Out:
# 0.07540404106442862

# %%
G.symm_unfold(G.trap_centers, np.array([[-1.50191679,  0.],
                                        [-0.49426382,  0.]]), graph=True)
G.symm_unfold(G.Voff, np.array([0.99107376, 1.00888942]))
G.sf = .5828346670502338
G.singleband_Hubbard(u=True)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
cv = G.v_res_func(G.A, None, G.sf)
ct = G.t_res_func(G.A, None, None)
cu = G.u_res_func(G.U, None, G.sf)
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {cv}')
print(f't_err = {ct}')
print(f'U_err = {cu}')
# Out:
# V = [ 0.91709976 -0.91709976 -0.91709976  0.91709976]
# t = [0.26926703 0.28590869 0.26926703]
# U = [1.15051069 1.09589021 1.09589021 1.15051069]
# V_err = [ 0.78675807 -0.78675807 -0.78675807  0.78675807]
# t_err = [-0.01165401  0.02330803 -0.01165401]
# U_err = [ 0.02342881 -0.02342881 -0.02342881  0.02342881]
