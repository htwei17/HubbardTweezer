# %% [markdown]
# # Zigzag

# %% [markdown]
# ### Sanity check by comparing (2a, 0) to 1D chain

# %%
import matplotlib.pyplot as plt
from Hubbard.core import *
import numpy as np

N = 20
R0 = np.array([3, 3, 7.2])
W = MLWF(N,
         R0=R0,
         lattice=np.array([4, 2], dtype=int),
         lc=(3000, 0),
         band=1,
         dim=3,
         shape='zigzag',
         sparse=True,
         symmetry=True)

x = np.linspace(-W.R0[0] * 0.8, W.R0[0] * 0.8, 500)
X = np.meshgrid(x, x)
V = W.Vfun(*X, 0)

plt.pcolormesh(*X, V)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1000nm
# lattice: lattice shape is zigzag; lattice constants set to: (3000, 0)
# Triangular lattice size adjust to: [4 2]
# lattice: lattice shape is zigzag
# lattice: Full lattice sizes: [4 2]
# lattice: lattice constants: [3. 0.]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[55 20 20] is set.
# DVR: R0=[8.25 3.   7.2 ]w is set.

# %%
import matplotlib.pyplot as plt
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=1550,
                 ascatt=1770,
                 laser=780,
                 band=1,
                 dim=d,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 lattice_symmetry=True,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G = read_trap(report, G)
G.draw_graph(A=G.A, U=G.U)
# Out:
# lattice: lattice shape is square; lattice constants set to: (1550, 1550)
# Equalize: scale_factor is not a number. Set to None.

# %%
import matplotlib.pyplot as plt
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 4
Ly = 2
d = 3
shape = 'zigzag'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=(3100, 0),
                 ascatt=1770,
                 laser=780,
                 dim=d,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 lattice_symmetry=False,
                 symmetry=True,
                 verbosity=3)
fn = f'../output/3100/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G = read_trap(report, G)
G.draw_graph(A=G.A, U=G.U)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=52.26kHz w=1000nm
# lattice: lattice shape is zigzag; lattice constants set to: (3100, 0)
# Triangular lattice size adjust to: [4 2]
# lattice: lattice shape is zigzag
# lattice: Full lattice sizes: [4 2]
# lattice: lattice constants: [3.1 0. ]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[56 20 20] is set.
# DVR: R0=[8.425 3.    7.2  ]w is set.
# Equalize: scale_factor is not a number. Set to None.
#
# Start to plot graph...

# %% [markdown]
# The two agree well.

# %%
import matplotlib.pyplot as plt
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'vT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=1550,
                 ascatt=1770,
                 laser=780,
                 band=1,
                 dim=d,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqmethod=meth,
                 eqtarget=eqt,
                 lattice_symmetry=True,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G = read_trap(report, G)
G.draw_graph(A=G.A, U=G.U)
# Out:
# lattice: lattice shape is square; lattice constants set to: (1550, 1550)
# Equalize: scale_factor is not a number. Set to None.

# %%
import matplotlib.pyplot as plt
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 4
Ly = 2
d = 3
shape = 'zigzag'
w = None
eqt = 'vT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=(3100, 0),
                 ascatt=1770,
                 laser=780,
                 dim=d,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqmethod=meth,
                 eqtarget=eqt,
                 lattice_symmetry=False,
                 symmetry=True,
                 verbosity=3)
fn = f'../output/3100/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G = read_trap(report, G)
G.draw_graph(A=G.A, U=G.U)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=52.26kHz w=1000nm
# lattice: lattice shape is zigzag; lattice constants set to: (3100, 0)
# Triangular lattice size adjust to: [4 2]
# lattice: lattice shape is zigzag
# lattice: Full lattice sizes: [4 2]
# lattice: lattice constants: [3.1 0. ]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[56 20 20] is set.
# DVR: R0=[8.425 3.    7.2  ]w is set.
# Equalize: scale_factor is not a number. Set to None.
#
# Start to plot graph...

# %% [markdown]
# ## Nontrivial case

# %%
import matplotlib.pyplot as plt
from Hubbard.core import *
import numpy as np

N = 20
R0 = np.array([3, 3, 7.2])
W = MLWF(N,
         R0=R0,
         lattice=np.array([4, 2], dtype=int),
         lc=(2400, 1000),
         band=1,
         dim=3,
         avg=1 / 2,
         shape='zigzag',
         sparse=True,
         symmetry=True)

x = np.linspace(-W.R0[0] * 0.8, W.R0[0] * 0.8, 500)
X = np.meshgrid(x, x)
V = W.Vfun(*X, 0)

plt.pcolormesh(*X, V)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=52.26kHz w=1000nm
# lattice: lattice shape is zigzag; lattice constants set to: (2400, 1000)
# Triangular lattice size adjust to: [4 2]
# lattice: lattice shape is zigzag
# lattice: Full lattice sizes: [4 2]
# lattice: lattice constants: [2.4 1. ]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[48 23 20] is set.
# DVR: R0=[7.2 3.5 7.2]w is set.

# %%
import matplotlib.pyplot as plt
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 4
Ly = 2
d = 3
shape = 'zigzag'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(73.0219, 1000),
                 lc=(2400, 1000),
                 ascatt=1770,
                 laser=780,
                 band=1,
                 dim=d,
                 avg=1,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 lattice_symmetry=False,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G = read_trap(report, G)
G.draw_graph(nnn=True, A=G.A, U=G.U)
# Out:
# lattice: lattice shape is zigzag; lattice constants set to: (2400, 1000)
# Triangular lattice size adjust to: [4 2]
# Equalize: scale_factor is not a number. Set to None.

# %%
import matplotlib.pyplot as plt
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 4
Ly = 2
d = 3
shape = 'zigzag'
w = None
eqt = 'vT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(73.0219, 1000),
                 lc=(2400, 1000),
                 ascatt=1770,
                 laser=780,
                 band=1,
                 dim=d,
                 avg=1,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 lattice_symmetry=False,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
c = rep.a(report, "Equalization_Log", "cost_func_value")
G = read_trap(report, G)

plt.plot(c, '-')
plt.yscale('log')

G.draw_graph(A=G.A, U=G.U)
print(c[-1])
print(c[-2] - c[-1])
# Out:
# lattice: lattice shape is zigzag; lattice constants set to: (2400, 1000)
# Triangular lattice size adjust to: [4 2]
# Equalize: scale_factor is not a number. Set to None.
# 0.010289284373965701
# 0.0034684819335496116
