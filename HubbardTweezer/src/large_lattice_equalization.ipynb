# %% [markdown]
# # Large lattice Hubbard parameter equalization

# %% [markdown]
# ### 8x1 chain

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_parameters(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
# V = [-35.09276912 -36.47123987 -36.50406209 -36.50624561 -36.50624561
#  -36.50406209 -36.47123987 -35.09276912]
# t = [0.62065988 0.50139018 0.49634266 0.49601698 0.49634266 0.50139018
#  0.62065988]
# U = [0.57223066 0.52368636 0.50915316 0.5150087  0.5150087  0.50915316
#  0.52368636 0.57223066]
# V_err = 0.00028189780728694907
# t_err = 0.010761712415048088
# U_err = 0.0022093578222907614

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_parameters(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# V = [-100.67788254 -100.28440131 -101.06199516 -101.66750036 -101.66750036
#  -101.06199516 -100.28440131 -100.67788254]
# t = [0.02048734 0.02048866 0.02048077 0.02048741 0.02048077 0.02048866
#  0.02048734]
# U = [1.48009102 1.48495257 1.47157407 1.46108297 1.46108297 1.47157407
#  1.48495257 1.48009102]
# V_err = 0.005056009828683803
# t_err = 0.0001590648115294013
# U_err = 0.00615165582037634

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_parameters(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# V = [-28.72094576 -28.72094576 -28.72094569 -28.72094576 -28.72094576
#  -28.72094569 -28.72094576 -28.72094576]
# t = [0.20488951 0.20488951 0.20488951 0.20488951 0.20488951 0.20488951
#  0.20488951]
# U = [0.49859204 0.49859204 0.49859204 0.49859204 0.49859204 0.49859204
#  0.49859204 0.49859204]
# V_err = 1.060608958124161e-09
# t_err = 2.528722379220967e-09
# U_err = 1.925086937059502e-09

# %% [markdown]
# ### 3x3 Lieb

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 3
d = 3
shape = 'Lieb'
w = None
eqt = 'uv'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, L], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{L}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_parameters(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# Lieb lattice size adjust to: [3 3]
# V = [-35.92892762 -35.77101324 -35.92892763 -35.79352649 -35.79352648
#  -35.92892762 -35.77101324 -35.92892765]
# t = [0.13938346 0.13938345 0.14234877 0.14234877 0.14234877 0.13938346
#  0.14234876 0.13938345]
# U = [0.72335162 0.72578811 0.72335162 0.72564001 0.72564001 0.72335162
#  0.72578811 0.72335162]
# V_err = 0.0020571296823899414
# t_err = 2.6736084884952474e-08
# U_err = 0.0016319197774883015

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 3
d = 3
shape = 'Lieb'
w = 'xy'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, L], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{L}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_parameters(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# Lieb lattice size adjust to: [3 3]
# V = [-34.81336729 -34.81336873 -34.81336731 -34.81336989 -34.81336985
#  -34.81336728 -34.81336873 -34.81336729]
# t = [0.11600791 0.11600791 0.12661598 0.12661598 0.12661598 0.11600791
#  0.12661598 0.11600791]
# U = [0.71726308 0.71726293 0.71726308 0.71726281 0.71726282 0.71726309
#  0.71726293 0.71726308]
# V_err = 3.107065215909901e-08
# t_err = 3.5978585457268993e-09
# U_err = 1.5818062631158356e-07

# %% [markdown]
# ### 3x3 square

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 3
d = 3
shape = 'square'
w = 'xy'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, L], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{L}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_parameters(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# V = [-35.26939056 -35.6384751  -35.26939054 -36.28677532 -36.43146081
#  -36.28677537 -35.26939058 -35.6384751  -35.26939055]
# t = [0.09694077 0.09694077 0.17915249 0.17639615 0.09635225 0.17915243
#  0.09635225 0.17915253 0.17639615 0.09694077 0.17915244 0.09694077]
# U = [0.70663464 0.69902416 0.70663465 0.68886129 0.68056718 0.68886128
#  0.70663464 0.69902416 0.70663465]
# V_err = 0.013111151512780054
# t_err = 0.00783383584463415
# U_err = 0.013259876328977313
