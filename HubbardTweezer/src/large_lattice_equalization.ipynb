# %% [markdown]
# # Large lattice Hubbard parameter equalization

# %% [markdown]
# ### 8x1 chain

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
# V = [-35.09276912 -36.47123987 -36.50406209 -36.50624561 -36.50624561
#  -36.50406209 -36.47123987 -35.09276912]
# t = [0.62065988 0.50139018 0.49634266 0.49601698 0.49634266 0.50139018
#  0.62065988]
# U = [0.57223066 0.52368636 0.50915316 0.5150087  0.5150087  0.50915316
#  0.52368636 0.57223066]
# V_err = 0.0002818978072869493
# t_err = 0.010761712415048077
# U_err = 0.002209357822290761

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'vt'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# V = [-35.42080651 -35.42010358 -35.41573809 -35.41714947 -35.41714947
#  -35.41573809 -35.42010358 -35.42080651]
# t = [0.49980033 0.49979133 0.49977059 0.49980939 0.49977059 0.49979133
#  0.49980033]
# U = [0.60753791 0.51221241 0.49867026 0.50343713 0.50343713 0.49867026
#  0.51221241 0.60753791]
# V_err = 5.877340211181231e-05
# t_err = 2.7728493103790794e-05
# U_err = 0.08438400800153151

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# V = [-34.63255346 -36.37377061 -36.6781255  -36.65503056 -36.65503056
#  -36.6781255  -36.37377061 -34.63255346]
# t = [0.52778461 0.51875128 0.51252515 0.51098154 0.51252515 0.51875128
#  0.52778461]
# U = [0.57473485 0.53147768 0.50856889 0.5121071  0.5121071  0.50856889
#  0.53147768 0.57473485]
# V_err = 0.023472793356427258
# t_err = 0.012636482417842232
# U_err = 0.049499593298694015

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# V = [-28.72094576 -28.72094576 -28.72094569 -28.72094576 -28.72094576
#  -28.72094569 -28.72094576 -28.72094576]
# t = [0.20488951 0.20488951 0.20488951 0.20488951 0.20488951 0.20488951
#  0.20488951]
# U = [0.49859204 0.49859204 0.49859204 0.49859204 0.49859204 0.49859204
#  0.49859204 0.49859204]
# V_err = 1.060608961057463e-09
# t_err = 2.5287223933926486e-09
# U_err = 1.925086935568178e-09

# %% [markdown]
# ### 3x3 Lieb

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 3
d = 3
shape = 'Lieb'
w = None
eqt = 'uv'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, L], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{L}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# Lieb lattice size adjust to: [3 3]
# V = [-36.16347585 -36.16296898 -36.16347582 -36.16299405 -36.16299406
#  -36.16347582 -36.16296901 -36.16347582]
# t = [0.11506893 0.11506893 0.11604813 0.11604813 0.11604813 0.11506893
#  0.11604813 0.11506893]
# U = [0.74176765 0.74177623 0.74176765 0.74177655 0.74177655 0.74176765
#  0.74177623 0.74176765]
# V_err = 6.838715146874799e-06
# t_err = 2.4090242382346976e-09
# U_err = 5.891816104219989e-06

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 3
d = 3
shape = 'Lieb'
w = 'xy'
eqt = 'uv'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, L], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{L}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# Lieb lattice size adjust to: [3 3]
# V = [-35.27037613 -35.27037345 -35.27037612 -35.27037224 -35.27037229
#  -35.27037612 -35.27037345 -35.27037607]
# t = [0.12787327 0.12787327 0.1939649  0.1939649  0.1939649  0.12787327
#  0.1939649  0.12787327]
# U = [0.71226633 0.71226643 0.71226633 0.7122665  0.7122665  0.71226633
#  0.71226643 0.71226634]
# V_err = 4.761897691351344e-08
# t_err = 2.877338467337087e-09
# U_err = 9.869928231700692e-08

# %% [markdown]
# ### 3x3 square

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 3
d = 3
shape = 'square'
w = None
eqt = 'vt'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, L], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{L}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# V = [-36.31718043 -36.31718025 -36.31718046 -36.31718017 -36.31718049
#  -36.31718014 -36.31718043 -36.31718025 -36.31718043]
# t = [0.10160779 0.10160778 0.24297509 0.24297508 0.10160778 0.24297509
#  0.10160779 0.24297509 0.24297509 0.10160779 0.24297509 0.10160779]
# U = [0.71339576 0.67295127 0.71339576 0.64550414 0.60676374 0.64550414
#  0.71339576 0.67295127 0.71339576]
# V_err = 3.4731264061360627e-09
# t_err = 3.580761168182546e-08
# U_err = 0.054449318079074625

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 3
d = 3
shape = 'square'
w = None
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, L], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{L}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# V = [-35.70629082 -36.05853231 -35.70629082 -36.72917793 -37.1542261
#  -36.72917794 -35.70629084 -36.0585323  -35.70629083]
# t = [0.08925459 0.08925459 0.28751793 0.28752132 0.08925448 0.28751793
#  0.08925448 0.28751797 0.2875213  0.08925459 0.28751795 0.08925459]
# U = [0.69322784 0.66264367 0.69322784 0.64816629 0.61958077 0.64816629
#  0.69322784 0.66264367 0.69322784]
# V_err = 0.014508776733964649
# t_err = 5.546008277843575e-06
# U_err = 0.03777220442350199

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.output import *

N = 20
L = 3
d = 3
shape = 'square'
w = 'xy'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, L], dtype=int),
                 band=1,
                 dim=d,
                 avg=0.5,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{L}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.Voff, G.trap_centers, G.waists = read_trap(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {np.sqrt(G.v_cost_func(G.A, None))}')
print(f't_err = {np.sqrt(G.t_cost_func(G.A, None, None))}')
print(f'U_err = {np.sqrt(G.u_cost_func(G.U, None))}')
# Out:
# V = [-35.26939056 -35.6384751  -35.26939054 -36.28677532 -36.43146081
#  -36.28677537 -35.26939058 -35.6384751  -35.26939055]
# t = [0.09694077 0.09694077 0.17915249 0.17639615 0.09635225 0.17915243
#  0.09635225 0.17915253 0.17639615 0.09694077 0.17915244 0.09694077]
# U = [0.70663464 0.69902416 0.70663465 0.68886129 0.68056718 0.68886128
#  0.70663464 0.69902416 0.70663465]
# V_err = 0.013111151512780033
# t_err = 0.007833835844634134
# U_err = 0.013259876328977334
