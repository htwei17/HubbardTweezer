# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 4
Ly = 5
d = 3
shape = 'kagome'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=1550,
                 ascatt=1770,
                 laser=780,
                 band=1,
                 dim=d,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 lattice_symmetry=True,
                 symmetry=True,
                 verbosity=0)
G.draw_graph()
# Out:
# lattice: lattice shape is kagome; lattice constants set to: (1550, 1342.33937586588)
# Kagome lattice size adjust to: [4 5]
# Triangular lattice size adjust to: [4 5]
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
# WARNING: total distance = 0.6789414623714591. Assignment might be non-local.

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 6
Ly = 5
d = 3
shape = 'defecthoneycomb'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=1550,
                 ascatt=1770,
                 laser=780,
                 band=1,
                 dim=d,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 lattice_symmetry=True,
                 symmetry=True,
                 verbosity=0)
G.draw_graph()
# Out:
# lattice: lattice shape is defecthoneycomb; lattice constants set to: (1550, 1550)
# Honeycomb lattice size adjust to: [6 5]
# Triangular lattice size adjust to: [6 5]
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
# WARNING: total distance = 0.5668140099181884. Assignment might be non-local.
