# %% [markdown]
# # Test least_squares

# %% [markdown]
# #### Test bounds

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.io import *

N = 20
L = 4
d = 1
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([L], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize_lsq(eqt)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
print(G.eqinfo['Nfeval'])
# Out:
# Varying waist direction: x.
# Equalization method: trf
# Equalization target: uvt
#
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.7858e-03                                    1.27e-01
#        1              2         3.4738e-04      2.44e-03       4.91e-03       6.33e-04
#        2              3         4.7796e-05      3.00e-04       6.47e-02       7.37e-03
#        3              4         1.4837e-05      3.30e-05       1.24e-02       2.35e-04
#        4              5         2.5421e-07      1.46e-05       2.72e-02       1.58e-04
#        5              6         7.6751e-10      2.53e-07       3.03e-03       5.33e-06
#        6              7         4.5885e-15      7.68e-10       2.64e-04       2.18e-08
# `gtol` termination condition is satisfied.
# Function evaluations 7, initial cost 2.7858e-03, final cost 4.5885e-15, first-order optimality 2.18e-08.
# Equalization took 0.5344679355621338 seconds.
# V = [-46.1327956 -46.132799  -46.132799  -46.1327956]
# t = [0.12348377 0.1234837  0.12348377]
# U = [2.1335744  2.13357405 2.13357405 2.1335744 ]
# V_err = 1.3595610435191294e-15
# t_err = 7.388727135652391e-14
# U_err = 6.844932551542404e-15
# 49

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.output import *

N = 20
L = 4
d = 1
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([L], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize_lsq(eqt, nobounds=True)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
print(G.eqinfo['Nfeval'])
# Out:
# Varying waist direction: x.
# Equalization method: trf
# Equalization target: uvt
#
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.7858e-03                                    1.27e+00
#        1              2         7.4038e-05      2.71e-03       9.98e-02       2.16e-01
#        2              3         9.1217e-09      7.40e-05       1.46e-02       2.38e-03
#        3              4         6.7828e-16      9.12e-09       1.68e-04       6.92e-07
#        4              5         8.6303e-27      6.78e-16       5.94e-09       2.43e-12
# `gtol` termination condition is satisfied.
# Function evaluations 5, initial cost 2.7858e-03, final cost 8.6303e-27, first-order optimality 2.43e-12.
# Equalization took 0.33736586570739746 seconds.
# V = [-44.59612312 -44.59612299 -44.59612299 -44.59612312]
# t = [0.16265313 0.16265303 0.16265313]
# U = [2.10070657 2.10070659 2.10070659 2.10070657]
# V_err = 2.3325698405477222e-18
# t_err = 7.853876060206992e-14
# U_err = 2.7855835282400614e-17
# 35

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.output import *

N = 20
L = 4
d = 2
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([L], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize_lsq(eqt, nobounds=True)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
print(G.eqinfo['Nfeval'])
# Out:
# Varying waist direction: x.
# Equalization method: trf
# Equalization target: uvt
#
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.7001e-03                                    1.17e+00
#        1              2         6.0220e-05      2.64e-03       1.65e-01       2.02e-01
#        2              3         5.3528e-09      6.02e-05       1.03e-02       1.85e-03
#        3              4         8.1614e-15      5.35e-09       4.30e-04       1.96e-06
#        4              5         1.0172e-25      8.16e-15       1.31e-07       8.38e-12
# `gtol` termination condition is satisfied.
# Function evaluations 5, initial cost 2.7001e-03, final cost 1.0172e-25, first-order optimality 8.38e-12.
# Equalization took 4.04982590675354 seconds.
# V = [-38.76256525 -38.7625651  -38.7625651  -38.76256525]
# t = [0.27145666 0.2714565  0.27145666]
# U = [2.54644366 2.5464437  2.5464437  2.54644366]
# V_err = 3.684431503508159e-18
# t_err = 7.727391356080874e-14
# U_err = 4.1535091113261915e-17
# 35

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.io import *

N = 20
L = 4
d = 2
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([L], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize_lsq(eqt)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
# Varying waist direction: x.
# Equalization method: trf
# Equalization target: uvt
#
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.7001e-03                                    1.17e-01
#        1              2         3.3725e-04      2.36e-03       5.39e-03       6.25e-04
#        2              3         4.5365e-05      2.92e-04       6.85e-02       6.09e-03
#        3              4         1.4327e-05      3.10e-05       1.45e-02       2.17e-04
#        4              5         2.2595e-07      1.41e-05       2.94e-02       3.00e-05
#        5              6         9.1174e-11      2.26e-07       3.34e-03       1.51e-06
#        6              7         6.5186e-17      9.12e-11       4.88e-05       1.21e-09
# `gtol` termination condition is satisfied.
# Function evaluations 7, initial cost 2.7001e-03, final cost 6.5186e-17, first-order optimality 1.21e-09.
# Equalization took 4.107007026672363 seconds.
# V = [-37.44933805 -37.44933843 -37.44933843 -37.44933805]
# t = [0.15130268 0.15130259 0.15130268]
# U = [2.5442662  2.54426618 2.54426618 2.5442662 ]
# V_err = 5.081724953892747e-09
# t_err = 2.647508694226757e-07
# U_err = 4.795298533777369e-09

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.output import *

N = 20
L = 4
d = 3
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([L], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize_lsq(eqt)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
# Varying waist direction: x.
# Equalization method: trf
# Equalization target: uvt
#
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.3736e-03                                    1.23e-01
#        1              2         5.8095e-04      2.79e-03       1.38e-02       4.20e-03
#        2              3         1.3524e-04      4.46e-04       1.02e-01       1.68e-02
#        3              4         8.6489e-05      4.87e-05       1.04e-02       1.31e-04
#        4              5         1.5832e-05      7.07e-05       7.79e-02       3.42e-04
#        5              6         8.3207e-07      1.50e-05       3.06e-02       1.06e-04
#        6              7         4.8646e-08      7.83e-07       1.84e-02       3.22e-04
#        7              8         3.0126e-08      1.85e-08       5.22e-05       3.42e-05
#        8              9         2.5227e-10      2.99e-08       3.89e-03       1.20e-05
#        9             10         7.2589e-11      1.80e-10       3.61e-05       1.80e-06
#       10             11         2.0705e-15      7.26e-11       2.10e-04       2.92e-08
# `gtol` termination condition is satisfied.
# Function evaluations 11, initial cost 3.3736e-03, final cost 2.0705e-15, first-order optimality 2.92e-08.
# Equalization took 76.36861515045166 seconds.
# V = [-37.13257537 -37.13257882 -37.13257882 -37.13257537]
# t = [0.11052374 0.11052367 0.11052374]
# U = [1.28218857 1.28218848 1.28218848 1.28218857]
# V_err = 4.647160756039644e-08
# t_err = 2.7625979188481464e-07
# U_err = 3.6259543743647936e-08

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.output import *

N = 20
L = 4
d = 3
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([L], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize_lsq(eqt, nobounds=True)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
# Varying waist direction: x.
# Equalization method: trf
# Equalization target: uvt
#
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.3736e-03                                    1.23e+00
#        1              2         5.8795e-04      2.79e-03       2.82e-01       4.90e-01
#        2              3         1.0035e-08      5.88e-04       1.15e-02       2.09e-03
#        3              4         4.5490e-17      1.00e-08       1.23e-04       1.40e-07
#        4              5         9.6156e-26      4.55e-17       1.34e-08       6.59e-12
# `gtol` termination condition is satisfied.
# Function evaluations 5, initial cost 3.3736e-03, final cost 9.6156e-26, first-order optimality 6.59e-12.
# Equalization took 32.59472298622131 seconds.
# V = [-32.54459368 -32.54459365 -32.54459365 -32.54459368]
# t = [0.03905772 0.0390577  0.03905772]
# U = [1.26342332 1.26342332 1.26342332 1.26342332]
# V_err = 5.098991037120525e-10
# t_err = 2.2451254675669907e-07
# U_err = 1.3466110416044802e-09

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.output import *

N = 20
L = 4
d = 3
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([L], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize_lsq(eqt)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
# Varying waist direction: x.
# Equalization method: trf
# Equalization target: uvt
#
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.3736e-03                                    1.23e+00
#        1              2         4.5781e-04      2.92e-03       2.27e-01       4.22e-01
#        2              3         5.1407e-08      4.58e-04       6.01e-02       3.72e-03
#        3              4         3.3922e-14      5.14e-08       6.26e-04       4.18e-06
#        4              5         2.3848e-25      3.39e-14       6.26e-08       1.11e-11
#        5              7         3.0953e-27      2.35e-25       6.33e-09       1.19e-12
#        6             10         1.8436e-27      1.25e-27       7.92e-10       9.44e-13
#        7             22         1.8436e-27      0.00e+00       0.00e+00       9.44e-13
# `xtol` termination condition is satisfied.
# Function evaluations 22, initial cost 3.3736e-03, final cost 1.8436e-27, first-order optimality 9.44e-13.
# Equalization took 87.85514712333679 seconds.
# V = [-34.83487357 -34.83487357 -34.83487357 -34.83487357]
# t = [0.06736603 0.06736603 0.06736603]
# U = [1.2647899 1.2647899 1.2647899 1.2647899]
# V_err = 1.685106264110036e-15
# t_err = 1.133430149935909e-12
# U_err = 5.04253370666641e-16

# %% [markdown]
# ## Large size

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.output import *

N = 20
L = 8
d = 3
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardParamEqualizer(N,
                          R0=R0,
                          lattice=np.array([L], dtype=int),
                          band=1,
                          dim=d,
                          avg=0.5,
                          sparse=True,
                          shape=shape,
                          waist=w,
                          equalize=False,
                          symmetry=True,
                          verbosity=0)
G.waist_dir = w
G.equalize_lsq(eqt, nobounds=True)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
# Varying waist direction: x.
# Equalization method: trf
# Equalization target: uvt
#
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.2798e-03                                    5.98e-01
#        1              3         5.4407e-04      2.74e-03       2.75e-01       1.98e-01
#        2              5         3.3301e-05      5.11e-04       1.37e-01       1.74e-02
#        3              7         1.6164e-06      3.17e-05       6.41e-02       3.88e-03
#        4              8         3.9053e-09      1.61e-06       1.55e-02       4.79e-04
#        5              9         6.3741e-13      3.90e-09       1.64e-03       5.82e-06
#        6             10         4.8492e-19      6.37e-13       2.27e-05       5.61e-09
# `gtol` termination condition is satisfied.
# Function evaluations 10, initial cost 3.2798e-03, final cost 4.8492e-19, first-order optimality 5.61e-09.
# Equalization took 196.99119997024536 seconds.
# V = [-35.49747178 -35.49747179 -35.49747185 -35.49747172 -35.49747172
#  -35.49747185 -35.49747179 -35.49747178]
# t = [0.12715665 0.12715665 0.12715667 0.1271566  0.12715667 0.12715665
#  0.12715665]
# U = [1.27439685 1.27439685 1.27439684 1.27439685 1.27439685 1.27439684
#  1.27439685 1.27439685]
# V_err = 1.2430959475496666e-09
# t_err = 1.6337983726122942e-07
# U_err = 2.348962550224441e-09

# %% [markdown]
# # Test NM

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.output import *

N = 20
L = 4
d = 1
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([L], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize(eqt, method='Nelder-Mead')
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
print(G.eqinfo['Nfeval'])
# Out:
# Varying waist direction: x.
# Equalization method: Nelder-Mead
# Equalization target: uvt
#
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 157
#          Function evaluations: 282
# Equalization took 3.2362849712371826 seconds.
# V = [-45.57284772 -45.57282948 -45.57282948 -45.57284772]
# t = [0.12458415 0.12458416 0.12458415]
# U = [2.16357225 2.16357192 2.16357192 2.16357225]
# V_err = 4.002030103051552e-14
# t_err = 3.4714750354145526e-15
# U_err = 5.6495988863925315e-15
# 282

# %% [markdown]
# # Test SLSQP

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.io import *

N = 20
L = 4
d = 1
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([L], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize(eqt, lsq=True)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
print(G.eqinfo['Nfeval'])
# Out:
# Varying waist direction: x.
# Equalization method: SLSQP
# Equalization target: uvt
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8.886187165664224e-13
#             Iterations: 10
#             Function evaluations: 83
#             Gradient evaluations: 10
# Equalization took 0.8521311283111572 seconds.
# V = [-44.68434426 -44.68433171 -44.68433171 -44.68434426]
# t = [0.15785356 0.15785356 0.15785356]
# U = [2.1120598  2.11205586 2.11205586 2.1120598 ]
# V_err = 1.971700325996355e-14
# t_err = 5.476355037115794e-16
# U_err = 8.683540778027473e-13
# 83

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.output import *

N = 20
L = 4
d = 2
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([L], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize(eqt, method='SLSQP', lsq=True)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
print(G.eqinfo['Nfeval'])
# Out:
# Varying waist direction: x.
# Equalization method: SLSQP
# Equalization target: uvt
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7.001765602560151e-13
#             Iterations: 11
#             Function evaluations: 90
#             Gradient evaluations: 11
# Equalization took 9.380089044570923 seconds.
# V = [-36.3322797  -36.33230319 -36.33230319 -36.3322797 ]
# t = [0.18400634 0.18400631 0.18400634]
# U = [2.51136153 2.51135767 2.51135767 2.51136153]
# V_err = 1.0443749984836e-13
# t_err = 6.0511286199720306e-15
# U_err = 5.896879317876831e-13
# 90

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.output import *

N = 20
L = 4
d = 2
shape = 'square'
w = 'x'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([L], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize(eqt, method='SLSQP', nobounds=True)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
#
# i=680	c=[1.13719121e-09 2.10471308e-07 1.94091313e-07]	c_i=4.056998123218694e-07	c_i//2-c_i=0.0011928344474729223
# i=690	c=[0.00018595 0.00058749 0.00028864]	c_i=0.0010620775651184332	c_i//2-c_i=0.00013119551070219513
# i=700	c=[3.11460831e-07 1.84315330e-06 8.31912723e-07]	c_i=2.986526855524595e-06	c_i//2-c_i=0.0009946741101040618
# i=710	c=[2.19832868e-07 1.35743716e-06 6.16958719e-07]	c_i=2.1942287494249836e-06	c_i//2-c_i=0.000995735503386199
# i=720	c=[2.98408254e-07 1.13991848e-06 3.64625128e-07]	c_i=1.8029518645647082e-06	c_i//2-c_i=0.0008568978293503367
# i=730	c=[6.44599270e-08 2.48789199e-07 8.06440558e-08]	c_i=3.938931817539187e-07	c_i//2-c_i=0.0008583403656023215
# i=740	c=[7.16800323e-08 3.69682544e-08 7.26779619e-08]	c_i=1.813262486505529e-07	c_i//2-c_i=0.00034753752989450135
# i=750	c=[7.03037440e-08 3.10325501e-08 7.60944233e-08]	c_i=1.7743071733219446e-07	c_i//2-c_i=0.0003474484132216108
# i=760	c=[1.12195752e-06 4.50842070e-06 2.43442652e-06]	c_i=8.064804740116963e-06	c_i//2-c_i=0.000256755442906448
# i=770	c=[1.89494009e-07 6.35620629e-07 2.07505079e-07]	c_i=1.032619716525797e-06	c_i//2-c_i=0.00026375378841532427
# i=780	c=[1.01841894e-07 4.39670625e-08 5.69722263e-08]	c_i=2.0278118266625472e-07	c_i//2-c_i=0.00026461746674389335
# i=790	c=[7.25506292e-08 2.57782317e-07 1.51806147e-07]	c_i=4.821390928385326e-07	c_i//2-c_i=0.00016805188665947347
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0499067934441608e-07
#             Iterations: 58
#             Function evaluations: 795
#             Gradient evaluations: 58
# Equalization took 47.26757597923279 seconds.
# V = [-39.34414824 -39.34415263 -39.34415263 -39.34414824]
# t = [0.16690861 0.16690863 0.16690861]
# U = [2.33862444 2.33862493 2.33862493 2.33862444]
# V_err = 5.5791421238465574e-08
# t_err = 4.496581812237061e-08
# U_err = 1.042334399835799e-07

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.output import *

N = 20
d = 3
shape = 'square'
w = 'xy'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([4], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize(eqt, method='SLSQP')
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
# Varying waist direction: xy.
# Equalization method: SLSQP
# Equalization target: uvt
#
# i=10	c=[0.42712204 1.41151941 0.0401421 ]	c_i=1.878783558729102	c_i//2-c_i=-1.7578556973251092
# i=20	c=[0.03920684 0.0005361  0.0117639 ]	c_i=0.05150684113355966	c_i//2-c_i=0.8987602407249573
# i=30	c=[0.03927272 0.0002674  0.0117401 ]	c_i=0.05128023304101685	c_i//2-c_i=0.00022655034353472048
# i=40	c=[0.02031507 0.0005284  0.02003611]	c_i=0.04087957828636819	c_i//2-c_i=0.010626918668121904
# i=270	c=[2.27429316e-07 1.81328505e-07 9.58111829e-07]	c_i=1.3668696504617424e-06	c_i//2-c_i=0.00019341617708029045
# i=280	c=[0.00040319 0.0091651  0.00097353]	c_i=0.010541814652336542	c_i//2-c_i=-0.010347009217191302
# i=290	c=[3.08830975e-07 2.85193016e-06 1.05578697e-06]	c_i=4.216548109244609e-06	c_i//2-c_i=8.002767490423333e-05
# i=300	c=[1.06335273e-06 3.73166166e-05 5.90153468e-07]	c_i=3.8970122811114334e-05	c_i//2-c_i=4.537716790358277e-05
# i=310	c=[1.66139126e-07 8.77746797e-07 8.93404241e-07]	c_i=1.937290163442038e-06	c_i//2-c_i=3.600878026859914e-05
# i=320	c=[1.91777879e-07 1.23878728e-07 5.96166671e-08]	c_i=3.7527327321969447e-07	c_i//2-c_i=3.728953031585212e-05
# i=330	c=[2.83961476e-07 1.19578153e-06 6.86046755e-07]	c_i=2.1657897643331302e-06	c_i//2-c_i=2.4970703178589002e-05
# i=340	c=[1.94439330e-07 2.58202212e-07 8.79168232e-09]	c_i=4.614332237014538e-07	c_i//2-c_i=2.6572065299101988e-05
# i=350	c=[2.01162128e-07 1.04859848e-08 1.63066854e-08]	c_i=2.2795479776261736e-07	c_i//2-c_i=1.4431088437508784e-05
# i=360	c=[2.23338006e-05 3.25369333e-04 1.81134268e-04]	c_i=0.0005288374014788406	c_i//2-c_i=-0.0005144744425882738
# i=370	c=[2.00677684e-07 3.54317997e-09 1.23820528e-08]	c_i=2.1660291700025764e-07	c_i//2-c_i=9.852316055728194e-06
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1660291700025764e-07
#             Iterations: 30
#             Function evaluations: 370
#             Gradient evaluations: 30
# Equalization took 374.2833149433136 seconds.
# V = [-35.53316367 -35.53316279 -35.53316279 -35.53316367]
# t = [0.14748357 0.14748356 0.14748357]
# U = [1.21499867 1.21499915 1.21499915 1.21499867]
# V_err = 1.2382052790755413e-08
# t_err = 3.5431799701753964e-09
# U_err = 2.0067768423932684e-07

# %%
from Hubbard.equalizer import *
import numpy as np
from Hubbard.output import *

N = 20
L = 3
d = 2
shape = 'square'
w = 'xy'
eqt = 'uvt'
R0 = np.array([3, 3, 7.2])
G = HubbardEqualizer(N,
                     R0=R0,
                     lattice=np.array([3, 2], dtype=int),
                     band=1,
                     dim=d,
                     avg=0.5,
                     sparse=True,
                     shape=shape,
                     waist=w,
                     equalize=False,
                     symmetry=True,
                     verbosity=0)
G.waist_dir = w
G.equalize(eqt, method='SLSQP')
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
# Varying waist direction: x.
# Equalization method: SLSQP
# Equalization target: uvt
#
# i=10	c=[0.04942192 0.47920228 0.01624121]	c_i=0.5448654127072305	c_i//2-c_i=-0.503680115249012
# i=20	c=[0.02006233 0.00031359 0.01139492]	c_i=0.03177084005654972	c_i//2-c_i=0.09596954108300777
# i=30	c=[0.02006133 0.00031655 0.01139526]	c_i=0.03177315013831904	c_i//2-c_i=-2.4199520104600802e-06
# i=40	c=[0.01487728 0.04325198 0.00713674]	c_i=0.06526600273619612	c_i//2-c_i=0.047472258811381784
# /Users/nottforestfc/mambaforge/lib/python3.9/site-packages/pymanopt/optimizers/conjugate_gradient.py:67: RuntimeWarning: invalid value encountered in true_divide
#   manifold.inner_product(newx, Pnewgrad, diff)
# i=50	c=[0.02006183 0.00031662 0.01139478]	c_i=0.03177322825873743	c_i//2-c_i=0.00023992828775030312
# i=60	c=[0.02263304 0.00073899 0.00852802]	c_i=0.031900052198592946	c_i//2-c_i=-0.00012855773784564012
# i=70	c=[0.02442008 0.00504259 0.00792898]	c_i=0.037391638448539724	c_i//2-c_i=-0.005620137091543409
# i=80	c=[0.02148451 0.00594161 0.00229986]	c_i=0.029725979348282878	c_i//2-c_i=0.015157020702352118
# i=90	c=[0.01115427 0.01320099 0.00104801]	c_i=0.025403272357334417	c_i//2-c_i=1.3941913318810446
# i=100	c=[0.02229657 0.00380756 0.00098431]	c_i=0.02708844255565368	c_i//2-c_i=0.004684765493227494
# i=110	c=[0.02240908 0.00389519 0.00026009]	c_i=0.026564356990573173	c_i//2-c_i=0.005208976855194076
# i=120	c=[0.00537254 0.00062725 0.00155829]	c_i=0.007558086570662483	c_i//2-c_i=0.023946951590993013
# i=130	c=[0.00540822 0.00029777 0.00191112]	c_i=0.0076171166056077586	c_i//2-c_i=0.023887924396685502
# i=140	c=[0.00537291 0.00062378 0.001562  ]	c_i=0.007558692493307966	c_i//2-c_i=0.020915094213480364
# i=150	c=[0.00254677 0.00218616 0.00012403]	c_i=0.004856962251463994	c_i//2-c_i=0.02361683056453898
# i=160	c=[0.00156832 0.00272235 0.00038585]	c_i=0.004676511658738062	c_i//2-c_i=0.022416976497828783
# i=170	c=[0.00047412 0.00318704 0.00051722]	c_i=0.004178383211104952	c_i//2-c_i=0.022915106077450863
# i=180	c=[0.00115517 0.00168275 0.00013363]	c_i=0.0029715495702525943	c_i//2-c_i=0.02326540911486113
# i=190	c=[1.43674408e-03 1.29625736e-03 4.30966534e-05]	c_i=0.002776098090400038	c_i//2-c_i=0.02428326346384443
# i=200	c=[1.31743096e-03 2.00740149e-04 5.79116066e-05]	c_i=0.0015760827182383721	c_i//2-c_i=0.025512344707574103
# i=210	c=[1.32798061e-03 3.46918500e-05 6.76730685e-05]	c_i=0.00143034552386336	c_i//2-c_i=0.025658198892148255
# i=220	c=[9.05592558e-04 1.74779125e-04 4.69554383e-06]	c_i=0.0010850672259511472	c_i//2-c_i=0.025479301092214888
# i=230	c=[0.05909747 0.00974341 0.0206323 ]	c_i=0.08947317422527758	c_i//2-c_i=-0.06290892557869468
# i=240	c=[5.92814342e-05 3.45725248e-04 2.00729663e-04]	c_i=0.0006057363453164245	c_i//2-c_i=0.006952369690798039
# i=250	c=[1.47690170e-05 3.57036558e-04 2.18026432e-04]	c_i=0.0005898320064577849	c_i//2-c_i=0.08373791044509632
# i=260	c=[3.09284758e-05 1.95148180e-04 1.84606569e-04]	c_i=0.00041068322503365817	c_i//2-c_i=0.007174786064891593
# i=270	c=[5.40641300e-05 9.70230378e-05 1.43832646e-04]	c_i=0.00029491981343075736	c_i//2-c_i=0.007263775031366682
# i=280	c=[3.03973157e-05 2.00063726e-05 1.12321798e-04]	c_i=0.0001627254867320132	c_i//2-c_i=0.007395967402045761
# i=290	c=[3.67249726e-06 5.67209838e-05 4.51347876e-05]	c_i=0.00010552826858928652	c_i//2-c_i=0.004751436333277516
# i=300	c=[8.40997383e-06 7.11890827e-05 1.77996524e-05]	c_i=9.739870897944354e-05	c_i//2-c_i=0.00475956427955359
# i=310	c=[9.91032735e-06 7.41523163e-05 4.41466808e-06]	c_i=8.84773117039513e-05	c_i//2-c_i=0.004645972772026577
# i=320	c=[5.34358116e-06 5.50003486e-05 1.74294903e-05]	c_i=7.777342006457476e-05	c_i//2-c_i=0.0045987338592159725
# i=330	c=[3.03064845e-06 3.07820355e-05 3.32058874e-06]	c_i=3.7133272740702105e-05	c_i//2-c_i=0.014193335162419317
# i=340	c=[6.10361031e-06 1.67636748e-05 2.04236910e-06]	c_i=2.490965421554129e-05	c_i//2-c_i=0.004153481102706716
# i=350	c=[5.93681663e-06 1.41275317e-04 2.53609031e-05]	c_i=0.00017257303655590173	c_i//2-c_i=0.002799029159689677
# i=360	c=[4.45415018e-06 7.56567046e-07 4.20232694e-06]	c_i=9.413044163812084e-06	c_i//2-c_i=0.0029620383553478793
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9.30589265422536e-06
#             Iterations: 34
#             Function evaluations: 369
#             Gradient evaluations: 34
# Equalization took 55.069008111953735 seconds.
# V = [-37.11643323 -37.11643323 -37.11676401 -37.11676404 -37.11643326
#  -37.11643324]
# t = [0.06244436 0.15952958 0.15952957 0.0624445  0.15952957 0.15952958
#  0.06244436]
# U = [2.44868078 2.44868078 2.44865766 2.44865765 2.44868078 2.44868078]
# V_err = 4.201195891027615e-06
# t_err = 6.523581119261403e-07
# U_err = 4.452338651271605e-06

# %% [markdown]
# # Test Gurobi

# %%
import numpy as np
import scipy.sparse as sp
import gurobipy as gp
from gurobipy import GRB

try:
    # Create a new model
    m = gp.Model("matrix1")

    # Create variables
    x = m.addMVar(shape=3, vtype=GRB.INTEGER, name="x")

    # Set objective
    obj = np.array([1.0, 1.0, 2.0])
    m.setObjective(obj @ x, GRB.MAXIMIZE)

    # Build (sparse) constraint matrix
    data = np.array([1.0, 2.0, 3.0, -1.0, -1.0])
    row = np.array([0, 0, 0, 1, 1])
    col = np.array([0, 1, 2, 0, 1])
    A = sp.csr_matrix((data, (row, col)), shape=(2, 3))
    # Build rhs vector
    rhs = np.array([4.0, -1.0])
    # Add constraints
    m.addConstr(A @ x <= rhs, name="c")
    # Optimize model
    m.optimize()
    print('x: {}'.format(x.x))
    print('Obj: {}'.format(m.objVal))
except gp.GurobiError as e:
    print('Error code ' + str(e.errno) + ": " + str(e))
except AttributeError:
    print('Encountered an attribute error')
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-10-13
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2 rows, 3 columns and 5 nonzeros
# Model fingerprint: 0x4179a010
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 2 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# x: [ 4. -0.  0.]
# Obj: 4.0
