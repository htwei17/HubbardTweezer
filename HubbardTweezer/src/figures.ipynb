# %% [markdown]
# # Hubbard parameter calculations for figures

# %%
# Directives on Jupyter
# %reset
# Auto reload bootstrap.py
# %load_ext autoreload
# %autoreload 2

import numpy as np

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = 'x'
eqt = 'UvT'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(73.0219, 1000),
                 lc=1450,
                 ascatt=1770,
                 laser=780,
                 band=1,
                 dim=d,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=True,
                 eqtarget=eqt,
                 lattice_symmetry=True,
                 symmetry=True,
                 verbosity=0)
G.draw_graph(nnn=True)
# Out:
# Lattice: lattice shape is square; lattice constants set to: (1450, 1450)
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
# Illegal x0 provided. Use no initial guess.
# Equalize: varying waist direction = x.
# Equalize: method = trf
# Equalize: quantities = UvT
#
# Equalize: scale factor = 0.23723837801360126
# Equalize: target tunneling = 0.23723837801360126, None
# Equalize: target interaction = 1.7079002948795075
# Equalize: target onsite potential = 0
# i=1	c=[0.42416186 0.14502511 3.1467208 ]	c_i=3.1784897868261894	c_i//2-c_i=0.0
# i=2	c=[0.42416186 0.14502509 3.1467192 ]	c_i=3.1784882086735102	c_i//2-c_i=0.0
# i=3	c=[0.42416183 0.14502512 3.14672126]	c_i=3.178490248006828	c_i//2-c_i=-2.039333317771508e-06
# i=4	c=[0.42416182 0.14502511 3.14672137]	c_i=3.1784903553575443	c_i//2-c_i=-1.0735071631629012e-07
# i=5	c=[0.42416183 0.14502511 3.14672138]	c_i=3.1784903581880606	c_i//2-c_i=-1.1018123258210721e-07
# i=6	c=[0.42416186 0.14502515 3.14672055]	c_i=3.1784895494143512	c_i//2-c_i=8.05943193071812e-07
# i=7	c=[0.42416189 0.14502515 3.14672064]	c_i=3.17848963801794	c_i//2-c_i=7.173396041615376e-07
# i=8	c=[0.42416191 0.1450251  3.14672112]	c_i=3.1784901160733083	c_i//2-c_i=2.421147522468914e-07
# i=9	c=[0.4241619  0.14502511 3.14672112]	c_i=3.1784901191892008	c_i//2-c_i=2.3899885981393254e-07
# i=10	c=[0.42416181 0.14502465 3.14672205]	c_i=3.1784910012375858	c_i//2-c_i=-1.451823234521754e-06
# i=11	c=[0.42416181 0.14502547 3.14671926]	c_i=3.1784882777689756	c_i//2-c_i=1.2716453756667079e-06
# i=12	c=[0.42416183 0.14502509 3.14672079]	c_i=3.178489775854956	c_i//2-c_i=-1.378370160232123e-07
# i=13	c=[0.42416186 0.14502511 3.1467208 ]	c_i=3.178489787853905	c_i//2-c_i=-1.4983596496875862e-07
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.0514e+00                                    3.37e+02
# i=14	c=[0.39446015 0.10292674 0.00952492]	c_i=0.4077786729983305	c_i//2-c_i=2.770711443074978
# i=15	c=[0.39446018 0.10292673 0.00952655]	c_i=0.4077787393653423	c_i//2-c_i=2.770711376707966
# i=16	c=[0.39446011 0.10292674 0.00952466]	c_i=0.407778633505338	c_i//2-c_i=2.770711485683863
# i=17	c=[0.39446011 0.10292674 0.00952442]	c_i=0.4077786278637489	c_i//2-c_i=2.770711491325452
# i=18	c=[0.39446013 0.10292674 0.00952406]	c_i=0.40777863257047925	c_i//2-c_i=2.7707123686671067
# i=19	c=[0.39446013 0.10292678 0.00952519]	c_i=0.4077786709540876	c_i//2-c_i=2.770712330283498
# i=20	c=[0.39446018 0.10292677 0.00952512]	c_i=0.40777871569217833	c_i//2-c_i=2.770709562076797
# i=115	c=[1.21341378e-07 4.41706535e-07 1.73552853e-06]	c_i=1.7949617442762853e-06	c_i//2-c_i=0.02661903700915836
# i=116	c=[7.34771909e-08 2.71216255e-07 9.38447171e-07]	c_i=9.79612294136847e-07	c_i//2-c_i=0.026620072033849546
# i=117	c=[2.34829157e-08 1.58428528e-07 5.36814923e-07]	c_i=5.601975610515062e-07	c_i//2-c_i=0.026620491448582632
#        8              9         2.5689e-19      1.56e-11       5.85e-06       6.78e-08
# `gtol` termination condition is satisfied.
# Function evaluations 9, initial cost 5.0514e+00, final cost 2.5689e-19, first-order optimality 6.78e-08.
# Equalization took 397.79720163345337 seconds.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 30
#      12 R0 = np.array([3, 3, 7.2])
#      13 G = HubbardGraph(N,
#      14                  R0=R0,
#      15                  lattice=np.array([L, Ly], dtype=int),
#    (...)
#      28                  symmetry=True,
#      29                  verbosity=0)
# ---> 30 G.draw_graph(nnn=True)
#
# File c:\Users\Nottforestfc\OneDrive - Rice University\Documents\Research\Fermi Hubbard tweezer array\HubbardTweezer\src\Hubbard\plot.py:185, in HubbardGraph.draw_graph(self, label, band, nnn, A, U, scalebar)
#     182     self.wf_centers[:, 1] = 0
#     184 self.set_edges(label)
# --> 185 self.set_nodes(label)
#     187 if self.verbosity:
#     188     print('\nStart to plot graph...')
#
# File c:\Users\Nottforestfc\OneDrive - Rice University\Documents\Research\Fermi Hubbard tweezer array\HubbardTweezer\src\Hubbard\plot.py:111, in HubbardGraph.set_nodes(self, label)
#     108     self.pos = dict(
#     109         (n, self.wf_centers[n]) for n in self.graph.nodes())
#     110     depth = np.real(np.diag(self.A)) * 1e3  # Convert to kHz
# --> 111     self.node_label = dict(
#     112         (n, f'{depth[n]:d}') for n in self.graph.nodes)
#     113 elif label == 'adjust':
#     114     # Label trap offset
#     115     self.pos = dict(
#     116         # (n, np.sign(self.trap_centers[n]) * abs(self.trap_centers[n])**1.1)
#     117         (n, self.trap_centers[n]) for n in self.graph.nodes())
#
# File c:\Users\Nottforestfc\OneDrive - Rice University\Documents\Research\Fermi Hubbard tweezer array\HubbardTweezer\src\Hubbard\plot.py:112, in <genexpr>(.0)
#     108     self.pos = dict(
#     109         (n, self.wf_centers[n]) for n in self.graph.nodes())
#     110     depth = np.real(np.diag(self.A)) * 1e3  # Convert to kHz
#     111     self.node_label = dict(
# --> 112         (n, f'{depth[n]:d}') for n in self.graph.nodes)
#     113 elif label == 'adjust':
#     114     # Label trap offset
#     115     self.pos = dict(
#     116         # (n, np.sign(self.trap_centers[n]) * abs(self.trap_centers[n])**1.1)
#     117         (n, self.trap_centers[n]) for n in self.graph.nodes())
#
# ValueError: Unknown format code 'd' for object of type 'float'

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=1550,
                 ascatt=1770,
                 laser=780,
                 band=1,
                 dim=d,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 lattice_symmetry=True,
                 symmetry=True,
                 verbosity=0)
fn = '../output/3D_8x1_square_None_neq.ini'
read_file(fn, G)
G.draw_graph(nnn=True, A=G.A, U=G.U)
# Out:
# Lattice: lattice shape is square; lattice constants set to: (1550, 1550)
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.

# %% [markdown]
# ## 5x5 Lieb

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 5
d = 3
shape = 'Lieb'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, L], dtype=int),
                 trap=(52.26, 1000),
                 lc=(1550, 1600),
                 ascatt=1770,
                 laser=780,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = '../output/3D_5x5_Lieb_None_neq.ini'
read_file(fn, G)
G.draw_graph(nnn=False, A=G.A, U=G.U)
# Out:
# Lieb lattice size adjust to: [5 5]
# Lattice: lattice shape is Lieb; lattice constants set to: (1550, 1600)
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.

# %% [markdown]
# ## 5x5 square

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 5
d = 3
shape = 'square'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, L], dtype=int),
                 trap=(52.26, 1000),
                 lc=(1550, 1600),
                 ascatt=1770,
                 laser=780,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=0)
fn = '../output/3D_5x5_square_None_neq.ini'
read_file(fn, G)
G.draw_graph(nnn=False, A=G.A, U=G.U)
# Out:
# Lattice: lattice shape is square; lattice constants set to: (1550, 1600)
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.

# %% [markdown]
# ### Two-band 3x3 square

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 3
Ly = 3
d = 1
shape = 'square'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=(1550, 1600),
                 ascatt=1770,
                 laser=780,
                 band=2,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 symmetry=True,
                 verbosity=3)
fn = '../output/3D_3x3_square_twobands.ini'
b = 1
read_file(fn, G, band=b)
G.draw_graph(band=b, A=G.A, U=G.U)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=52.26kHz w=1000nm
# Lattice: lattice shape is square; lattice constants set to: (1550, 1600)
# lattice: lattice shape is square
# lattice: Full lattice sizes: [3 3]
# lattice: lattice constants: [1.55 1.6 ]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[30 30 20] is set.
# DVR: R0=[4.55 4.6  7.2 ]w is set.
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
#
# Start to plot graph...

# %%
b = [1, 2]
read_file(fn, G, band=b)
G.draw_graph(band=b, A=G.A, U=G.U)
# Out:
# Start to plot graph...

# %%
b = 2
read_file(fn, G, band=b)
G.draw_graph(band=b, A=G.A, U=G.U)
# Out:
# Start to plot graph...

# %% [markdown]
# ## 20 site ring

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 20
Ly = 1
d = 3
shape = 'ring'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=1550,
                 ascatt=1770,
                 laser=780,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 symmetry=True,
                 verbosity=0)
fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
report = rep.get_report(fn)
G.U, G.A = read_Hubbard(report)
G.draw_graph(nnn=False, A=G.A, U=G.U)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
# Ring size adjust to: 20
# Lattice: lattice shape is ring; lattice constants set to: (1550, 1550)
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [7], line 28
#      26 fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}.ini'
#      27 report = rep.get_report(fn)
# ---> 28 G.U, G.A = read_Hubbard(report)
#      29 G.draw_graph(nnn=False, A=G.A, U=G.U)
#      30 print(f'V = {np.diag(G.A)}')
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# ## Kagome lattice

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 4
Ly = 5
d = 3
shape = 'kagome'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=1550,
                 ascatt=1770,
                 laser=780,
                 band=1,
                 dim=d,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 lattice_symmetry=True,
                 symmetry=True,
                 verbosity=0)
fn = '../output/3D_4x5_kagome_None_neq.ini'
read_file(fn, G)
G.draw_graph(nnn=False, A=G.A, U=G.U)
# Out:
# Kagome lattice size adjust to: [4 5]
# Triangular lattice size adjust to: [4 5]
# Lattice: lattice shape is kagome; lattice constants set to: (1550, 1342.33937586588)
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.

# %% [markdown]
# ## Defect honeycomb

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 6
Ly = 5
d = 3
shape = 'defecthoneycomb'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=1550,
                 ascatt=1770,
                 laser=780,
                 band=1,
                 dim=d,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 lattice_symmetry=True,
                 symmetry=True,
                 verbosity=0)
fn = '../output/3D_6x5_defecthoneycomb_None_neq.ini'
read_file(fn, G)
G.draw_graph(nnn=False, A=G.A, U=G.U)
# Out:
# Honeycomb lattice size adjust to: [6 5]
# Triangular lattice size adjust to: [6 5]
# Lattice: lattice shape is defecthoneycomb; lattice constants set to: (1550, 1342.33937586588)
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.

# %% [markdown]
# # Equalization

# %% [markdown]
# ## 1D chain

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'UvT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=(1550,),
                 ascatt=1770,
                 laser=780,
                 band=1,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize_V0=False,
                 equalize=False,
                 eqtarget=eqt,
                 eqmethod=meth,
                 symmetry=True,
                 verbosity=3)

fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
G = read_file(fn, G)
G.draw_graph(nnn=False, A=G.A, U=G.U)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=52.26kHz w=1000nm
# Lattice: lattice shape is square; lattice constants set to: (1550, 1550)
# lattice: lattice shape is square
# lattice: Full lattice sizes: [8 1]
# lattice: lattice constants: [1.55 1.55]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[56 20 20] is set.
# DVR: R0=[8.425 3.    7.2  ]w is set.
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
#
# Start to plot graph...

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = 'x'
eqt = 'UvT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=(1550,),
                 ascatt=1770,
                 laser=780,
                 band=1,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 eqmethod=meth,
                 symmetry=True,
                 verbosity=3)

fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
G = read_file(fn, G)
G.draw_graph(nnn=False, A=G.A, U=G.U)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=52.26kHz w=1000nm
# Lattice: lattice shape is square; lattice constants set to: (1550, 1550)
# lattice: lattice shape is square
# lattice: Full lattice sizes: [8 1]
# lattice: lattice constants: [1.55 1.55]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[56 20 20] is set.
# DVR: R0=[8.425 3.    7.2  ]w is set.
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
#
# Start to plot graph...

# %%
from turtle import update
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 10
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'UvT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=(1550,),
                 ascatt=1770,
                 laser=780,
                 band=1,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 equalize_V0=False,
                 eqtarget=eqt,
                 eqmethod=meth,
                 ghost=True,
                 symmetry=True,
                 verbosity=3)

fn = f'../output/ghost/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
G = read_file(fn, G)
G.draw_graph(nnn=False, A=G.A, U=G.U)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=52.26kHz w=1000nm
# Lattice: lattice shape is square; lattice constants set to: (1550, 1550)
# lattice: lattice shape is square
# lattice: Full lattice sizes: [10  1]
# lattice: lattice constants: [1.55 1.55]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[66 20 20] is set.
# DVR: R0=[9.975 3.    7.2  ]w is set.
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
#
# Start to plot graph...

# %% [markdown]
# ## 2D lattices

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 3
Ly = 3
d = 3
shape = 'square'
w = None
eqt = 'UvT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=(1550, 1600),
                 ascatt=1770,
                 laser=780,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize_V0=False,
                 equalize=False,
                 eqtarget=eqt,
                 eqmethod=meth,
                 ghost=False,
                 symmetry=True,
                 verbosity=3)

fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
# update_saved_data(fn, G)
G = read_file(fn, G)
G.draw_graph(nnn=False, A=G.A, U=G.U)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=52.26kHz w=1000nm
# Lattice: lattice shape is square; lattice constants set to: (1550, 1600)
# lattice: lattice shape is square
# lattice: Full lattice sizes: [3 3]
# lattice: lattice constants: [1.55 1.6 ]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[30 30 20] is set.
# DVR: R0=[4.55 4.6  7.2 ]w is set.
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
#
# Start to plot graph...

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 3
Ly = 3
d = 3
shape = 'square'
w = 'xy'
eqt = 'UvT'
meth = 'NM'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=(1550, 1600),
                 ascatt=1770,
                 laser=780,
                 band=1,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 equalize_V0=False,
                 eqtarget=eqt,
                 eqmethod=meth,
                 symmetry=True,
                 verbosity=3)

fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
# update_saved_data(fn, G)
G = read_file(fn, G)
G.draw_graph(nnn=False, A=G.A, U=G.U)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=52.26kHz w=1000nm
# Lattice: lattice shape is square; lattice constants set to: (1550, 1600)
# lattice: lattice shape is square
# lattice: Full lattice sizes: [3 3]
# lattice: lattice constants: [1.55 1.6 ]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[30 30 20] is set.
# DVR: R0=[4.55 4.6  7.2 ]w is set.
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
#
# Start to plot graph...

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 5
Ly = 5
d = 3
shape = 'square'
w = None
eqt = 'UvT'
meth = 'NM'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=(1550, 1600),
                 ascatt=1770,
                 laser=780,
                 band=1,
                 sparse=True,
                 shape=shape,
                 equalize_V0=False,
                 ghost=True,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 eqmethod=meth,
                 symmetry=True,
                 verbosity=3)

fn = f'../output/ghost/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
# update_tc(fn, G)
# update_saved_data(fn, G)
G = read_file(fn, G)
G.draw_graph(nnn=False, A=G.A, U=G.U)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=52.26kHz w=1000nm
# Lattice: lattice shape is square; lattice constants set to: (1550, 1600)
# lattice: lattice shape is square
# lattice: Full lattice sizes: [5 5]
# lattice: lattice constants: [1.55 1.6 ]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[40 41 20] is set.
# DVR: R0=[6.1 6.2 7.2]w is set.
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
#
# Start to plot graph...

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 3
Ly = 3
d = 3
shape = 'Lieb'
w = None
eqt = 'UvT'
meth = 'NM'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=(1550, 1600),
                 ascatt=1770,
                 laser=780,
                 band=1,
                 sparse=True,
                 shape=shape,
                 equalize_V0=False,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 eqmethod=meth,
                 symmetry=True,
                 verbosity=3)

fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
# update_tc(fn, G)
# update_saved_data(fn, G)
G = read_file(fn, G)
G.draw_graph(nnn=False, A=G.A, U=G.U)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=52.26kHz w=1000nm
# Lieb lattice size adjust to: [3 3]
# Lattice: lattice shape is Lieb; lattice constants set to: (1550, 1600)
# lattice: lattice shape is Lieb
# lattice: Full lattice sizes: [3 3]
# lattice: lattice constants: [1.55 1.6 ]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[30 30 20] is set.
# DVR: R0=[4.55 4.6  7.2 ]w is set.
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
#
# Start to plot graph...

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 3
Ly = 3
d = 3
shape = 'Lieb'
w = 'xy'
eqt = 'UvT'
meth = 'trf'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=(1550, 1600),
                 ascatt=1770,
                 laser=780,
                 band=1,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 equalize_V0=False,
                 eqtarget=eqt,
                 eqmethod=meth,
                 symmetry=True,
                 verbosity=3)

fn = f'../output/{d}D_{L}x{Ly}_{shape}_{w}_{eqt}_{meth}.ini'
# update_tc(fn, G)
# update_saved_data(fn, G)
G = read_file(fn, G)
G.draw_graph(nnn=False, A=G.A, U=G.U)
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=52.26kHz w=1000nm
# Lieb lattice size adjust to: [3 3]
# Lattice: lattice shape is Lieb; lattice constants set to: (1550, 1600)
# lattice: lattice shape is Lieb
# lattice: Full lattice sizes: [3 3]
# lattice: lattice constants: [1.55 1.6 ]w
# lattice: dx fixed to: [0.15 0.15 0.36]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[30 30 20] is set.
# DVR: R0=[4.55 4.6  7.2 ]w is set.
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
#
# Start to plot graph...

# %% [markdown]
# ### Proposal figure

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=1550,
                 ascatt=1770,
                 laser=780,
                 band=1,
                 dim=d,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 lattice_symmetry=True,
                 symmetry=True,
                 verbosity=0)
fn = '../output/3D_8x1_square_None_neq.ini'
read_file(fn, G)
G.draw_graph(nnn=True, A=G.A, U=G.U, scalebar=False)
# Out:
# Lattice: lattice shape is square; lattice constants set to: (1550, 1550)
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
L = 8
Ly = 1
d = 3
shape = 'square'
w = 'x'
eqt = 'UvT'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([L, Ly], dtype=int),
                 trap=(52.26, 1000),
                 lc=1550,
                 ascatt=1770,
                 laser=780,
                 band=1,
                 dim=d,
                 sparse=True,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 equalize_V0=False,
                 eqtarget=eqt,
                 lattice_symmetry=True,
                 symmetry=True,
                 verbosity=0)
fn = '../output/3D_8x1_square_x_UvT_trf.ini'
read_file(fn, G)
G.draw_graph(nnn=True, A=G.A, U=G.U, scalebar=True)
# Out:
# Lattice: lattice shape is square; lattice constants set to: (1550, 1550)
# Equalize: scale_factor is not a number. Set to None.
# Equalize: ghost sites are set.
