# %% [markdown]
# # Simultaneous diagonalization

# %%
import numpy as np
import numpy.linalg as la

R = [None, None]
V = [None, None]
R[0] = np.array([[0.,          0., - 0.68510884, 0.],
                 [0.,         0.,        0., - 0.68644896],
                 [-0.68510884, 0.,         0.,          0.],
                 [0., - 0.68644896, 0.,          0.]])
# [-0.68644896 -0.68510884  0.68510884  0.68644896]
V[0] = np.array([[0.,        0.70710678, - 0.70710678, 0.],
                 [0.70710678, 0.,  0., - 0.70710678],
                 [0.,      0.70710678, 0.70710678, 0.],
                 [0.70710678, 0.,    0.,     0.70710678]])
R[1] = np.array([[0., - 0.68510884, 0.,        0.],
                 [-0.68510884, 0.,         0.,         0.],
                 [0.,      0.,         0., - 0.68644896],
                 [0.,      0., - 0.68644896, 0.]])
# [-0.68644896 - 0.68510884  0.68510884  0.68644896]
V[1] = np.array([[0.,        0.70710678, - 0.70710678, 0.],
                 [0.,      0.70710678, 0.70710678, 0.],
                 [0.70710678, 0.,  0., - 0.70710678],
                 [0.70710678, 0.,    0.,       0.70710678]])
print(R[0] @ R[1] - R[1] @ R[0])
# Out:
# [[ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.00183805  0.        ]
#  [ 0.         -0.00183805  0.          0.        ]
#  [ 0.          0.          0.          0.        ]]

# %%
B = V[0].T @ R[1] @ V[0]
la.eigh(B)
# Out:
# (array([-0.68644896, -0.68510884,  0.68510884,  0.68644896]),
#  array([[-0.5,  0.5, -0.5,  0.5],
#         [-0.5,  0.5,  0.5, -0.5],
#         [-0.5, -0.5, -0.5, -0.5],
#         [-0.5, -0.5,  0.5,  0.5]]))

# %% [markdown]
# ### New unitary 'optimization' method

# %%
from Hubbard.equalizer import *
import numpy as np
from scipy.optimize import minimize, shgo, dual_annealing

N = 20
R0 = np.array([3, 3, 7.2])

W = HubbardParamEqualizer(N,
                          R0=R0,
                          lattice=np.array([4, 4], dtype=int),
                          lc=(1500, 1500),
                          band=1,
                          dim=3,
                          avg=1 / 2,
                          sparse=True,
                          equalize=False,
                          symmetry=True)

eqV = True
fixed = False
W.eq_label = 'eq'

E, V, parity = eigen_basis(W)
R = locality_mat(W, V[0], parity[0])
np.set_printoptions(precision=4, suppress=True)
A1, U1 = singleband_optimize(W, E[0], V[0], parity[0])
A2, U2 = singleband_diagonalize(W, E[0], V[0], parity[0])
# Out:
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1000nm
# Triangular lattice size adjust to: [4 4]
# lattice: dx is fixed at: [0.15 0.15 0.36]w
# lattice: lattice shape is square
# lattice: Full lattice sizes: [4 4]
# lattice: lattice constants: [1.5 1.5 1.5]w
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[35 35 20] is set.
# DVR: R0=[5.25 5.25 7.2 ]w is set.
# H_op: n=[35 35 20] dx=[0.15 0.15 0.36]w p=[1 1 1] Gaussian sparse diagonalization is enabled. Lowest 16 states are to be calculated.
# H_op: n=[35 35 20] dx=[0.15 0.15 0.36]w p=[1 1 1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 2.49s.
# H_solver: eigenstates memory usage: 3.32 MiB.
# H_op: n=[35 35 20] dx=[0.15 0.15 0.36]w p=[ 1 -1  1] Gaussian sparse diagonalization is enabled. Lowest 16 states are to be calculated.
# H_op: n=[35 35 20] dx=[0.15 0.15 0.36]w p=[ 1 -1  1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 2.54s.
# H_solver: eigenstates memory usage: 3.23 MiB.
# H_op: n=[35 35 20] dx=[0.15 0.15 0.36]w p=[-1  1  1] Gaussian sparse diagonalization is enabled. Lowest 16 states are to be calculated.
# H_op: n=[35 35 20] dx=[0.15 0.15 0.36]w p=[-1  1  1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 2.16s.
# H_solver: eigenstates memory usage: 3.23 MiB.
# H_op: n=[35 35 20] dx=[0.15 0.15 0.36]w p=[-1 -1  1] Gaussian sparse diagonalization is enabled. Lowest 16 states are to be calculated.
# H_op: n=[35 35 20] dx=[0.15 0.15 0.36]w p=[-1 -1  1] Gaussian operator constructed.
# H_solver: diagonalize sparse hermitian matrix.
# H_solver: Gaussian Hamiltonian solved. Time spent: 2.21s.
# H_solver: eigenstates memory usage: 3.14 MiB.
# Optimizing...
# Iteration    Cost                       Gradient norm
# ---------    -----------------------    --------------
#    1         +6.2358041798529221e+01    9.84315554e+00
#    2         +5.1945822802039373e+01    1.29613926e+01
#    3         +3.6594628969685303e+01    1.16557941e+01
#    4         +3.0611507689748155e+01    8.68097175e+00
#    5         +2.6821479580318751e+01    8.24597775e+00
#    6         +2.1105532349922740e+01    9.14830299e+00
#    7         +1.8183089391493542e+01    8.58484028e+00
#    8         +1.5209192225534544e+01    6.27273556e+00
#    9         +1.3278167968908456e+01    5.27876721e+00
#   10         +1.0609172257693597e+01    4.74727840e+00
#   11         +8.9656808722743833e+00    5.60303770e+00
#   12         +8.3756033175262026e+00    3.60077259e+00
#   13         +7.9920171415915124e+00    3.00959487e+00
#   14         +7.4524348951542567e+00    2.63980028e+00
#   15         +7.2408606268809255e+00    2.10931549e+00
#   16         +7.0612096454015703e+00    1.32784276e+00
#   17         +6.9917191229733575e+00    1.02981858e+00
#   18         +6.9069569998528690e+00    1.28510449e+00
#   19         +6.7879369949043937e+00    1.66728377e+00
#   20         +6.6758483138613745e+00    1.37009590e+00
#   21         +6.5989490869021044e+00    9.57467940e-01
#   22         +6.5644829354462368e+00    7.74925106e-01
#   23         +6.5360303028561280e+00    5.32170675e-01
#   24         +6.5141500525114875e+00    6.47780481e-01
#   25         +6.4964141053794275e+00    2.82144481e-01
#   26         +6.4908230618695617e+00    3.74839150e-01
#   27         +6.4880370019329066e+00    1.59229477e-01
# Sweep No. = 0	Rotation s = 0.5312346865701644
# Sweep No. = 0	Rotation s = 0.23165428776969152
# Sweep No. = 0	Rotation s = 0.050947248568280055
# Sweep No. = 0	Rotation s = 0.20636286502197615
# Sweep No. = 0	Rotation s = 0.2845894913066834
# Sweep No. = 0	Rotation s = 0.21139258735584932
# Sweep No. = 0	Rotation s = 0.16695018957154745
# Sweep No. = 0	Rotation s = 0.3621692406325069
# Sweep No. = 0	Rotation s = 0.04573799610035868
# Sweep No. = 0	Rotation s = 0.007963548474801881
# Sweep No. = 0	Rotation s = 0.08196540728883489
# Sweep No. = 0	Rotation s = 0.13873092238083004
# Sweep No. = 0	Rotation s = 0.12361811021606109
# Sweep No. = 0	Rotation s = 0.16910197872576593
# Sweep No. = 0	Rotation s = 0.6120314894204341
# Sweep No. = 0	Rotation s = 0.17206553421033663
# Sweep No. = 0	Rotation s = 0.062198689576153134
# Sweep No. = 0	Rotation s = 0.3457720445224376
# Sweep No. = 0	Rotation s = 0.10403250909698761
# Sweep No. = 0	Rotation s = 0.19821425697592956
# Sweep No. = 0	Rotation s = 0.1921169381154795
# Sweep No. = 0	Rotation s = 0.9218996328430166
# Sweep No. = 0	Rotation s = 0.30118472452991785
# Sweep No. = 0	Rotation s = 0.006495733755492468
# Sweep No. = 0	Rotation s = 0.014696888115689765
# Sweep No. = 0	Rotation s = 0.7581426812025979
# Sweep No. = 0	Rotation s = 0.13964401516064787
# Sweep No. = 0	Rotation s = 0.49313395595159365
# Sweep No. = 0	Rotation s = 0.24534884878509672
# Sweep No. = 0	Rotation s = 0.003914419511448909
# Sweep No. = 0	Rotation s = 0.3458204097707618
# Sweep No. = 0	Rotation s = 0.2437057257549107
# Sweep No. = 0	Rotation s = 0.19182956918864505
# Sweep No. = 0	Rotation s = 0.20046063869620437
# Sweep No. = 0	Rotation s = 0.12024180365216416
# Sweep No. = 0	Rotation s = 0.13056391621040328
# Sweep No. = 0	Rotation s = 0.01167225719824921
# Sweep No. = 0	Rotation s = 0.10274940321831055
# Sweep No. = 0	Rotation s = 0.160920387619645
# Sweep No. = 0	Rotation s = 0.12719490647499201
# Sweep No. = 0	Rotation s = 0.21272261968691952
# Sweep No. = 0	Rotation s = 0.03085438366849754
# Sweep No. = 0	Rotation s = 0.10495574779468081
# Sweep No. = 0	Rotation s = 0.2235478313805955
# Sweep No. = 0	Rotation s = 0.22039241616286248
# Sweep No. = 0	Rotation s = 0.21755162454197555
# Sweep No. = 0	Rotation s = 0.004164515329912333
# Sweep No. = 0	Rotation s = 0.1507748732158708
# Sweep No. = 0	Rotation s = 0.003859073503897457
# Sweep No. = 0	Rotation s = 0.10276535957125368
# Sweep No. = 0	Rotation s = 0.46765482421249516
# Sweep No. = 0	Rotation s = 0.11632278084717301
# Sweep No. = 0	Rotation s = 0.5671701525477598
# Sweep No. = 0	Rotation s = 0.7133291588182692
# Sweep No. = 0	Rotation s = 0.004768096750508662
# Sweep No. = 0	Rotation s = 0.14266574681632807
# Sweep No. = 0	Rotation s = 0.09317924392419435
# Sweep No. = 0	Rotation s = 0.18576068651073577
# Sweep No. = 0	Rotation s = 0.08728646488273688
# Sweep No. = 0	Rotation s = 0.003801623167493034
# Sweep No. = 0	Rotation s = 0.02830000457542163
# Sweep No. = 0	Rotation s = 0.0010836580877334496
# Sweep No. = 0	Rotation s = 0.10267330119339996
# Sweep No. = 0	Rotation s = 0.14269036023162807
# Sweep No. = 0	Rotation s = 0.7085619671725343
# Sweep No. = 0	Rotation s = 0.04346909108973297
# Sweep No. = 0	Rotation s = 0.2403807671281133
# Sweep No. = 0	Rotation s = 0.09097659685928591
# Sweep No. = 0	Rotation s = 0.00454734524122413
# Sweep No. = 0	Rotation s = 0.0005726440051793021
# Sweep No. = 0	Rotation s = 0.10556806505673268
# Sweep No. = 0	Rotation s = 0.2425473699770692
# Sweep No. = 0	Rotation s = 0.01337081454325767
# Sweep No. = 0	Rotation s = 0.0144353940696154
# Sweep No. = 0	Rotation s = 0.23723126977523334
# Sweep No. = 0	Rotation s = 0.10030821701833287
# Sweep No. = 0	Rotation s = 0.18775781445990128
# Sweep No. = 0	Rotation s = 0.22268644955741576
# Sweep No. = 0	Rotation s = 0.0007230441879147035
# Sweep No. = 0	Rotation s = 0.09323478817414788
# Sweep No. = 0	Rotation s = 0.0162914392744476
# Sweep No. = 0	Rotation s = 0.17996420033817773
# Sweep No. = 0	Rotation s = 0.05839704651943717
# Sweep No. = 0	Rotation s = 0.20516443964395528
# Sweep No. = 0	Rotation s = 0.12299003326275687
# Sweep No. = 0	Rotation s = 0.12486067470586433
# Sweep No. = 0	Rotation s = 0.0035896788798099035
# Sweep No. = 0	Rotation s = 0.053067073557340444
# Sweep No. = 0	Rotation s = 0.07323623837695997
# Sweep No. = 0	Rotation s = 0.020639660607655715
# Sweep No. = 0	Rotation s = 0.31049297072981347
# Sweep No. = 0	Rotation s = 0.18088504008483555
# Sweep No. = 0	Rotation s = 0.7349266608889434
# Sweep No. = 0	Rotation s = 0.018069203632937594
# Sweep No. = 0	Rotation s = 0.9019915250877159
# Sweep No. = 0	Rotation s = 0.718899227589388
# Sweep No. = 0	Rotation s = 0.6202901262049656
# Sweep No. = 0	Rotation s = 0.1523685484976441
# Sweep No. = 0	Rotation s = 0.6796348665795223
# Sweep No. = 0	Rotation s = 0.012861818865207195
# Sweep No. = 0	Rotation s = 0.8587913253973325
# Sweep No. = 0	Rotation s = 0.3409573839308762
# Sweep No. = 0	Rotation s = 0.5896940060354121
# Sweep No. = 0	Rotation s = 0.3353112182292298
# Sweep No. = 0	Rotation s = 0.004546527940419349
# Sweep No. = 0	Rotation s = 0.10998448345044001
# Sweep No. = 0	Rotation s = 0.5279766806519504
# Sweep No. = 0	Rotation s = 0.16696912318887758
# Sweep No. = 0	Rotation s = 0.010379897234580616
# Sweep No. = 0	Rotation s = 0.17940220622894376
# Sweep No. = 0	Rotation s = 0.12536423627266907
# Sweep No. = 0	Rotation s = 0.03189284777593299
# Sweep No. = 0	Rotation s = 0.004380155101762293
# Sweep No. = 0	Rotation s = 0.011021580768000942
# Sweep No. = 0	Rotation s = 0.0024467194611379013
# Sweep No. = 0	Rotation s = 0.020945434243040108
# Sweep No. = 0	Rotation s = 0.3168706986262994
# Sweep No. = 0	Rotation s = 0.13029150527971645
# Sweep No. = 1	Rotation s = 0.019480707944808093
# Sweep No. = 1	Rotation s = 0.14348710537396345
# Sweep No. = 1	Rotation s = 0.020859503254628667
# Sweep No. = 1	Rotation s = 0.07608203400317273
# Sweep No. = 1	Rotation s = 0.044863695825786844
# Sweep No. = 1	Rotation s = 0.28129088940486857
# Sweep No. = 1	Rotation s = 0.18890214832359878
# Sweep No. = 1	Rotation s = 0.07578382549697785
# Sweep No. = 1	Rotation s = 0.1932365156062545
# Sweep No. = 1	Rotation s = 0.04614895341684035
# Sweep No. = 1	Rotation s = 0.056312940905517396
# Sweep No. = 1	Rotation s = 0.001051672786288806
# Sweep No. = 1	Rotation s = 0.1295979222952405
# Sweep No. = 1	Rotation s = 0.1252455409022112
# Sweep No. = 1	Rotation s = 0.19179266773759784
# Sweep No. = 1	Rotation s = 0.311990841963362
# Sweep No. = 1	Rotation s = 0.1782742900978991
# Sweep No. = 1	Rotation s = 0.05526496866044234
# Sweep No. = 1	Rotation s = 0.15785644208554908
# Sweep No. = 1	Rotation s = 0.04104379750284745
# Sweep No. = 1	Rotation s = 0.147279437631863
# Sweep No. = 1	Rotation s = 0.0812877963481121
# Sweep No. = 1	Rotation s = 0.7516575132933413
# Sweep No. = 1	Rotation s = 0.05291374788645742
# Sweep No. = 1	Rotation s = 0.43064092809488497
# Sweep No. = 1	Rotation s = 0.01898998167750803
# Sweep No. = 1	Rotation s = 0.28444704351837796
# Sweep No. = 1	Rotation s = 0.038474313559267045
# Sweep No. = 1	Rotation s = 0.22229799244750015
# Sweep No. = 1	Rotation s = 0.05550298651402953
# Sweep No. = 1	Rotation s = 0.09930291933243712
# Sweep No. = 1	Rotation s = 0.21995571305770012
# Sweep No. = 1	Rotation s = 0.12119487441903144
# Sweep No. = 1	Rotation s = 0.06040251981076122
# Sweep No. = 1	Rotation s = 0.012250508459297102
# Sweep No. = 1	Rotation s = 0.1043791039558116
# Sweep No. = 1	Rotation s = 0.0060036558025934285
# Sweep No. = 1	Rotation s = 0.061128811731852424
# Sweep No. = 1	Rotation s = 0.0018794278556720553
# Sweep No. = 1	Rotation s = 0.7060530374156494
# Sweep No. = 1	Rotation s = 0.03933106857529533
# Sweep No. = 1	Rotation s = 0.0010239261795714546
# Sweep No. = 1	Rotation s = 0.08830394207530734
# Sweep No. = 1	Rotation s = 0.11080671257964401
# Sweep No. = 1	Rotation s = 0.02578415532916337
# Sweep No. = 1	Rotation s = 0.045331687756242425
# Sweep No. = 1	Rotation s = 0.5475729051169035
# Sweep No. = 1	Rotation s = 0.09957590875010931
# Sweep No. = 1	Rotation s = 0.07496125746292553
# Sweep No. = 1	Rotation s = 0.10019890078666352
# Sweep No. = 1	Rotation s = 0.009529791646329572
# Sweep No. = 1	Rotation s = 0.19762259396386153
# Sweep No. = 1	Rotation s = 0.08234695303706349
# Sweep No. = 1	Rotation s = 0.06984699100679415
# Sweep No. = 1	Rotation s = 0.06665124822682691
# Sweep No. = 1	Rotation s = 0.053935541993876734
# Sweep No. = 1	Rotation s = 0.06361654593492311
# Sweep No. = 1	Rotation s = 0.24847890795797262
# Sweep No. = 1	Rotation s = 0.010501619828966512
# Sweep No. = 1	Rotation s = 0.16264026966655556
# Sweep No. = 1	Rotation s = 0.57990535205704
# Sweep No. = 1	Rotation s = 0.0018771598401281459
# Sweep No. = 1	Rotation s = 0.006487578332573014
# Sweep No. = 1	Rotation s = 0.030358827823825527
# Sweep No. = 1	Rotation s = 0.053662551515750966
# Sweep No. = 1	Rotation s = 0.05225510237605832
# Sweep No. = 1	Rotation s = 0.06095192231259268
# Sweep No. = 1	Rotation s = 0.07033406336113363
# Sweep No. = 1	Rotation s = 0.02940755408442025
# Sweep No. = 1	Rotation s = 0.005547212711395797
# Sweep No. = 1	Rotation s = 0.018667524579928416
# Sweep No. = 1	Rotation s = 0.00170425368320601
# Sweep No. = 1	Rotation s = 0.048566244629840424
# Sweep No. = 1	Rotation s = 0.0613274874671343
# Sweep No. = 1	Rotation s = 0.05316272439220932
# Sweep No. = 1	Rotation s = 0.08171047972215181
# Sweep No. = 1	Rotation s = 0.03275126173784621
# Sweep No. = 1	Rotation s = 0.0184009422616366
# Sweep No. = 1	Rotation s = 0.039031696012091395
# Sweep No. = 1	Rotation s = 0.09234782389628034
# Sweep No. = 1	Rotation s = 0.0009392210557654584
# Sweep No. = 1	Rotation s = 0.3417504491584951
# Sweep No. = 1	Rotation s = 0.00948841456286522
# Sweep No. = 1	Rotation s = 0.8166646867458633
# Sweep No. = 1	Rotation s = 0.047813938579773535
# Sweep No. = 1	Rotation s = 0.08650546193015574
# Sweep No. = 1	Rotation s = 0.17849793046983917
# Sweep No. = 1	Rotation s = 0.06673022531962297
# Sweep No. = 1	Rotation s = 0.0005160985443278124
# Sweep No. = 1	Rotation s = 0.02339663527888916
# Sweep No. = 1	Rotation s = 0.5739295551798462
# Sweep No. = 1	Rotation s = 0.07599461703048309
# Sweep No. = 1	Rotation s = 0.1404703076031571
# Sweep No. = 1	Rotation s = 0.0479793281252226
# Sweep No. = 1	Rotation s = 0.2744967577716233
# Sweep No. = 1	Rotation s = 0.010110178700324558
# Sweep No. = 1	Rotation s = 0.09720768301106295
# Sweep No. = 1	Rotation s = 0.054955051315249664
# Sweep No. = 1	Rotation s = 0.03944405721673235
# Sweep No. = 1	Rotation s = 0.1433208495290416
# Sweep No. = 1	Rotation s = 0.09058285266200788
# Sweep No. = 1	Rotation s = 0.004866042177012956
# Sweep No. = 1	Rotation s = 0.02834001954475655
# Sweep No. = 1	Rotation s = 0.23206797087016567
# Sweep No. = 1	Rotation s = 0.1417617621072525
# Sweep No. = 1	Rotation s = 0.4962679170323672
# Sweep No. = 1	Rotation s = 0.008818297698911355
# Sweep No. = 1	Rotation s = 0.005166883325789919
# Sweep No. = 1	Rotation s = 0.026594935015165435
# Sweep No. = 1	Rotation s = 0.011649948111754963
# Sweep No. = 1	Rotation s = 0.003915010676628141
# Sweep No. = 1	Rotation s = 0.02971247502251469
# Sweep No. = 1	Rotation s = 0.01747808404266086
# Sweep No. = 1	Rotation s = 0.0014411694684974491
# Sweep No. = 1	Rotation s = 0.0038789996905577687
# Sweep No. = 1	Rotation s = 0.0006250374906825324
# Sweep No. = 1	Rotation s = 0.00012816510119305504
# Sweep No. = 1	Rotation s = 0.01319703352834367
# Sweep No. = 1	Rotation s = 0.10284142463850651
# Sweep No. = 1	Rotation s = 0.010102251032435316
# Sweep No. = 2	Rotation s = 0.05960770766971711
# Sweep No. = 2	Rotation s = 0.002635480213716445
# Sweep No. = 2	Rotation s = 0.03000269079956094
# Sweep No. = 2	Rotation s = 0.022701673041114256
# Sweep No. = 2	Rotation s = 0.014699904042423302
# Sweep No. = 2	Rotation s = 0.3028788672254625
# Sweep No. = 2	Rotation s = 0.9109812175743073
# Sweep No. = 2	Rotation s = 0.008201009694514958
# Sweep No. = 2	Rotation s = 0.25647437217641106
# Sweep No. = 2	Rotation s = 0.02443857622799622
# Sweep No. = 2	Rotation s = 0.059539460747211885
# Sweep No. = 2	Rotation s = 0.0009491997079328807
# Sweep No. = 2	Rotation s = 0.0026520151229358193
# Sweep No. = 2	Rotation s = 0.027809966374034666
# Sweep No. = 2	Rotation s = 0.07660440106718759
# Sweep No. = 2	Rotation s = 0.9218228592837838
# Sweep No. = 2	Rotation s = 0.2151066944654427
# Sweep No. = 2	Rotation s = 0.017021931859571328
# Sweep No. = 2	Rotation s = 0.24378069179656014
# Sweep No. = 2	Rotation s = 0.07953240125930253
# Sweep No. = 2	Rotation s = 0.07018535835528976
# Sweep No. = 2	Rotation s = 0.048411430892027305
# Sweep No. = 2	Rotation s = 0.13915733356826146
# Sweep No. = 2	Rotation s = 0.01703861665721118
# Sweep No. = 2	Rotation s = 0.04281965386134323
# Sweep No. = 2	Rotation s = 0.005478778815508376
# Sweep No. = 2	Rotation s = 0.024289064212323325
# Sweep No. = 2	Rotation s = 0.008121803466359092
# Sweep No. = 2	Rotation s = 0.18271062405983887
# Sweep No. = 2	Rotation s = 0.09296778321080151
# Sweep No. = 2	Rotation s = 0.06357080515050911
# Sweep No. = 2	Rotation s = 0.6963867486081521
# Sweep No. = 2	Rotation s = 0.024950628422487856
# Sweep No. = 2	Rotation s = 0.002395852089733441
# Sweep No. = 2	Rotation s = 0.2548278437245278
# Sweep No. = 2	Rotation s = 0.05094667064303875
# Sweep No. = 2	Rotation s = 0.006188220143486319
# Sweep No. = 2	Rotation s = 0.008506104612003166
# Sweep No. = 2	Rotation s = 0.003014656314962333
# Sweep No. = 2	Rotation s = 0.1713009207934274
# Sweep No. = 2	Rotation s = 0.004934381440925685
# Sweep No. = 2	Rotation s = 0.0828651026970456
# Sweep No. = 2	Rotation s = 0.01658460373616917
# Sweep No. = 2	Rotation s = 0.12016558277055735
# Sweep No. = 2	Rotation s = 0.019456366340093924
# Sweep No. = 2	Rotation s = 0.01039830283562987
# Sweep No. = 2	Rotation s = 0.19424964057860836
# Sweep No. = 2	Rotation s = 0.0751253641645278
# Sweep No. = 2	Rotation s = 0.02446919929560383
# Sweep No. = 2	Rotation s = 0.031966377290771945
# Sweep No. = 2	Rotation s = 5.1923180506248956e-05
# Sweep No. = 2	Rotation s = 0.019391501727127135
# Sweep No. = 2	Rotation s = 0.013857695555845727
# Sweep No. = 2	Rotation s = 0.03144052185690516
# Sweep No. = 2	Rotation s = 0.043955630745313244
# Sweep No. = 2	Rotation s = 0.018104375847484394
# Sweep No. = 2	Rotation s = 0.016284725426069794
# Sweep No. = 2	Rotation s = 0.28181702054004454
# Sweep No. = 2	Rotation s = 0.03925389987135829
# Sweep No. = 2	Rotation s = 0.1687114504258316
# Sweep No. = 2	Rotation s = 0.10730492094126233
# Sweep No. = 2	Rotation s = 0.0006929039840613284
# Sweep No. = 2	Rotation s = 0.028388831094820342
# Sweep No. = 2	Rotation s = 0.03301390135140781
# Sweep No. = 2	Rotation s = 0.031749326215333815
# Sweep No. = 2	Rotation s = 0.017622096189414658
# Sweep No. = 2	Rotation s = 0.0008941367487890909
# Sweep No. = 2	Rotation s = 0.4733338311637343
# Sweep No. = 2	Rotation s = 0.026751998986056725
# Sweep No. = 2	Rotation s = 0.006913343232133626
# Sweep No. = 2	Rotation s = 0.013163941832915929
# Sweep No. = 2	Rotation s = 0.002870027411343623
# Sweep No. = 2	Rotation s = 0.04940204443913573
# Sweep No. = 2	Rotation s = 0.006476349231530221
# Sweep No. = 2	Rotation s = 0.019261726092568793
# Sweep No. = 2	Rotation s = 0.005835813395954266
# Sweep No. = 2	Rotation s = 0.000831728814689199
# Sweep No. = 2	Rotation s = 0.14042129932256675
# Sweep No. = 2	Rotation s = 0.03877591547675893
# Sweep No. = 2	Rotation s = 0.056644468458668294
# Sweep No. = 2	Rotation s = 0.001882490523238512
# Sweep No. = 2	Rotation s = 0.08285184984913917
# Sweep No. = 2	Rotation s = 0.03270187908616053
# Sweep No. = 2	Rotation s = 0.11527189192608646
# Sweep No. = 2	Rotation s = 0.020179721895402875
# Sweep No. = 2	Rotation s = 0.4696905004780861
# Sweep No. = 2	Rotation s = 0.044629686985905845
# Sweep No. = 2	Rotation s = 0.05771476692522181
# Sweep No. = 2	Rotation s = 0.0012666050549596675
# Sweep No. = 2	Rotation s = 0.011741881126970078
# Sweep No. = 2	Rotation s = 0.0073136230784431695
# Sweep No. = 2	Rotation s = 0.02221053285017732
# Sweep No. = 2	Rotation s = 0.029086444912531612
# Sweep No. = 2	Rotation s = 0.04275338629060942
# Sweep No. = 2	Rotation s = 0.021536073532102892
# Sweep No. = 2	Rotation s = 0.0040555017826325096
# Sweep No. = 2	Rotation s = 0.0033019106192697274
# Sweep No. = 2	Rotation s = 0.013586119838332493
# Sweep No. = 2	Rotation s = 0.0042729240057433945
# Sweep No. = 2	Rotation s = 0.10790614148664647
# Sweep No. = 2	Rotation s = 0.025998056241463584
# Sweep No. = 2	Rotation s = 0.00029937943996606863
# Sweep No. = 2	Rotation s = 0.0026822601842130165
# Sweep No. = 2	Rotation s = 0.24173136753250313
# Sweep No. = 2	Rotation s = 0.03162732760984344
# Sweep No. = 2	Rotation s = 0.01351290282655105
# Sweep No. = 2	Rotation s = 0.0007994462476443837
# Sweep No. = 2	Rotation s = 0.0012332324893125203
# Sweep No. = 2	Rotation s = 0.03717185808779041
# Sweep No. = 2	Rotation s = 0.016145668114081423
# Sweep No. = 2	Rotation s = 0.00026502109273725206
# Sweep No. = 2	Rotation s = 0.0044305451484281605
# Sweep No. = 2	Rotation s = 0.033839729102985605
# Sweep No. = 2	Rotation s = 0.0040225287070710415
# Sweep No. = 2	Rotation s = 0.00015387858037207243
# Sweep No. = 2	Rotation s = 0.00011657948929399886
# Sweep No. = 2	Rotation s = 0.00027520052394206467
# Sweep No. = 2	Rotation s = 0.004008581955740214
# Sweep No. = 2	Rotation s = 0.03217597895803938
# Sweep No. = 2	Rotation s = 0.00025541054872263056
# Sweep No. = 3	Rotation s = 0.01672396414709128
# Sweep No. = 3	Rotation s = 0.021101982163966325
# Sweep No. = 3	Rotation s = 0.007960899175741977
# Sweep No. = 3	Rotation s = 0.015688598903106494
# Sweep No. = 3	Rotation s = 0.01671391584749551
# Sweep No. = 3	Rotation s = 0.06511530172977915
# Sweep No. = 3	Rotation s = 0.11064731110697366
# Sweep No. = 3	Rotation s = 0.005568457740700984
# Sweep No. = 3	Rotation s = 0.2762702169259983
# Sweep No. = 3	Rotation s = 0.010447789707097132
# Sweep No. = 3	Rotation s = 0.0054499494607619684
# Sweep No. = 3	Rotation s = 7.029173316471894e-05
# Sweep No. = 3	Rotation s = 0.018673614683686387
# Sweep No. = 3	Rotation s = 0.03846487933656907
# Sweep No. = 3	Rotation s = 0.04831600546039706
# Sweep No. = 3	Rotation s = 0.05235433984513263
# Sweep No. = 3	Rotation s = 0.0074577044369287
# Sweep No. = 3	Rotation s = 0.01125644858020219
# Sweep No. = 3	Rotation s = 0.05131057523115893
# Sweep No. = 3	Rotation s = 0.02188685415312481
# Sweep No. = 3	Rotation s = 0.03082761176789295
# Sweep No. = 3	Rotation s = 0.04215947364458831
# Sweep No. = 3	Rotation s = 0.020760178117988363
# Sweep No. = 3	Rotation s = 0.00035892591903153713
# Sweep No. = 3	Rotation s = 0.0017470293484833708
# Sweep No. = 3	Rotation s = 0.00089469725379506
# Sweep No. = 3	Rotation s = 0.00904912401413978
# Sweep No. = 3	Rotation s = 0.00565958512806483
# Sweep No. = 3	Rotation s = 0.008649854336719174
# Sweep No. = 3	Rotation s = 0.06421475022668006
# Sweep No. = 3	Rotation s = 0.046656513904989656
# Sweep No. = 3	Rotation s = 0.013324547415143002
# Sweep No. = 3	Rotation s = 0.010076000648195084
# Sweep No. = 3	Rotation s = 0.024926138790537514
# Sweep No. = 3	Rotation s = 0.07144131579670106
# Sweep No. = 3	Rotation s = 0.01389191070260967
# Sweep No. = 3	Rotation s = 0.004718545505497405
# Sweep No. = 3	Rotation s = 0.011082612089658802
# Sweep No. = 3	Rotation s = 0.00022257686171093957
# Sweep No. = 3	Rotation s = 0.0021572770838739286
# Sweep No. = 3	Rotation s = 0.0068556473162811205
# Sweep No. = 3	Rotation s = 0.009975805765274152
# Sweep No. = 3	Rotation s = 0.01600692766033617
# Sweep No. = 3	Rotation s = 0.1043440432712087
# Sweep No. = 3	Rotation s = 0.014261605521972698
# Sweep No. = 3	Rotation s = 0.022436198930148112
# Sweep No. = 3	Rotation s = 0.07149061977606667
# Sweep No. = 3	Rotation s = 0.018186487253541758
# Sweep No. = 3	Rotation s = 0.008019776080097954
# Sweep No. = 3	Rotation s = 0.014737850307215472
# Sweep No. = 3	Rotation s = 0.00021710499479802694
# Sweep No. = 3	Rotation s = 0.00812291076792713
# Sweep No. = 3	Rotation s = 0.015479174940282104
# Sweep No. = 3	Rotation s = 0.009169027946509358
# Sweep No. = 3	Rotation s = 0.03690567979308486
# Sweep No. = 3	Rotation s = 0.0034334544700858173
# Sweep No. = 3	Rotation s = 0.00868262105774539
# Sweep No. = 3	Rotation s = 0.042023829767562665
# Sweep No. = 3	Rotation s = 0.031947556593905344
# Sweep No. = 3	Rotation s = 0.003851621718001221
# Sweep No. = 3	Rotation s = 0.02101829081101137
# Sweep No. = 3	Rotation s = 0.00027814758977018025
# Sweep No. = 3	Rotation s = 0.0030335298651542907
# Sweep No. = 3	Rotation s = 0.02352083258425768
# Sweep No. = 3	Rotation s = 0.0015594086225137172
# Sweep No. = 3	Rotation s = 0.015566812461756901
# Sweep No. = 3	Rotation s = 0.024675868011573975
# Sweep No. = 3	Rotation s = 0.018293867569166174
# Sweep No. = 3	Rotation s = 0.01306533497418144
# Sweep No. = 3	Rotation s = 0.0032225542253490396
# Sweep No. = 3	Rotation s = 0.007190445509036483
# Sweep No. = 3	Rotation s = 1.314258910498983e-05
# Sweep No. = 3	Rotation s = 0.004099810885463409
# Sweep No. = 3	Rotation s = 0.009273292086035504
# Sweep No. = 3	Rotation s = 0.005464899956608935
# Sweep No. = 3	Rotation s = 0.024646106534160633
# Sweep No. = 3	Rotation s = 0.011770239247724214
# Sweep No. = 3	Rotation s = 0.06777176250384952
# Sweep No. = 3	Rotation s = 0.001318886388802534
# Sweep No. = 3	Rotation s = 0.0005471895100101578
# Sweep No. = 3	Rotation s = 4.619207964046571e-05
# Sweep No. = 3	Rotation s = 0.013759097280251095
# Sweep No. = 3	Rotation s = 0.013286036159041469
# Sweep No. = 3	Rotation s = 0.06687092494798662
# Sweep No. = 3	Rotation s = 0.022224308798212935
# Sweep No. = 3	Rotation s = 0.026103390072276307
# Sweep No. = 3	Rotation s = 0.0030160079991106694
# Sweep No. = 3	Rotation s = 0.002033626869167109
# Sweep No. = 3	Rotation s = 0.00011574150139310188
# Sweep No. = 3	Rotation s = 0.00945939103993761
# Sweep No. = 3	Rotation s = 0.012563955626792571
# Sweep No. = 3	Rotation s = 0.02218042345999936
# Sweep No. = 3	Rotation s = 0.003215175570032613
# Sweep No. = 3	Rotation s = 0.001705097827738221
# Sweep No. = 3	Rotation s = 0.004520560012913739
# Sweep No. = 3	Rotation s = 0.00015403036112530323
# Sweep No. = 3	Rotation s = 0.009284781350443161
# Sweep No. = 3	Rotation s = 0.005389131968127771
# Sweep No. = 3	Rotation s = 0.011602949679421055
# Sweep No. = 3	Rotation s = 0.02657990955173622
# Sweep No. = 3	Rotation s = 0.03940337898760594
# Sweep No. = 3	Rotation s = 0.0003474949211103659
# Sweep No. = 3	Rotation s = 0.00019176080314953694
# Sweep No. = 3	Rotation s = 0.1914631172154673
# Sweep No. = 3	Rotation s = 0.0018156175111583937
# Sweep No. = 3	Rotation s = 0.008464180525564163
# Sweep No. = 3	Rotation s = 3.356337065492343e-05
# Sweep No. = 3	Rotation s = 0.0006405841488678305
# Sweep No. = 3	Rotation s = 0.016422229510250387
# Sweep No. = 3	Rotation s = 0.0003524359659171477
# Sweep No. = 3	Rotation s = 5.207220852634708e-05
# Sweep No. = 3	Rotation s = 0.0034609555931105576
# Sweep No. = 3	Rotation s = 0.027736898752227793
# Sweep No. = 3	Rotation s = 0.005121956524860808
# Sweep No. = 3	Rotation s = 1.7314371124228482e-06
# Sweep No. = 3	Rotation s = 0.00015044442337196445
# Sweep No. = 3	Rotation s = 0.00011166283069884045
# Sweep No. = 3	Rotation s = 0.003073722050465854
# Sweep No. = 3	Rotation s = 0.019226764883360448
# Sweep No. = 3	Rotation s = 0.005469162249678158
# Sweep No. = 4	Rotation s = 0.01504607711312368
# Sweep No. = 4	Rotation s = 0.00023806245126953822
# Sweep No. = 4	Rotation s = 0.010004599648193705
# Sweep No. = 4	Rotation s = 2.3763607962735693e-05
# Sweep No. = 4	Rotation s = 0.006455699337281369
# Sweep No. = 4	Rotation s = 0.07988781582139845
# Sweep No. = 4	Rotation s = 0.005688419483027239
# Sweep No. = 4	Rotation s = 0.005596267925120235
# Sweep No. = 4	Rotation s = 0.036708252106378424
# Sweep No. = 4	Rotation s = 0.004856347767419808
# Sweep No. = 4	Rotation s = 0.0024936579162834244
# Sweep No. = 4	Rotation s = 7.273478875859496e-05
# Sweep No. = 4	Rotation s = 0.006325597015916641
# Sweep No. = 4	Rotation s = 0.01137772224825703
# Sweep No. = 4	Rotation s = 0.01685144798784988
# Sweep No. = 4	Rotation s = 0.013501053287393686
# Sweep No. = 4	Rotation s = 0.003048297019672751
# Sweep No. = 4	Rotation s = 0.003161307636386902
# Sweep No. = 4	Rotation s = 0.0009371067510362066
# Sweep No. = 4	Rotation s = 0.008923695102634507
# Sweep No. = 4	Rotation s = 0.002779498096374379
# Sweep No. = 4	Rotation s = 0.002257539572694606
# Sweep No. = 4	Rotation s = 0.003516292405468079
# Sweep No. = 4	Rotation s = 0.0004467719353489784
# Sweep No. = 4	Rotation s = 0.0008134635371445522
# Sweep No. = 4	Rotation s = 6.348151766933276e-05
# Sweep No. = 4	Rotation s = 0.007375808427679551
# Sweep No. = 4	Rotation s = 0.00123591564417206
# Sweep No. = 4	Rotation s = 0.01067661833962797
# Sweep No. = 4	Rotation s = 0.006176798244217161
# Sweep No. = 4	Rotation s = 0.002181141895199114
# Sweep No. = 4	Rotation s = 0.0009085954733709586
# Sweep No. = 4	Rotation s = 0.0031992254444339284
# Sweep No. = 4	Rotation s = 0.0028665090407456973
# Sweep No. = 4	Rotation s = 0.005512177129522113
# Sweep No. = 4	Rotation s = 0.00046378158502386434
# Sweep No. = 4	Rotation s = 0.00024137526954123495
# Sweep No. = 4	Rotation s = 0.0017450207937335733
# Sweep No. = 4	Rotation s = 8.588918559229322e-07
# Sweep No. = 4	Rotation s = 0.0038488547998771824
# Sweep No. = 4	Rotation s = 0.0011634891191458056
# Sweep No. = 4	Rotation s = 0.0037942401184630666
# Sweep No. = 4	Rotation s = 0.028436008130270318
# Sweep No. = 4	Rotation s = 0.012215569155433401
# Sweep No. = 4	Rotation s = 0.008671179054857455
# Sweep No. = 4	Rotation s = 0.0058623768490838534
# Sweep No. = 4	Rotation s = 0.014404996471870903
# Sweep No. = 4	Rotation s = 0.005076940610105216
# Sweep No. = 4	Rotation s = 0.0016169274651383525
# Sweep No. = 4	Rotation s = 0.008362724412902376
# Sweep No. = 4	Rotation s = 9.051656732852799e-05
# Sweep No. = 4	Rotation s = 0.0007794681648849048
# Sweep No. = 4	Rotation s = 0.00924617674508965
# Sweep No. = 4	Rotation s = 0.0013209451616342112
# Sweep No. = 4	Rotation s = 0.01070221635182552
# Sweep No. = 4	Rotation s = 0.0017134033270902065
# Sweep No. = 4	Rotation s = 0.0028894232891057583
# Sweep No. = 4	Rotation s = 0.005349776021587153
# Sweep No. = 4	Rotation s = 0.008729426451718732
# Sweep No. = 4	Rotation s = 0.0012615639593705423
# Sweep No. = 4	Rotation s = 0.010164410484817938
# Sweep No. = 4	Rotation s = 5.4337770911005346e-05
# Sweep No. = 4	Rotation s = 0.0019042118327258764
# Sweep No. = 4	Rotation s = 0.009381064232535343
# Sweep No. = 4	Rotation s = 0.002394734879150243
# Sweep No. = 4	Rotation s = 0.006602699074188698
# Sweep No. = 4	Rotation s = 0.004037219310046003
# Sweep No. = 4	Rotation s = 0.008300567153283494
# Sweep No. = 4	Rotation s = 0.0009951055502182963
# Sweep No. = 4	Rotation s = 0.000572582973665003
# Sweep No. = 4	Rotation s = 0.0044870640517542726
# Sweep No. = 4	Rotation s = 3.84020525276922e-05
# Sweep No. = 4	Rotation s = 0.0010494461841017797
# Sweep No. = 4	Rotation s = 0.004596079931306701
# Sweep No. = 4	Rotation s = 0.0015007503147566861
# Sweep No. = 4	Rotation s = 0.01062641706290444
# Sweep No. = 4	Rotation s = 0.003460765462649324
# Sweep No. = 4	Rotation s = 0.014411421859602485
# Sweep No. = 4	Rotation s = 0.0012466029933669788
# Sweep No. = 4	Rotation s = 0.0002583245055860951
# Sweep No. = 4	Rotation s = 9.776744107856006e-05
# Sweep No. = 4	Rotation s = 0.007522302801041075
# Sweep No. = 4	Rotation s = 0.0036403350654098826
# Sweep No. = 4	Rotation s = 0.02895831959487685
# Sweep No. = 4	Rotation s = 0.002616255889743961
# Sweep No. = 4	Rotation s = 0.0010557634794730118
# Sweep No. = 4	Rotation s = 0.001984366322500871
# Sweep No. = 4	Rotation s = 0.0017877641337687726
# Sweep No. = 4	Rotation s = 3.09677852105274e-05
# Sweep No. = 4	Rotation s = 0.003244947499062491
# Sweep No. = 4	Rotation s = 0.0023568388163136816
# Sweep No. = 4	Rotation s = 0.007090330110322672
# Sweep No. = 4	Rotation s = 0.00084261144022357
# Sweep No. = 4	Rotation s = 0.001368083627078837
# Sweep No. = 4	Rotation s = 0.002469773099788419
# Sweep No. = 4	Rotation s = 5.8567058421256666e-05
# Sweep No. = 4	Rotation s = 0.0020302226804887946
# Sweep No. = 4	Rotation s = 0.001804227406411377
# Sweep No. = 4	Rotation s = 0.002480865989264066
# Sweep No. = 4	Rotation s = 0.005705405155074438
# Sweep No. = 4	Rotation s = 0.013049235666108567
# Sweep No. = 4	Rotation s = 0.00010475476532615478
# Sweep No. = 4	Rotation s = 0.0003521505131856716
# Sweep No. = 4	Rotation s = 0.03045763532088918
# Sweep No. = 4	Rotation s = 0.0011410811651367207
# Sweep No. = 4	Rotation s = 0.0035653884246941298
# Sweep No. = 4	Rotation s = 4.158408208518902e-05
# Sweep No. = 4	Rotation s = 0.00029231519038350873
# Sweep No. = 4	Rotation s = 0.0028020131837293103
# Sweep No. = 4	Rotation s = 0.0008298878802916144
# Sweep No. = 4	Rotation s = 4.529148064552455e-05
# Sweep No. = 4	Rotation s = 0.0015078390859893126
# Sweep No. = 4	Rotation s = 0.011595323637552479
# Sweep No. = 4	Rotation s = 0.0020957887684812018
# Sweep No. = 4	Rotation s = 7.384555993780059e-06
# Sweep No. = 4	Rotation s = 6.843451525315556e-05
# Sweep No. = 4	Rotation s = 3.306016877638627e-05
# Sweep No. = 4	Rotation s = 0.0008369006222785225
# Sweep No. = 4	Rotation s = 0.004469394591822012
# Sweep No. = 4	Rotation s = 0.0013192493422273027
# Sweep No. = 5	Rotation s = 0.0024841147127768345
# Sweep No. = 5	Rotation s = 0.0025710956171704647
# Sweep No. = 5	Rotation s = 0.004264914654340312
# Sweep No. = 5	Rotation s = 0.001241470824412034
# Sweep No. = 5	Rotation s = 0.0032844819403631416
# Sweep No. = 5	Rotation s = 0.012514940045049978
# Sweep No. = 5	Rotation s = 0.0051637979739696475
# Sweep No. = 5	Rotation s = 0.0018981487723662858
# Sweep No. = 5	Rotation s = 0.010754937103494107
# Sweep No. = 5	Rotation s = 0.002119505974718227
# Sweep No. = 5	Rotation s = 0.0007552379999761577
# Sweep No. = 5	Rotation s = 2.159898423254624e-05
# Sweep No. = 5	Rotation s = 0.0023768954001788085
# Sweep No. = 5	Rotation s = 0.0038271958987811817
# Sweep No. = 5	Rotation s = 0.005336369089879567
# Sweep No. = 5	Rotation s = 0.0030832521999619718
# Sweep No. = 5	Rotation s = 0.0005944807522677849
# Sweep No. = 5	Rotation s = 0.000658535718205568
# Sweep No. = 5	Rotation s = 0.0001690578800481388
# Sweep No. = 5	Rotation s = 0.002806164705865552
# Sweep No. = 5	Rotation s = 0.0016979953868682847
# Sweep No. = 5	Rotation s = 0.0003973531358148436
# Sweep No. = 5	Rotation s = 0.0016177826160510655
# Sweep No. = 5	Rotation s = 0.0005503727885300937
# Sweep No. = 5	Rotation s = 0.0003376435337179695
# Sweep No. = 5	Rotation s = 2.35131305978191e-05
# Sweep No. = 5	Rotation s = 0.00233772688587401
# Sweep No. = 5	Rotation s = 0.0009628970816690573
# Sweep No. = 5	Rotation s = 0.0031453048150792778
# Sweep No. = 5	Rotation s = 0.0007713775894911495
# Sweep No. = 5	Rotation s = 0.0008064067070578579
# Sweep No. = 5	Rotation s = 0.0019442700679695882
# Sweep No. = 5	Rotation s = 0.0018609615433054284
# Sweep No. = 5	Rotation s = 0.0012519823067295179
# Sweep No. = 5	Rotation s = 0.0015703883933693222
# Sweep No. = 5	Rotation s = 0.0003301051489630584
# Sweep No. = 5	Rotation s = 0.00035622554647551214
# Sweep No. = 5	Rotation s = 0.0005430216800114192
# Sweep No. = 5	Rotation s = 8.610524619659934e-07
# Sweep No. = 5	Rotation s = 0.0013765393189686904
# Sweep No. = 5	Rotation s = 0.00017467833444609782
# Sweep No. = 5	Rotation s = 0.0011981592861299943
# ...
# Sweep No. = 497	Rotation s = 3.360647858726969e-05
# Sweep No. = 497	Rotation s = 4.0490833843818795e-05
# Sweep No. = 497	Rotation s = 2.8519261667294135e-05
# Sweep No. = 497	Rotation s = 8.327081655367382e-06
# Sweep No. = 497	Rotation s = 2.890173834055211e-07
# Sweep No. = 497	Rotation s = 8.040182238609038e-06
# Sweep No. = 497	Rotation s = 2.541210749313488e-05
# Sweep No. = 497	Rotation s = 1.5150017320840062e-06
# Sweep No. = 497	Rotation s = 2.1743362016788466e-05
# Sweep No. = 497	Rotation s = 1.3989235797379582e-08
# Sweep No. = 497	Rotation s = 1.525805186643847e-05
# Sweep No. = 497	Rotation s = 2.269831402888413e-05
# Sweep No. = 497	Rotation s = 2.0523065385715037e-05
# Sweep No. = 497	Rotation s = 9.477169774324422e-06
# Sweep No. = 497	Rotation s = 7.974088289773088e-07
# Sweep No. = 497	Rotation s = 1.0370356882052408e-05
# Sweep No. = 497	Rotation s = 2.115515541847694e-05
# Sweep No. = 497	Rotation s = 4.21291037953055e-06
# Sweep No. = 497	Rotation s = 1.1530064165206097e-05
# Sweep No. = 497	Rotation s = 2.7540715796025726e-09
# Sweep No. = 497	Rotation s = 2.2559927188445015e-05
# Sweep No. = 497	Rotation s = 1.710873167327084e-05
# Sweep No. = 497	Rotation s = 2.725101732043168e-05
# Sweep No. = 497	Rotation s = 1.1057571835030771e-05
# Sweep No. = 497	Rotation s = 5.2937356106252094e-06
# Sweep No. = 497	Rotation s = 2.4172846300319258e-05
# Sweep No. = 497	Rotation s = 5.99370776378785e-06
# Sweep No. = 497	Rotation s = 6.595881126814124e-06
# Sweep No. = 497	Rotation s = 1.2039788504777689e-08
# Sweep No. = 497	Rotation s = 2.323100201891512e-05
# Sweep No. = 497	Rotation s = 1.4827199289155096e-05
# Sweep No. = 497	Rotation s = 5.5042764165919086e-05
# Sweep No. = 497	Rotation s = 1.998403547288437e-07
# Sweep No. = 497	Rotation s = 8.436311639391967e-06
# Sweep No. = 497	Rotation s = 1.985364952539523e-06
# Sweep No. = 497	Rotation s = 1.2133724815048085e-06
# Sweep No. = 497	Rotation s = 1.0811504629482724e-08
# Sweep No. = 497	Rotation s = 3.8692374782286175e-06
# Sweep No. = 497	Rotation s = 3.3743591506814186e-06
# Sweep No. = 497	Rotation s = 1.0275381253333261e-05
# Sweep No. = 497	Rotation s = 1.2633103921181589e-05
# Sweep No. = 497	Rotation s = 3.1078322691515877e-06
# Sweep No. = 497	Rotation s = 7.128467070749574e-06
# Sweep No. = 497	Rotation s = 1.1607684021677473e-08
# Sweep No. = 497	Rotation s = 9.483319409897871e-06
# Sweep No. = 497	Rotation s = 9.615040376809837e-06
# Sweep No. = 497	Rotation s = 1.3244495480544052e-05
# Sweep No. = 497	Rotation s = 2.835932575829451e-05
# Sweep No. = 497	Rotation s = 3.074645437852989e-05
# Sweep No. = 497	Rotation s = 3.675865362862147e-09
# Sweep No. = 497	Rotation s = 2.5671839995736514e-05
# Sweep No. = 497	Rotation s = 0.0001337595665458957
# Sweep No. = 497	Rotation s = 4.1482514579933596e-05
# Sweep No. = 497	Rotation s = 6.9168399206340215e-06
# Sweep No. = 497	Rotation s = 3.174406810290886e-08
# Sweep No. = 497	Rotation s = 6.056715620073808e-06
# Sweep No. = 497	Rotation s = 1.9079296703105208e-05
# Sweep No. = 497	Rotation s = 1.0421831789723066e-05
# Sweep No. = 497	Rotation s = 4.9634935784067244e-09
# Sweep No. = 497	Rotation s = 9.639920887255071e-06
# Sweep No. = 497	Rotation s = 3.67112051936796e-05
# Sweep No. = 497	Rotation s = 1.4178093524969335e-05
# Sweep No. = 497	Rotation s = 5.665638431129261e-09
# Sweep No. = 497	Rotation s = 9.978490775519826e-09
# Sweep No. = 497	Rotation s = 6.150642763519602e-09
# Sweep No. = 497	Rotation s = 1.822380616642757e-05
# Sweep No. = 497	Rotation s = 0.0001263697746788466
# Sweep No. = 497	Rotation s = 2.8144783808216848e-05
# Sweep No. = 498	Rotation s = 5.534099140186303e-06
# Sweep No. = 498	Rotation s = 6.26830214074839e-06
# Sweep No. = 498	Rotation s = 1.473822945412784e-05
# Sweep No. = 498	Rotation s = 8.677366813959422e-06
# Sweep No. = 498	Rotation s = 8.500287910198073e-06
# Sweep No. = 498	Rotation s = 2.2303772989479835e-05
# Sweep No. = 498	Rotation s = 1.0560596787127968e-05
# Sweep No. = 498	Rotation s = 5.12209628858594e-06
# Sweep No. = 498	Rotation s = 4.994097716141403e-05
# Sweep No. = 498	Rotation s = 7.765472005076474e-06
# Sweep No. = 498	Rotation s = 7.903836504147296e-06
# Sweep No. = 498	Rotation s = 4.657173010586925e-09
# Sweep No. = 498	Rotation s = 1.3493043682147005e-05
# Sweep No. = 498	Rotation s = 2.349782184704385e-05
# Sweep No. = 498	Rotation s = 2.4553436611790115e-05
# Sweep No. = 498	Rotation s = 7.562403596399277e-06
# Sweep No. = 498	Rotation s = 4.5000919906633e-06
# Sweep No. = 498	Rotation s = 3.5044228251950115e-06
# Sweep No. = 498	Rotation s = 9.244730190184868e-07
# Sweep No. = 498	Rotation s = 7.533140545106857e-06
# Sweep No. = 498	Rotation s = 2.5145123554363107e-06
# Sweep No. = 498	Rotation s = 2.968778758372625e-06
# Sweep No. = 498	Rotation s = 9.381158031469555e-06
# Sweep No. = 498	Rotation s = 2.7134425825013747e-06
# Sweep No. = 498	Rotation s = 3.0763564314111857e-06
# Sweep No. = 498	Rotation s = 2.9433059561714646e-08
# Sweep No. = 498	Rotation s = 1.8526015324315735e-05
# Sweep No. = 498	Rotation s = 5.914367907160987e-06
# Sweep No. = 498	Rotation s = 2.8058042893173766e-05
# Sweep No. = 498	Rotation s = 2.5559424150449945e-05
# Sweep No. = 498	Rotation s = 1.0704200905449823e-05
# Sweep No. = 498	Rotation s = 2.2778154401349397e-05
# Sweep No. = 498	Rotation s = 7.992829660051295e-06
# Sweep No. = 498	Rotation s = 1.574699707688888e-06
# Sweep No. = 498	Rotation s = 7.493364694104916e-06
# Sweep No. = 498	Rotation s = 1.3486116820963411e-05
# Sweep No. = 498	Rotation s = 3.3239420497864875e-06
# Sweep No. = 498	Rotation s = 5.87888497363144e-06
# Sweep No. = 498	Rotation s = 6.9027493261383665e-09
# Sweep No. = 498	Rotation s = 3.406797523882526e-05
# Sweep No. = 498	Rotation s = 1.0017497425497106e-05
# Sweep No. = 498	Rotation s = 3.019037951469988e-05
# Sweep No. = 498	Rotation s = 8.839915431020356e-05
# Sweep No. = 498	Rotation s = 9.826524245291832e-05
# Sweep No. = 498	Rotation s = 1.521038387841628e-05
# Sweep No. = 498	Rotation s = 4.051680980333144e-07
# Sweep No. = 498	Rotation s = 1.8058195166537872e-06
# Sweep No. = 498	Rotation s = 3.917020047759083e-05
# Sweep No. = 498	Rotation s = 5.362175070817826e-06
# Sweep No. = 498	Rotation s = 2.5265953602694655e-05
# Sweep No. = 498	Rotation s = 6.532255917090288e-09
# Sweep No. = 498	Rotation s = 3.1912799937529386e-05
# Sweep No. = 498	Rotation s = 3.342852071438683e-05
# Sweep No. = 498	Rotation s = 4.027849896825369e-05
# Sweep No. = 498	Rotation s = 2.8371297177307383e-05
# Sweep No. = 498	Rotation s = 8.284415956369108e-06
# Sweep No. = 498	Rotation s = 2.888085273028606e-07
# Sweep No. = 498	Rotation s = 8.004596440665816e-06
# Sweep No. = 498	Rotation s = 2.5285468520962572e-05
# Sweep No. = 498	Rotation s = 1.5055938063442806e-06
# Sweep No. = 498	Rotation s = 2.1633418284986733e-05
# Sweep No. = 498	Rotation s = 4.1444080082535874e-09
# Sweep No. = 498	Rotation s = 1.518362771914834e-05
# Sweep No. = 498	Rotation s = 2.2580348320399424e-05
# Sweep No. = 498	Rotation s = 2.0418411559010386e-05
# Sweep No. = 498	Rotation s = 9.425875541927457e-06
# Sweep No. = 498	Rotation s = 7.918443374119891e-07
# Sweep No. = 498	Rotation s = 1.03103081405e-05
# Sweep No. = 498	Rotation s = 2.104407192070264e-05
# Sweep No. = 498	Rotation s = 4.189157459972496e-06
# Sweep No. = 498	Rotation s = 1.1468063883884322e-05
# Sweep No. = 498	Rotation s = 7.287821863736962e-09
# Sweep No. = 498	Rotation s = 2.244340236916685e-05
# Sweep No. = 498	Rotation s = 1.7014874155254083e-05
# Sweep No. = 498	Rotation s = 2.710479663389049e-05
# Sweep No. = 498	Rotation s = 1.0999000255275724e-05
# Sweep No. = 498	Rotation s = 5.26593366313692e-06
# Sweep No. = 498	Rotation s = 2.4048989942311234e-05
# Sweep No. = 498	Rotation s = 5.961483496843434e-06
# Sweep No. = 498	Rotation s = 6.560785954457111e-06
# Sweep No. = 498	Rotation s = 3.370697945209385e-09
# Sweep No. = 498	Rotation s = 2.311157243503454e-05
# Sweep No. = 498	Rotation s = 1.4746752965779109e-05
# Sweep No. = 498	Rotation s = 5.474380648701579e-05
# Sweep No. = 498	Rotation s = 1.977349612875692e-07
# Sweep No. = 498	Rotation s = 8.397285587369116e-06
# Sweep No. = 498	Rotation s = 1.9766046930497096e-06
# Sweep No. = 498	Rotation s = 1.2080715582085207e-06
# Sweep No. = 498	Rotation s = 1.306690272656196e-09
# Sweep No. = 498	Rotation s = 3.847920649372793e-06
# Sweep No. = 498	Rotation s = 3.3582600989984473e-06
# Sweep No. = 498	Rotation s = 1.0217004170496124e-05
# Sweep No. = 498	Rotation s = 1.2569541898315506e-05
# Sweep No. = 498	Rotation s = 3.0914792635688553e-06
# Sweep No. = 498	Rotation s = 7.092670069944485e-06
# Sweep No. = 498	Rotation s = 2.8701715050501456e-09
# Sweep No. = 498	Rotation s = 9.434646379549538e-06
# Sweep No. = 498	Rotation s = 9.56499565205804e-06
# Sweep No. = 498	Rotation s = 1.31743848413707e-05
# Sweep No. = 498	Rotation s = 2.821273528156022e-05
# Sweep No. = 498	Rotation s = 3.0586274788832125e-05
# Sweep No. = 498	Rotation s = 6.005098865395828e-09
# Sweep No. = 498	Rotation s = 2.5545480950136518e-05
# Sweep No. = 498	Rotation s = 0.000133048791157088
# Sweep No. = 498	Rotation s = 4.126819416125105e-05
# Sweep No. = 498	Rotation s = 6.882936439211179e-06
# Sweep No. = 498	Rotation s = 3.0675414992520426e-08
# Sweep No. = 498	Rotation s = 6.025104537185477e-06
# Sweep No. = 498	Rotation s = 1.8979377802562312e-05
# Sweep No. = 498	Rotation s = 1.036518254298379e-05
# Sweep No. = 498	Rotation s = 5.256906169592719e-09
# Sweep No. = 498	Rotation s = 9.591019493852635e-06
# Sweep No. = 498	Rotation s = 3.6513822331251156e-05
# Sweep No. = 498	Rotation s = 1.4102843876921444e-05
# Sweep No. = 498	Rotation s = 1.137359401430756e-08
# Sweep No. = 498	Rotation s = 1.596108477694234e-08
# Sweep No. = 498	Rotation s = 9.623740999543991e-09
# Sweep No. = 498	Rotation s = 1.812944629788989e-05
# Sweep No. = 498	Rotation s = 0.00012573517002450568
# Sweep No. = 498	Rotation s = 2.799220108341696e-05
# Sweep No. = 499	Rotation s = 5.506633051462443e-06
# Sweep No. = 499	Rotation s = 6.2366115134254006e-06
# Sweep No. = 499	Rotation s = 1.46632029508469e-05
# Sweep No. = 499	Rotation s = 8.634291097213072e-06
# Sweep No. = 499	Rotation s = 8.455636397303542e-06
# Sweep No. = 499	Rotation s = 2.2187998153035363e-05
# Sweep No. = 499	Rotation s = 1.0507013571890893e-05
# Sweep No. = 499	Rotation s = 5.095972067927961e-06
# Sweep No. = 499	Rotation s = 4.96949412784486e-05
# Sweep No. = 499	Rotation s = 7.72466084011115e-06
# Sweep No. = 499	Rotation s = 7.863041714761093e-06
# Sweep No. = 499	Rotation s = 7.133722155251868e-09
# Sweep No. = 499	Rotation s = 1.3426327479475164e-05
# Sweep No. = 499	Rotation s = 2.337510556832542e-05
# Sweep No. = 499	Rotation s = 2.442491493351029e-05
# Sweep No. = 499	Rotation s = 7.521676704925291e-06
# Sweep No. = 499	Rotation s = 4.4791733019994776e-06
# Sweep No. = 499	Rotation s = 3.4880468228737044e-06
# Sweep No. = 499	Rotation s = 9.212599076907816e-07
# Sweep No. = 499	Rotation s = 7.494808092819185e-06
# Sweep No. = 499	Rotation s = 2.5001550432606374e-06
# Sweep No. = 499	Rotation s = 2.9538479767067198e-06
# Sweep No. = 499	Rotation s = 9.335373929965687e-06
# Sweep No. = 499	Rotation s = 2.699460591191061e-06
# Sweep No. = 499	Rotation s = 3.061098899464852e-06
# Sweep No. = 499	Rotation s = 2.8545827253062363e-08
# Sweep No. = 499	Rotation s = 1.84316668978964e-05
# Sweep No. = 499	Rotation s = 5.884163878614902e-06
# Sweep No. = 499	Rotation s = 2.7913758649281724e-05
# Sweep No. = 499	Rotation s = 2.5426503298821026e-05
# Sweep No. = 499	Rotation s = 1.065070558044693e-05
# Sweep No. = 499	Rotation s = 2.2656981348622998e-05
# Sweep No. = 499	Rotation s = 7.95113832809556e-06
# Sweep No. = 499	Rotation s = 1.5655735071346653e-06
# Sweep No. = 499	Rotation s = 7.453613019001799e-06
# Sweep No. = 499	Rotation s = 1.341807242980995e-05
# Sweep No. = 499	Rotation s = 3.306090646694163e-06
# Sweep No. = 499	Rotation s = 5.848385073610111e-06
# Sweep No. = 499	Rotation s = 8.73261204663387e-09
# Sweep No. = 499	Rotation s = 3.389794577671521e-05
# Sweep No. = 499	Rotation s = 9.964485163794911e-06
# Sweep No. = 499	Rotation s = 3.0035199201371977e-05
# Sweep No. = 499	Rotation s = 8.796624151270886e-05
# Sweep No. = 499	Rotation s = 9.772905379531286e-05
# Sweep No. = 499	Rotation s = 1.5130284603777671e-05
# Sweep No. = 499	Rotation s = 4.009028262126925e-07
# Sweep No. = 499	Rotation s = 1.7868523560950654e-06
# Sweep No. = 499	Rotation s = 3.8970957577255216e-05
# Sweep No. = 499	Rotation s = 5.332135521075882e-06
# Sweep No. = 499	Rotation s = 2.513574471467286e-05
# Sweep No. = 499	Rotation s = 6.30498874939832e-09
# Sweep No. = 499	Rotation s = 3.1751660336878434e-05
# Sweep No. = 499	Rotation s = 3.325144957865831e-05
# Sweep No. = 499	Rotation s = 4.006719592657497e-05
# Sweep No. = 499	Rotation s = 2.8224030520163795e-05
# Sweep No. = 499	Rotation s = 8.241948155848705e-06
# Sweep No. = 499	Rotation s = 2.885889042592118e-07
# Sweep No. = 499	Rotation s = 7.969124606686143e-06
# Sweep No. = 499	Rotation s = 2.5159374565684266e-05
# Sweep No. = 499	Rotation s = 1.4962491727091845e-06
# Sweep No. = 499	Rotation s = 2.1523993547159113e-05
# Sweep No. = 499	Rotation s = 7.258072705044448e-09
# Sweep No. = 499	Rotation s = 1.51095076423659e-05
# Sweep No. = 499	Rotation s = 2.2462949744567408e-05
# Sweep No. = 499	Rotation s = 2.0314234966199162e-05
# Sweep No. = 499	Rotation s = 9.374853186475654e-06
# Sweep No. = 499	Rotation s = 7.863203819034202e-07
# Sweep No. = 499	Rotation s = 1.02506036480641e-05
# Sweep No. = 499	Rotation s = 2.093352855616716e-05
# Sweep No. = 499	Rotation s = 4.165538078143694e-06
# Sweep No. = 499	Rotation s = 1.1406386449963193e-05
# Sweep No. = 499	Rotation s = 1.130443285673851e-08
# Sweep No. = 499	Rotation s = 2.232743215580295e-05
# Sweep No. = 499	Rotation s = 1.6921519367848034e-05
# Sweep No. = 499	Rotation s = 2.6959323477988875e-05
# Sweep No. = 499	Rotation s = 1.0940721786226894e-05
# Sweep No. = 499	Rotation s = 5.238268223064694e-06
# Sweep No. = 499	Rotation s = 2.3925699686189167e-05
# Sweep No. = 499	Rotation s = 5.929424324821319e-06
# Sweep No. = 499	Rotation s = 6.5258709368322345e-06
# Sweep No. = 499	Rotation s = 5.886942775312035e-09
# Sweep No. = 499	Rotation s = 2.2992681345916237e-05
# Sweep No. = 499	Rotation s = 1.466672190576975e-05
# Sweep No. = 499	Rotation s = 5.444641827608179e-05
# Sweep No. = 499	Rotation s = 1.956507840303144e-07
# Sweep No. = 499	Rotation s = 8.358391325613742e-06
# Sweep No. = 499	Rotation s = 1.9678701096650248e-06
# Sweep No. = 499	Rotation s = 1.202789050176144e-06
# Sweep No. = 499	Rotation s = 2.3297078951593324e-09
# Sweep No. = 499	Rotation s = 3.8267192501028504e-06
# Sweep No. = 499	Rotation s = 3.342220646533068e-06
# Sweep No. = 499	Rotation s = 1.0158956912699983e-05
# Sweep No. = 499	Rotation s = 1.2506258452435335e-05
# Sweep No. = 499	Rotation s = 3.0752071664901277e-06
# Sweep No. = 499	Rotation s = 7.05703811160882e-06
# Sweep No. = 499	Rotation s = 5.020458052144645e-09
# Sweep No. = 499	Rotation s = 9.386200196026868e-06
# Sweep No. = 499	Rotation s = 9.515190160548942e-06
# Sweep No. = 499	Rotation s = 1.3104620281211918e-05
# Sweep No. = 499	Rotation s = 2.8066831490066174e-05
# Sweep No. = 499	Rotation s = 3.0426865608751476e-05
# Sweep No. = 499	Rotation s = 1.0516855474978635e-08
# Sweep No. = 499	Rotation s = 2.541964974302127e-05
# Sweep No. = 499	Rotation s = 0.00013234157742127102
# Sweep No. = 499	Rotation s = 4.1054877819410325e-05
# Sweep No. = 499	Rotation s = 6.849171853238172e-06
# Sweep No. = 499	Rotation s = 2.871905819054871e-08
# Sweep No. = 499	Rotation s = 5.993645697214024e-06
# Sweep No. = 499	Rotation s = 1.8879944541570758e-05
# Sweep No. = 499	Rotation s = 1.030882987446945e-05
# Sweep No. = 499	Rotation s = 7.927993339723272e-09
# Sweep No. = 499	Rotation s = 9.542339860538639e-06
# Sweep No. = 499	Rotation s = 3.6317474628734384e-05
# Sweep No. = 499	Rotation s = 1.402797215754773e-05
# Sweep No. = 499	Rotation s = 6.028049283308808e-09
# Sweep No. = 499	Rotation s = 6.434462615650546e-09
# Sweep No. = 499	Rotation s = 1.164654098636016e-08
# Sweep No. = 499	Rotation s = 1.8035528656273518e-05
# Sweep No. = 499	Rotation s = 0.0001251033780870614
# Sweep No. = 499	Rotation s = 2.784041692903693e-05
# Jacobi angle reaches max iter time.
# Trap site position of Wannier functions: [ 3  5  2 13  4  8  1 15 11 10  7  6 14  9  0 15]
# Order of Wannier function is set to match trap site.

# %% [markdown]
# The target function Jacobi angle to minimize is the same as cost function of MLWF Riemannian manifold optimization. The two method is equivalent. The only difference is that in Jacobi angle a closed form is provided for exactly commuting matrices.
#
# However, due to unexact commutativeness of Rx and Ry, given the error from sparse diagonalization, the error grows with the matrix scale, which makes the matrices finally non-commute nuermcally.

# %%
# %timeit A1, U1 = singleband_optimize(W, E[0], V[0], parity[0])
# %timeit A2, U2 = singleband_diagonalize(W, E[0], V[0], parity[0])
# Out:
# Optimizing...
# Terminated - min grad norm reached after 307 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 2  5  4  7  1  9 14 11  2  6 10  3 15 13 12  8]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 268 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 8 13  0  1 15  9  2 12  4 14 10 11 15  5  7  6]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 234 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [ 0 14  6 11  3 12  9  1  8  7 13  5  3 15  2  4]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 315 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [14  9 15  7  6  0  1  4  2  5 12 10 11 13 11  3]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 269 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 1  7  1  5 14  9  8  6  0  3 12 11  4 15  2 10]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 187 iterations, 0.05 seconds.
#
# Trap site position of Wannier functions: [ 2  0 10  0 11 15  1  8  3  6 14  4 12  9  5  7]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 268 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 5  0 12  4  2 10  6 15 14  1  3  9 11  8 13 15]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 256 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 5  4  2  4  6  0 15 12  7 11 14  8 10  3  9 13]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 348 iterations, 0.09 seconds.
#
# Trap site position of Wannier functions: [14  7 10  9  8  4 12  0 14  1  3  2 15  5 13  6]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 240 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [14  9 15  4  3 13  0  1 11  2  5 10  7  8  7  6]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 255 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [12  3  2  3  5  7  1 13  8  9 14  4 11 10  6 15]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 243 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [ 7  3  6  8  2  9 10 12  7  0 13 11  1 14  5  4]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 122 iterations, 0.03 seconds.
#
# Trap site position of Wannier functions: [13 11  4  5  1  7  8 10  9  3 12  6  0  2 15 10]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 304 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [14  6  1  8  0  4  2 13 14 15  9 11  3 12  5 10]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 244 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [ 0  5  4  3  6 11  2  1  0 15 14  8 12 13  9  7]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 337 iterations, 0.09 seconds.
#
# Trap site position of Wannier functions: [ 7  3  7 10  0 13  1  2  4  8  5 14 15  6 12  9]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 259 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 3  1  7 10 15 13  5  6  9 12 11  4  2  0  2 14]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 287 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [10  9 11  3  5  2  6  1  8 12 14  3 13  4 15  7]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 363 iterations, 0.09 seconds.
#
# Trap site position of Wannier functions: [12  1  2  5  6  0  8 11  3 13 14 15 10  7 10  4]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 287 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [14  5  1  9  3  6  0  7 10  4 13  9 11 12  2  8]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 334 iterations, 0.09 seconds.
#
# Trap site position of Wannier functions: [15  8 10  2  1  3  7  0 15 13  9 12  5  4 14 11]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 274 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 1 12 11 12 14 15  8 13  4  6  7  9 10  5  0  3]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 201 iterations, 0.05 seconds.
#
# Trap site position of Wannier functions: [ 1  0  5  0  8 13  2 11  7  6  9  3 14 10 15  4]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 328 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 1 13 11  5 14  8  3 10  0  4  6  7 14 15 12  2]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 350 iterations, 0.09 seconds.
#
# Trap site position of Wannier functions: [ 0  3  7  5  8  1  6  9 11 10 15  4  8 14 13  2]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 311 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 5 15  9  8 13  0  2 11  5  4 12  6 10 14  3  1]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 284 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 3  4  1 13  5  2 14  7 10  8 15 12  9 11  0 11]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 349 iterations, 0.09 seconds.
#
# Trap site position of Wannier functions: [15  9 13  5  4 11  6 10 15  7  8  0  1 12  3 14]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 358 iterations, 0.09 seconds.
#
# Trap site position of Wannier functions: [ 4 12  9 13  0  2  3 15 10  1  8 13  6 14  7 11]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 288 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 1 10  2  9 13  6 14  8 15 11  7  3 12  4  5  4]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 300 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [14  3  2  9  5  6  7 13 10 15  1  0  8 12  8  4]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 236 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [ 0  6  5  9  4  7  2  8 11 10 12  3  4 13  1 15]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 246 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [ 2  7  9 12 13 11  4  5  0  3  6 12  8 10  1 15]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 305 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [12 15 11 10 14  9  5 13 12  6  4  3  2  8  1  7]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 237 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [ 9  8 13  6  2  4  1 12  7  0  3 11 10  5 15  5]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 217 iterations, 0.05 seconds.
#
# Trap site position of Wannier functions: [ 0  2  6  5 11  1 10  7 14 15  4  5  3  9 13  8]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 326 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 7  9 13  1 14 15 11  5  4  8  0  1  2 12  3 10]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 327 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 6 14  1 15 11 12 10  0  5  3  2  9  8 13  7  0]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 250 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [12  1 12  6  7  2  3  5 11  4  0 13  8 10 15 14]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 311 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [13 12  2 12  9  8 15  6  3  0 11 10 14  5  4  7]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 277 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 5  6  7 14 10 15  1 11  5  4 12  8  3  2  0  9]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 216 iterations, 0.05 seconds.
#
# Trap site position of Wannier functions: [ 3 11 12  9  6  8 10 14  0 13 15  1  6  2  4  7]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 264 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 0  7  1  6  2 12  3 13  8 14 11  5  9 15  9  4]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 340 iterations, 0.09 seconds.
#
# Trap site position of Wannier functions: [ 3  6  7 13  4  0  8 15 12 10  9 13  5  1  2 11]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 382 iterations, 0.10 seconds.
#
# Trap site position of Wannier functions: [ 7 10 13  1  8 11 14  4  6 15  9  2  3 12  0  4]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 328 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 0  5  6  5 15 13 14  3  7  9  1 10 11 12  8  4]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 259 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 3 11  3  7 10  6  2  0 15  4  5  8 14  9 13  1]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 216 iterations, 0.05 seconds.
#
# Trap site position of Wannier functions: [11  1  7 14  0 12  8  6  2 13 15 10  0  4  9  5]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 297 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 4  0  1  7 13 14 12  9  2  3 15  7  6  5 10 11]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 259 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [10  5  2 13  0  7  8 11  9 14  3  1 15  6 12 11]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 276 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [12 11 15 11  5  0  9  8  7  1  6  4  2 13 14 10]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 223 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [ 2 14 15  4  8  3  9 13 12  0  7  6  5 10  5  1]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 323 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 2 12  8  1  9 11  4  6  2 13  3 10  7  0 15 14]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 225 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [ 9 13  2 11  6 12 15  4 10  3  5  0  7  8  1  8]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 394 iterations, 0.10 seconds.
#
# Trap site position of Wannier functions: [ 3  2  4  2  5 15 11 12  9 13 14  7 10  0  8  1]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 156 iterations, 0.04 seconds.
#
# Trap site position of Wannier functions: [ 6  0  7  9  3 10 13  1 12 11  8  4  3  2 15 14]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 333 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 0 15  4 11  9  8 10  5  3  6 14 12  7  2 13  2]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 311 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 1  6  0  6 13  9  5 15 12  7  3 11  8  2 10 14]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 217 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [12  2 12  8  6 15  4  0 10  3 14  9 11  5 13  1]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 278 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 6  2 15  7  1  3 10 12 13 11  0  8  9 14  9  4]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 224 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [13 15 11  6  4 14 10  7  3  9  5 12  1  0  2  0]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 237 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [ 7  8 12  2  3  4  9  6 11 10 14  0 15 13  5 13]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 325 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [11  7 11 12  8 13  5 15 10  6  2  4  0 14  9  3]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 309 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 9  8 15  1 12 10  0 11  4  5  3  1  2  7  6 14]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 273 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 8  1 13  5 15 14  4  7 10  9 11  5  3  0  2  6]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 323 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [13  4 14  5 11 12  1  7 13  9  8  3  0 15  2  6]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 249 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [ 8 13  1 13 12  6  4 14  9  5  7 10 15  0  2 11]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 325 iterations, 0.09 seconds.
#
# Trap site position of Wannier functions: [ 6 14  7 14 11 13  0  9 15  8  5  2  4 12  3 10]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 328 iterations, 0.11 seconds.
#
# Trap site position of Wannier functions: [15  2  1  7  4  0 13 10 14  9  8 12  6 11  3 10]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 273 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [13 10 15  8 11  2  9 12  5  1  0  6  3  4  3 14]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 295 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 5 15  4  7  9 11 10  2  3 14  8  7 13  1  6 12]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 295 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [12  0  6  8 11 13  3 10  2 14  5  8  1  7  9 15]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 227 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [11 10 11  2  4 13  9  3  1  7  5  8 14 12  6  0]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 243 iterations, 0.06 seconds.
#
# Trap site position of Wannier functions: [15  7  9  0 12 13  1 14  2  6  4 10  8  5  8 11]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 317 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [ 9 11 14  6  8 15  0 12 10 13  4  1  3  7  5  7]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 307 iterations, 0.08 seconds.
#
# Trap site position of Wannier functions: [13  1 10  1  8  9 15 11  4  5 12  0  7  6  2 14]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 219 iterations, 0.05 seconds.
#
# Trap site position of Wannier functions: [14 13 15  2  4  3 10  5 14  8  7 11  6  0  1 12]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 287 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [15 12  2  7  5  6  3  1  8 10 14  7  0 11  4 13]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 294 iterations, 0.09 seconds.
#
# Trap site position of Wannier functions: [ 9 11  9  0  3  2 12  5  8  1  4 13 15  6  7 10]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 267 iterations, 0.07 seconds.
#
# Trap site position of Wannier functions: [13  5 15 12 14  3  1 10  6  2  4 12 11  0  7  9]
# Order of Wannier function is set to match trap site.
# Optimizing...
# Terminated - min grad norm reached after 342 iterations, 0.11 seconds.
#
# Trap site position of Wannier functions: [15  8  6  7  0 10  9  4 15 11 12 13  3  2  1 14]
# Order of Wannier function is set to match trap site.
# 162 ms ± 6.83 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Jacobi angle reaches max iter time.
# Trap site position of Wannier functions: [ 0  0  6  6  7 14  1  4  9  8  5 13 15 11  2 10]
# Order of Wannier function is set to match trap site.
# Jacobi angle reaches max iter time.
# Trap site position of Wannier functions: [ 0  0  6  6  7 14  1  4  9  8  5 13 15 11  2 10]
# Order of Wannier function is set to match trap site.
# Jacobi angle reaches max iter time.
# Trap site position of Wannier functions: [ 0  0  6  6  7 14  1  4  9  8  5 13 15 11  2 10]
# Order of Wannier function is set to match trap site.
# Jacobi angle reaches max iter time.
# Trap site position of Wannier functions: [ 0  0  6  6  7 14  1  4  9  8  5 13 15 11  2 10]
# Order of Wannier function is set to match trap site.
# Jacobi angle reaches max iter time.
# Trap site position of Wannier functions: [ 0  0  6  6  7 14  1  4  9  8  5 13 15 11  2 10]
# Order of Wannier function is set to match trap site.
# Jacobi angle reaches max iter time.
# Trap site position of Wannier functions: [ 0  0  6  6  7 14  1  4  9  8  5 13 15 11  2 10]
# Order of Wannier function is set to match trap site.
# Jacobi angle reaches max iter time.
# Trap site position of Wannier functions: [ 0  0  6  6  7 14  1  4  9  8  5 13 15 11  2 10]
# Order of Wannier function is set to match trap site.
# Jacobi angle reaches max iter time.
# Trap site position of Wannier functions: [ 0  0  6  6  7 14  1  4  9  8  5 13 15 11  2 10]
# Order of Wannier function is set to match trap site.
# 1.93 s ± 27.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
from tools.jacobi_angles import jacobi_angles
import numpy as np

N = 2

# A = np.eye(N)
# B = np.array([[0., 1.], [1., 0.]])
# jacobi_angles(A, B)

# A = np.eye(N)
# C = np.array([[0., -1j], [1j, 0.]])
# jacobi_angles(A, C)

jacobi_angles(C)
# Out:
# Rotation s = 0.7071067811865475
# Rotation s = 9.983673087713698e-17
# Jacobi angle converged.
# (array([[0.7071-0.j    , 0.    -0.7071j],
#         [0.    -0.7071j, 0.7071-0.j    ]]),
