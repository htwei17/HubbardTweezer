# %% [markdown]
# # Convergence of 3D tweezer potential

# %%
# Directives on Jupyter
# %reset
# Auto reload bootstrap.py
# %load_ext autoreload
# %autoreload 2

import numpy as np

# %% [markdown]
# ## Lifetime fitting

# %% [markdown]
# Test case for 1D

# %%
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os
from plot_dynamics import *

N = 20
freq = 39.4
os.system(
    'python3 -u dynamics_exe.py -a -n {} -d 1 -m Gaussian -f {}'.format(
        N, freq))
os.system('mv *.h5 ../output')

N_list = range(N, N + 1, 2)
R = 3 * np.array([1, 1, 2.4])
freq_list = np.array([freq])
an = 0
length = 1
sn = 1000.0

p = plot(cvg='N',
         quantity='gs',
         N=N,
         R0=R,
         freq_list=freq_list,
         dim=1,
         model='Gaussian',
         wavefunc=False,
         realtime=False,
         symmetry=True,
         absorber=True)

plot_dynamics(N_list,
              R0_list=[R for i in range(len(N_list))],
              dvr=p,
              length=length,
              avg_no=an,
              fit=True)
# Out:
# /storage/hpc/work/kh30/hw50/DVR/src/dynamics.py:123: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if t is 0:
# param_set: model is Gaussian potential.
# ['x']-reflection symmetry is used.
# 1D N=20 R0=[3.]w
# freq=[39.4]kHz
# Gaussian potential starts.
# n=[26], dx=[0.15]w, p=[0], model=Gaussian,
# t=[0.],
# t_step=[0.]
# starts.
# Matrix size= 53
# Estimated full matrix memory usage, float: 0.02 MiB, complex: 0.04 MiB
# Parameter setting time: 0.00s.
#
# init_state: initial state of T+0.5V is calculated.
# H_mat: n=[26] dx=[0.15]w p=[0] Gaussian starts.
# H_mat: H matrix memory usage: 0.04 MiB.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.01s.
# H_solver: eigenstates memory usage: 0.04 MiB.
# Initial state preparation finished. Time spent: 0.01s.
#
# H_mat: n=[26] dx=[0.15]w p=[0] Gaussian starts.
# H_mat: H matrix memory usage: 0.04 MiB.
# H_solver: Gaussian Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.04 MiB.
# H_mat: n=[26] dx=[0.15]w p=[0] Gaussian starts.
# H_mat: H matrix memory usage: 0.04 MiB.
# H_solver: free particle Hamiltonian solved. Time spent: 0.00s.
# H_solver: eigenstates memory usage: 0.04 MiB.
# n=0, dx=0.0, p=0, model=Gaussian, t=[0.] stroboscopic states preparation finished.
# eigen_list: eigenstates memory usage: 0.09 MiB.
# Stroboscopic eigensolver time spent: 0.01s.
#
#
# Top 4 lines
# #1: /home/hw50/env/lib/python3.9/site-packages/scipy/linalg/decomp.py:233: 0.1 MiB
#     w, vl, vr, info = geev(a1, lwork=lwork,
# #2: /home/hw50/env/lib/python3.9/site-packages/scipy/linalg/basic.py:955: 0.1 MiB
#     lu, piv, info = getrf(a1, overwrite_a=overwrite_a)
# #3: /home/hw50/env/lib/python3.9/site-packages/opt_einsum/paths.py:135: 0.0 MiB
#     k12 = either & keep
# #4: <__array_function__ internals>:5: 0.0 MiB
# 167 other: 0.1 MiB
# Total allocated size: 0.3 MiB
#
# Wavefunction output is enabled.
# Absorption potential is enabled. Paramter: L=1.00w V_OI=57.04kHz
#
# Dynamic time step=1.07554e-06 is too small compared to driving period 2.53807e-05. Set time step to driving period.
#
# freq=39kHz model=Gaussian starts. Time step=2.53807e-05, driving period=2.53807e-05.
#
# freq=39kHz model=Gaussian time evolution operator prepared.
#
# Top 6 lines
# #1: /home/hw50/env/lib/python3.9/linecache.py:137: 0.4 MiB
#     lines = fp.readlines()
# #2: /storage/hpc/work/kh30/hw50/DVR/src/dynamics.py:225: 0.0 MiB
#     U = U1 @ U0
# #3: /home/hw50/env/lib/python3.9/site-packages/scipy/linalg/decomp.py:233: 0.0 MiB
#     w, vl, vr, info = geev(a1, lwork=lwork,
# #4: /home/hw50/env/lib/python3.9/tracemalloc.py:67: 0.0 MiB
#     return (self.size, self.count, self.traceback)
# #5: /home/hw50/env/lib/python3.9/tracemalloc.py:193: 0.0 MiB
#     self._frames = tuple(reversed(frames))
# #6: <__array_function__ internals>:5: 0.0 MiB
# 225 other: 0.1 MiB
# Total allocated size: 0.6 MiB
#
# freq=39kHz model=Gaussian time evolution operator diagonalized. Time spent: 0.07s.
# Time step is set to: 2.53807e-05s. Matrix power p in each time step: 1.
# freq=39kHz model=Gaussian finished. Time spent on this freq: 0.35s.
# All done. Total time spent: 0.48s.
# param_set: model is Gaussian potential.
# ['x']-reflection symmetry is used.
# Dynamic time step=1.07554e-06 is too small compared to driving period 2.53807e-05. Set time step to driving period.
# ([<matplotlib.figure.SubFigure at 0x7f3cea3845e0>],
#  [[<AxesSubplot:title={'center':'1D Gaussian gs population \nw/ freq=39.400kHz $R_0$=[3.]w'}, xlabel='t/s', ylabel='$\\rho$'>]])

# %% [markdown]
# 3D

# %%
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os
from plot_dynamics import *

N_list = range(16, 21, 1)
N = 18
# N_list = range(N, N + 1, 2)
R = 3 * np.array([1, 1, 2.4])
freq_list = np.arange(200, 250, 20)
an = 0
length = 1
sn = 1000.0

p = plot(
    cvg='N',
    quantity='gs',
    N=N,
    R0=R,
    #  trap=(156, 1.18E-6),
    freq_list=freq_list,
    dim=3,
    model='Gaussian',
    wavefunc=True,
    realtime=False,
    symmetry=True,
    absorber=True)

ax = None
for i in range(len(N_list)):
    ax = plot_dynamics([N_list[i]],
                       R0_list=[R for i in range(len([N_list[i]]))],
                       ax=ax,
                       dvr=p,
                       length=length,
                       avg_no=an,
                       fit=True)
# Out:
# param_set: model is Gaussian potential.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# DVR: dx=[0.19 0.19 0.45]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21 21 18] by adding absorber.
# DVR: R=[3.94 3.94 8.1 ]w is set.
# DVR: dx=[0.19 0.19 0.45]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21 21 18] by adding absorber.
# DVR: R=[3.94 3.94 8.1 ]w is set.
# DVR: dx=[0.19 0.19 0.45]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21 21 18] by adding absorber.
# DVR: R=[3.94 3.94 8.1 ]w is set.
# DVR: dx=[0.19 0.19 0.45]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21 21 18] by adding absorber.
# DVR: R=[3.94 3.94 8.1 ]w is set.
# DVR: dx=[0.19 0.19 0.45]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21 21 18] by adding absorber.
# DVR: R=[3.94 3.94 8.1 ]w is set.
# DVR: dx=[0.19 0.19 0.45]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [21 21 18] by adding absorber.
# DVR: R=[3.94 3.94 8.1 ]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.

# %%
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os
from plot_dynamics import *

# N_list = range(16, 21, 1)
N = 18
N_list = range(N, N + 1, 2)
R = 3 * np.array([1, 1, 2.4])
freq_list = np.array([180])
an = 0
length = 1
sn = 1000.0

p = plot(
    cvg='N',
    quantity='gs',
    N=N,
    R0=R,
    #  trap=(156, 1.18E-6),
    freq_list=freq_list,
    dim=3,
    model='Gaussian',
    wavefunc=True,
    realtime=False,
    symmetry=True,
    absorber=True)

fig = None
for i in range(len(N_list)):
    fig = plot_dynamics([N_list[i]],
                        R0_list=[R for i in range(len([N_list[i]]))],
                        fig=fig,
                        dvr=p,
                        length=length,
                        avg_no=an,
                        fit=True)
# Out:
# param_set: model is Gaussian potential.
# DVR: dx=[0.16666667 0.16666667 0.4       ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1e-06m
# DVR: dx=[0.16666667 0.16666667 0.4       ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.

# %% [markdown]
# ## Lifetime vs Driving frequency
#
# ### Varying N

# %%
from plot_dynamics import *
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os

N_list = range(17, 21, 1)
N = 18
R = 3 * np.array([1, 1, 2.4])
freq_list = np.arange(100, 250, 10)
an = 0
t0 = 17.9
length = 1
sn = 1000.0

p = plot(cvg='N',
         quantity='gs',
         N=N,
         R0=R,
         freq_list=freq_list,
         dim=3,
         model='Gaussian',
         wavefunc=True,
         realtime=False,
         symmetry=True,
         absorber=True)

ax = plot_lifetime(
    N_list,
    R0_list=[R for i in range(len(N_list))],
    dvr=p,
    avg_no=an,
    length=2,
    #  tau=t0,
    #  file=True,
    #  extrapolte=-3
)
# Out:
# param_set: model is Gaussian potential.
# DVR: dx=[0.16666667 0.16666667 0.4       ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1e-06m
# DVR: dx=[0.17647059 0.17647059 0.42352941]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.05882353 4.05882353 8.04705882]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.18 0.18 0.42]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [23 23 19] by adding absorber.
# DVR: R=[4.06 4.06 8.05]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.16 0.16 0.38]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 22] by adding absorber.
# DVR: R=[3.95 3.95 8.34]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[17 17 17] is set.
# DVR: R0=[2.55 2.55 6.12]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[3.6 3.6 7.2]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[2.7  2.7  6.48]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [25 25 21] by adding absorber.
# DVR: R=[3.75 3.75 7.56]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[19 19 19] is set.
# DVR: R0=[2.85 2.85 6.84]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [26 26 22] by adding absorber.
# DVR: R=[3.9  3.9  7.92]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.

# %%
from plot_dynamics import *
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os

N_list = range(18, 19, 1)
N = 18
R = 3 * np.array([1, 1, 2.4])
freq_list = np.arange(100, 250, 10)
an = 0
t0 = 17.9
length = 1
sn = 1000.0

p = plot(cvg='N',
         quantity='gs',
         N=N,
         R0=R,
         freq_list=freq_list,
         dim=3,
         model='Gaussian',
         wavefunc=True,
         realtime=False,
         symmetry=True,
         absorber=True)

fig = plot_lifetime(N_list,
                    R0_list=[R for i in range(len(N_list))],
                    dvr=p,
                    avg_no=an,
                    length=2)
# Out:
# param_set: model is Gaussian potential.
# DVR: dx=[0.16666667 0.16666667 0.4       ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1e-06m
# DVR: dx=[0.16666667 0.16666667 0.4       ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.

# %% [markdown]
# ### Varying R

# %%
from plot_dynamics import *
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os

N_list = np.arange(12, 19, 2)
dx = 3 / 18 * np.array([1, 1, 2.4], dtype=float)
R = dx * 18
N = 18
R0_list = [dx * n for n in N_list]
freq_list = np.arange(100, 250, 10)
an = 0
# t0 = 17.9
t0 = np.inf
length = 1
sn = 1000.0

p = plot(cvg='R',
         quantity='gs',
         N=N,
         R0=R,
         freq_list=freq_list,
         dim=3,
         model='Gaussian',
         wavefunc=True,
         realtime=False,
         symmetry=True,
         absorber=True)

fig = plot_lifetime(N_list, R0_list, dvr=p, avg_no=an, tau=t0)
# Out:
# /Users/nottforestfc/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Optical tweezer on Fermi Hubbard/src/dynamics.py:149: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if t is 0:
# param_set: model is Gaussian potential.
# DVR: dx=[0.16666667 0.16666667 0.4       ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1e-06m
# DVR: dx=[0.16666667 0.16666667 0.4       ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[12 12 12] is set.
# DVR: R0=[2.  2.  4.8]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [18 18 14] by adding absorber.
# DVR: R=[3.  3.  5.6]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[14 14 14] is set.
# DVR: R0=[2.33 2.33 5.6 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [20 20 16] by adding absorber.
# DVR: R=[3.33 3.33 6.4 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[16 16 16] is set.
# DVR: R0=[2.67 2.67 6.4 ]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [22 22 18] by adding absorber.
# DVR: R=[3.67 3.67 7.2 ]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.

# %% [markdown]
# # Error with varying trap depth and waist

# %%
from plot_dynamics import *
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os

# N_list = range(12, 19, 2)
N = 20
N_list = range(N, N + 1, 2)
R = 3 * np.array([1, 1, 2.4])
freq_list = np.arange(100, 250, 10)
an = 0
t0 = 17.9
# t0 = np.inf
length = 1
sn = 1000.0

p = plot(cvg='N',
         quantity='gs',
         N=N,
         R0=R,
         freq_list=freq_list,
         dim=3,
         model='Gaussian',
         wavefunc=True,
         realtime=False,
         symmetry=True,
         absorber=True)

ax = plot_lifetime(N_list,
                   R0_list=[R for i in range(len(N_list))],
                   dvr=p,
                   fig=None,
                   err=True,
                   avg_no=an,
                   tau=t0)
# Out:
# param_set: model is Gaussian potential.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1e-06m
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.
# DVR: dx=[0.15 0.15 0.36]w is set.
# DVR: n=[20 20 20] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [27 27 23] by adding absorber.
# DVR: R=[4.05 4.05 8.28]w is set.

# %%
import numpy as np

N = 10000
a= np.random.rand(N)+ 1j* np.random.rand(N)
f1 = lambda a:np.linalg.norm(a)**2
f2 = lambda a:np.sum(np.abs(a)**2)
f3 = lambda a:np.inner(a.conj(),a).real
print(a.shape)
print(f1(a))
print(f2(a))
print(f3(a))
# %timeit f1(a)
# %timeit f2(a)
# %timeit f3(a)
# Out:
# (10000,)
# 6627.3637784882285
# 6627.3637784882285
# 6627.363778488229

# %% [markdown]
# ## Absorption strength and width

# %%
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os
from plot_dynamics import *

d = 3
N = 18
N_list = range(N, N + 1, 2)
R = 3 * np.array([1, 1, 2.4])
freq_list = np.arange(100, 250, 20)
an = 0
# t0 = 17.9
t0 = np.inf
L = 1
sn = 1000.0
st = get_stop_time(freq_list, d)
Gamma_list = np.array([0, 1E-2, .5, 1, 10, 1E5]) * 57.04

p = plot(cvg='N',
         quantity='gs',
         N=N,
         R0=R,
         freq_list=freq_list,
         dim=d,
         model='Gaussian',
         wavefunc=False,
         realtime=False,
         symmetry=True,
         absorber=True)

fig = None
for i in range(len(Gamma_list)):
    p.VI = Gamma_list[i] * p.kHz_2p / p.V0_SI
    fig = plot_lifetime(N_list,
                       R0_list=[R for i in range(len(N_list))],
                       dvr=p,
                       fig=fig,
                       err=False,
                       avg_no=an,
                       tau=t0)
# Out:
# param_set: model is Gaussian potential.
# DVR: dx=[0.16666667 0.16666667 0.4       ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1e-06m
# DVR: dx=[0.16666667 0.16666667 0.4       ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.

# %%
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os
from plot_dynamics import *

d = 3
N = 18
N_list = range(N, N + 1, 2)
R = 3 * np.array([1, 1, 2.4])
freq_list = np.arange(100, 250, 20)
an = 0
# t0 = 17.9
t0 = np.inf
# L = 1
Vi = 57.4
sn = 1000.0
st = get_stop_time(freq_list, d)
L_list = np.array([.1, .5, 1, 2])

p = plot(cvg='N',
         quantity='gs',
         N=N,
         R0=R,
         freq_list=freq_list,
         dim=d,
         model='Gaussian',
         wavefunc=False,
         realtime=False,
         symmetry=True,
         absorber=True)

fig = None
for i in range(len(L_list)):
    p.L = L_list[i]
    fig = plot_lifetime(N_list,
                        R0_list=[R for i in range(len(N_list))],
                        dvr=p,
                        fig=fig,
                        err=False,
                        avg_no=an,
                        tau=t0)
# Out:
# param_set: model is Gaussian potential.
# DVR: dx=[0.16666667 0.16666667 0.4       ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# ['x' 'y' 'z']-reflection symmetry is used.
# param_set: trap parameter V0=104.52kHz w=1e-06m
# DVR: dx=[0.16666667 0.16666667 0.4       ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.
# DVR: dx=[0.17 0.17 0.4 ]w is set.
# DVR: n=[18 18 18] is set.
# DVR: R0=[3.  3.  7.2]w is set.
# DVR: Absorber width LI=1w
# DVR: n is set to [24 24 20] by adding absorber.
# DVR: R=[4. 4. 8.]w is set.

# %% [markdown]
# ## Wavefunction dynamics

# %%
from plot_dynamics import *
import numpy as np
import matplotlib.pyplot as plt
from DVR_exe import *
import os

N_list = range(18, 19, 1)
R = 3 * np.array([w, w, 2.4 * w])
freq_list = np.arange(0.12, 0.26, 0.04)
st = 2.5E-5 * np.exp(freq_list * 62.7)
st[np.nonzero(freq_list < .06)] = 1E-2
sn = 1000.0
plot_wavefunction(N_list,
                  R0_list=[R for i in range(len(N_list))],
                  freq_list=freq_list,
                  stop_time_list=st,
                  length=10,
                  step_no=sn,
                  dim=3,
                  symmetry=True,
                  model='Gaussian',
                  cvg='N',
                  realtime=False,
                  absorber=True)
