# %% [markdown]
# # Equalization illustrations

# %% [markdown]
# ## 1D 8 site illustrations

# %%
from Hubbard.plot import *
import numpy as np

N = 20
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([8], dtype=int),
                 laser=770,
                 trap=(50, (930, 1250)),
                 lc=(1350, 1550),
                 band=1,
                 dim=1,
                 avg=1,
                 sparse=True,
                 equalize=False,
                 symmetry=True,
                 verbosity=0)
eqtarget = 'uvt'
G.eq_label = eqtarget
__, __, __, info = G.equalize(eqtarget, callback=True)
G.draw_graph(nnn=True)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
# i=50	c=[0.03662581 0.0191537  0.01272851]	c_i=0.06850801812582519	c_i//2-c_i=0.03363924404274893
# i=100	c=[0.02190797 0.01188589 0.00362603]	c_i=0.03741989443499338	c_i//2-c_i=0.031088115006800816
# i=150	c=[0.00758617 0.00646634 0.00347457]	c_i=0.01752707757277408	c_i//2-c_i=0.0304225755142504
# i=200	c=[0.00049296 0.00268579 0.0014072 ]	c_i=0.004585947839081375	c_i//2-c_i=0.032833924657617676
# i=250	c=[0.00051895 0.00139406 0.00019078]	c_i=0.002103780302380592	c_i//2-c_i=0.01711897416603369
# i=300	c=[0.00014115 0.00036052 0.00017472]	c_i=0.0006763899763344551	c_i//2-c_i=0.043610068896069415
# i=350	c=[2.67358644e-05 2.93020012e-04 5.04632972e-05]	c_i=0.00037021917377937416	c_i//2-c_i=0.005723902207071894
# i=400	c=[1.59411871e-05 1.46103211e-04 1.95082298e-05]	c_i=0.00018155262784029462	c_i//2-c_i=0.0044043844516578265
# i=450	c=[8.49866220e-06 5.31066568e-05 1.89439731e-05]	c_i=8.054929212030238e-05	c_i//2-c_i=0.0031866936475684953
# i=500	c=[2.04711790e-05 1.31996529e-05 2.22224074e-05]	c_i=5.5893239324511673e-05	c_i//2-c_i=0.0020479480620525727
# i=550	c=[2.05768430e-05 1.31554856e-05 2.21940491e-05]	c_i=5.5926377663738735e-05	c_i//2-c_i=0.0011798234198122002
# i=600	c=[2.66863397e-05 9.47195645e-06 2.07539319e-05]	c_i=5.691222799810252e-05	c_i//2-c_i=0.0006194777137205216
# i=650	c=[2.21297946e-05 6.53059906e-06 2.18753007e-05]	c_i=5.0535694366190824e-05	c_i//2-c_i=0.002556432546436408
# i=700	c=[2.12009188e-05 7.41137961e-06 2.10856751e-05]	c_i=4.9697973564177025e-05	c_i//2-c_i=0.0003205547722044699
# i=750	c=[2.26911481e-05 5.40588909e-06 2.00347611e-05]	c_i=4.8131798320429975e-05	c_i//2-c_i=0.00020191744481398347
# i=800	c=[2.48137939e-05 1.51176039e-06 1.90967399e-05]	c_i=4.542229423453734e-05	c_i//2-c_i=0.0005372213415313245
# i=850	c=[2.35962877e-05 3.14017703e-06 1.68560613e-05]	c_i=4.359252599649656e-05	c_i//2-c_i=7.126900578698726e-05
# i=900	c=[2.35563147e-05 3.26868350e-06 1.67836248e-05]	c_i=4.360862299254303e-05	c_i//2-c_i=3.694012114579676e-05
# i=950	c=[2.35727610e-05 3.22166652e-06 1.68199971e-05]	c_i=4.3614424668373146e-05	c_i//2-c_i=0.00014257211709473152
# i=1000	c=[2.36927826e-05 1.35312649e-06 1.67866717e-05]	c_i=4.18325807907155e-05	c_i//2-c_i=1.3980597959618667e-05
# i=1050	c=[4.36901719e-05 2.82825064e-04 2.49331365e-04]	c_i=0.0005758466010756514	c_i//2-c_i=-0.0005200259272999246
# i=1100	c=[2.01255945e-05 5.67485689e-07 1.55897317e-05]	c_i=3.628281184387342e-05	c_i//2-c_i=0.0009121215636720386
# i=1150	c=[1.59514724e-05 2.23746962e-06 1.47767926e-05]	c_i=3.296573464135398e-05	c_i//2-c_i=3.662415346173882e-05
# i=1200	c=[1.26576103e-05 3.07745679e-06 6.43640222e-06]	c_i=2.2171469329416447e-05	c_i//2-c_i=3.351913849999731e-05
# i=1250	c=[3.92897478e-06 1.06469949e-06 6.49943565e-06]	c_i=1.1493109917045148e-05	c_i//2-c_i=3.9005133744599065e-05
# i=1300	c=[7.57225006e-06 9.39002402e-06 1.55191021e-05]	c_i=3.2481376161534365e-05	c_i//2-c_i=1.8040222184557797e-05
# i=1350	c=[3.61769038e-06 1.81427345e-06 5.70603667e-07]	c_i=6.0025675037275635e-06	c_i//2-c_i=4.378223472526667e-05
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5.98457937229016e-06
#             Iterations: 80
#             Function evaluations: 1387
#             Gradient evaluations: 79
# V = [-42.72747621 -42.72751359 -42.72746844 -42.72752604 -42.72752604
#  -42.72746844 -42.72751359 -42.72747621]
# t = [0.31982695 0.31982652 0.31982752 0.31982574 0.31982752 0.31982652
#  0.31982695]
# U = [2.38019153 2.38018454 2.38018338 2.38020489 2.38020489 2.38018338
#  2.38018454 2.38019153]
# V_err = 5.688461637613339e-07
# t_err = 1.8199263650206326e-06
# U_err = 3.595806746344502e-06

# %% [markdown]
# ### 3D 8-site chain

# %% [markdown]
# #### Unequalized

# %%
from Hubbard.plot import *
import numpy as np

N = 20
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([8], dtype=int),
                 laser=770,
                 trap=(50, (930, 1250)),
                 lc=(1350, 1550),
                 dim=3,
                 sparse=True,
                 equalize=False,
                 eqtarget='neq',
                 waist=None,
                 symmetry=True,
                 verbosity=0)
G.draw_graph(nnn=True)
# Out:
# lattice: lattice shape is square; lattice constants set to: (1350, 1550)
# Equalize: scale_factor is not a number. Set to None.

# %% [markdown]
# #### Equalized

# %%
G.Voff
# Out:
# array([1.10469109, 1.06599717, 1.08690923, 1.08806167, 1.08806167,
#        1.08690923, 1.06599717, 1.10469109])

# %%
G.trap_centers
# Out:
# array([[-5.04077118, -0.        ],
#        [-3.5281295 , -0.        ],
#        [-2.12418694, -0.        ],
#        [-0.70905579, -0.        ],
#        [ 0.70905579, -0.        ],
#        [ 2.12418694, -0.        ],
#        [ 3.5281295 , -0.        ],
#        [ 5.04077118, -0.        ]])

# %%
G.waists
# Out:
# array([[1.13315841, 1.        ],
#        [0.96886443, 1.        ],
#        [0.96752295, 1.        ],
#        [0.97152655, 1.        ],
#        [0.97152655, 1.        ],
#        [0.96752295, 1.        ],
#        [0.96886443, 1.        ],
#        [1.13315841, 1.        ]])

# %%
G.Voff = np.array([1.10469109, 1.06599717, 1.08690923, 1.08806167, 1.08806167,
                   1.08690923, 1.06599717, 1.10469109])
G.trap_centers = np.array([[-5.04077118, -0.],
                           [-3.5281295, -0.],
                           [-2.12418694, -0.],
                           [-0.70905579, -0.],
                           [0.70905579, -0.],
                           [2.12418694, -0.],
                           [3.5281295, -0.],
                           [5.04077118, -0.]])
G.waists = np.array([[1.13315841, 1.],
                     [0.96886443, 1.],
                     [0.96752295, 1.],
                     [0.97152655, 1.],
                     [0.97152655, 1.],
                     [0.96752295, 1.],
                     [0.96886443, 1.],
                     [1.13315841, 1.]])
G.waist_dir = 'x'
eqtarget = 'UvT'
G.eq_label = eqtarget
G.draw_graph(nnn=True)

# %% [markdown]
# Original calculation

# %%
from Hubbard.plot import *
import numpy as np

N = 20
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([8], dtype=int),
                 laser=770,
                 trap=(50, (930, 1250)),
                 lc=(1350, 1550),
                 band=1,
                 dim=3,
                 avg=1,
                 waist='x',
                 sparse=True,
                 equalize=False,
                 symmetry=True,
                 verbosity=0)
eqtarget = 'UvT'
G.eq_label = eqtarget
__, __, __, info = G.equalize(eqtarget, callback=True)
G.draw_graph(nnn=True)
print(f'V = {np.diag(G.A)}')
t = abs(G.nn_tunneling(G.A))
print(f't = {t}')
print(f'U = {G.U}')
print(f'V_err = {G.v_cost_func(G.A, None)}')
print(f't_err = {G.t_cost_func(G.A, None, None, None)}')
print(f'U_err = {G.u_cost_func(G.U, None)}')
# Out:
# lattice: lattice shape is square; lattice constants set to: (1350, 1550)
# Equalize: scale_factor is not a number. Set to None.
# Equalize: varying waist direction = x.
# Equalize: method = trf
# Equalize: quantities = UvT
#
# Equalize: scale factor = 0.4960169848933912
# Equalize: target tunneling = 0.4960169848933912, None
# Equalize: target interaction = 1.0152700178781615
# Equalize: target onsite potential = 0
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         7.7368e-01                                    4.04e+01
#        1              2         1.9561e-02      7.54e-01       4.52e-02       6.94e-01
#        2              3         3.9009e-03      1.57e-02       9.34e-02       4.05e-01
#        3              4         1.5716e-03      2.33e-03       5.70e-02       4.23e-01
#        4              5         2.2817e-04      1.34e-03       6.37e-02       2.63e-01
#        5              6         2.1363e-05      2.07e-04       2.54e-02       3.97e-02
#        6              7         1.3742e-07      2.12e-05       1.06e-02       3.65e-03
#        7              8         2.2314e-11      1.37e-07       8.55e-04       1.62e-05
#        8              9         5.1226e-20      2.23e-11       1.09e-05       5.39e-09
# `gtol` termination condition is satisfied.
# Function evaluations 9, initial cost 7.7368e-01, final cost 5.1226e-20, first-order optimality 5.39e-09.
# Equalization took 365.3899290561676 seconds.
# V = [ 6.60804744e-11 -1.36779477e-10  2.24886776e-11  4.82884843e-11
#   4.82671680e-11  2.24460450e-11 -1.36800793e-10  6.59952093e-11]
# t = [0.49601698 0.49601698 0.49601698 0.49601698 0.49601698 0.49601698
#  0.49601698]
# U = [1.01527002 1.01527002 1.01527002 1.01527002 1.01527002 1.01527002
#  1.01527002 1.01527002]
# V_err = 6.477017710181144e-19
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [4], line 29
#      27 print(f'U = {G.U}')
#      28 print(f'V_err = {G.v_cost_func(G.A, None)}')
# ---> 29 print(f't_err = {G.t_cost_func(G.A, None, None, None)}')
#      30 print(f'U_err = {G.u_cost_func(G.U, None)}')
#
# File ~/Library/CloudStorage/OneDrive-RiceUniversity/Documents/Research/Fermi Hubbard tweezer array/HubbardTweezer/src/Hubbard/equalizer.py:521, in HubbardEqualizer.t_cost_func(self, A, links, target, tfactor)
#     517 def t_cost_func(self, A: np.ndarray, links: tuple[np.ndarray, np.ndarray],
#     518                 target: tuple[float, ...], tfactor: float) -> float:
#     519     nnt, txTarget, tyTarget, xlinks, ylinks = self._set_t(
#     520         A, links, target)
# --> 521     ct = np.mean((abs(nnt[xlinks]) - txTarget)**2) / tfactor**2
#     522     if tyTarget != None:
#     523         ct += np.mean((abs(nnt[ylinks]) - tyTarget)**2) / tfactor**2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'NoneType' and 'int'

# %% [markdown]
# ## 3D 3x3 Lieb

# %%
from turtle import shape
from Hubbard.plot import *
import numpy as np

N = 20
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([3, 3], dtype=int),
                 band=1,
                 dim=3,
                 avg=1/2,
                 sparse=True,
                 equalize=False,
                 shape='Lieb',
                 waist=None,
                 eqtarget='neq',
                 symmetry=True,
                 verbosity=0)
G.draw_graph()
# Out:
# lattice: lattice shape is Lieb; lattice constants set to: (1520, 1690)
# Lieb lattice size adjust to: [3 3]
# Equalize: scale_factor is not a number. Set to None.

# %% [markdown]
# ## 3D 3x3 plaquette

# %%
from Hubbard.plot import *
import numpy as np

N = 20
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([3, 3], dtype=int),
                 band=1,
                 dim=3,
                 avg=1/2,
                 sparse=True,
                 equalize=False,
                 waist=None,
                 eqtarget='neq',
                 symmetry=True,
                 verbosity=0)
G.draw_graph(nnn=True)
# Out:
# lattice: lattice shape is square; lattice constants set to: (1520, 1690)
# Equalize: scale_factor is not a number. Set to None.

# %% [markdown]
# ## 3D 4x2 triangular

# %%
from Hubbard.plot import *
import numpy as np
from Hubbard.io import *

N = 20
Lx = 4
Ly = 2
d = 3
shape = 'triangular'
w = None
eqt = 'neq'
R0 = np.array([3, 3, 7.2])
G = HubbardGraph(N,
                 R0=R0,
                 lattice=np.array([Lx, Ly], dtype=int),
                 trap=(73.0219, 1000),
                 lc=1550,
                 laser=780,
                 dim=d,
                 shape=shape,
                 waist=w,
                 equalize=False,
                 eqtarget=eqt,
                 sparse=True,
                 symmetry=True,
                 lattice_symmetry=False,
                 verbosity=0)
G.draw_graph()
# Out:
# lattice: lattice shape is triangular; lattice constants set to: (1550, 1342.33937586588)
# Triangular lattice size adjust to: [4 2]
# Equalize: scale_factor is not a number. Set to None.
# WARNING: total distance = 0.6611037372607167. Assignment might be non-local.
