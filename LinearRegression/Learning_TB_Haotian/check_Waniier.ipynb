# %%
# Directives on Jupyter
# %reset
# Auto reload bootstrap.py
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np

import sys
import os

module_path = os.path.abspath(os.path.join("../../src/"))
if module_path not in sys.path:
    sys.path.append(module_path)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import HubbardTweezer.tools.reportIO as rep

idx = 1
report = rep.get_report(f"/Users/nottforestfc/Downloads/3D_4x4_square_None_neq_{idx}.ini")
wfc = rep.a(report, "Singleband_Parameters", "wf_centers")
tc = rep.a(report, "Trap_Adjustments", "trap_centers")
plt.scatter(wfc[:, 0], wfc[:, 1], c="r", marker="x")
plt.scatter(tc[:, 0], tc[:, 1], c="b", marker="+")

# %%
import HubbardTweezer.tools.reportIO as rep

idx = 6
report = rep.get_report(f"/Users/nottforestfc/Downloads/3D_4x4_square_None_neq_{idx}.ini")
wfc = rep.a(report, "Singleband_Parameters", "wf_centers")
tc = rep.a(report, "Trap_Adjustments", "trap_centers")
plt.scatter(wfc[:, 0], wfc[:, 1], c="r", marker="x")
plt.scatter(tc[:, 0], tc[:, 1], c="b", marker="+")
